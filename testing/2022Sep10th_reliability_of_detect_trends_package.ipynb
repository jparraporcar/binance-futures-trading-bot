# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester

# %%
macd = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd.prepare_data(start='2018-01-29-20:00', end='2022-09-11-20:00', interval='1d', ema_fast=12, ema_slow=26, ema_signal=9)
# Out:
# 1686

# %%
macd.data_init
# Out:
#                 Open      High       Low     Close         Volume   macd_diff  \
# Date
# 2018-01-30  11250.11  11308.42   9900.00  10237.51   25554.372946         NaN
# 2018-01-31  10230.00  10425.85   9700.00  10285.10   18015.956805         NaN
# 2018-02-01  10285.10  10335.00   8750.99   9224.52   33564.764311         NaN
# 2018-02-02   9224.52   9250.00   8010.02   8873.03   49971.626975         NaN
# 2018-02-03   8873.03   9473.01   8229.00   9199.96   28725.000735         NaN
# ...              ...       ...       ...       ...            ...         ...
# 2022-09-07  18790.61  19464.06  18510.77  19292.84  287394.778800  -68.041535
# 2022-09-08  19292.85  19458.25  19012.00  19319.77  262813.282730  -44.939608
# 2022-09-09  19320.54  21597.22  19291.75  21360.11  428919.746520  109.125145
# 2022-09-10  21361.62  21810.80  21111.13  21648.34  307997.335040  225.134246
# 2022-09-11  21647.21  21682.60  21350.00  21599.24   79356.863870  289.168674
#
#              macd_macd  macd_signal  log_returns_hold  multiple_hold_acum  \
# Date
# 2018-01-30         NaN          NaN               NaN                 NaN
# 2018-01-31         NaN          NaN          0.004638            1.004649
# 2018-02-01         NaN          NaN         -0.108831            0.901051
# 2018-02-02         NaN          NaN         -0.038849            0.866718
# 2018-02-03         NaN          NaN          0.036183            0.898652
# ...                ...          ...               ...                 ...
# 2022-09-07 -826.743994  -758.702459          0.026377            1.884525
# 2022-09-08 -814.876968  -769.937361          0.001395            1.887155
# 2022-09-09 -633.530929  -742.656074          0.100396            2.086456
# 2022-09-10 -461.238266  -686.372513          0.013404            2.114610
# 2022-09-11 -324.911670  -614.080344         -0.002271            2.109814
#
#             position  inv_sign
# Date
# 2018-01-30         0         0
# 2018-01-31         0         0
# 2018-02-01         0         0
# 2018-02-02         0         0
# 2018-02-03         0         0
# ...              ...       ...
# 2022-09-07         0         0
# 2022-09-08         0         0
# 2022-09-09         0         0
# 2022-09-10         0         0
# 2022-09-11         0         0
#
# [1686 rows x 12 columns]

# %%
macd.assign_trends(window_size=15)

# %%
macd.assign_trends(window_size=15)
# Out:
# The trends have already been assigned, please execute first 'clean_assign_trend' before executing            this method again
