# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm')
from macd_long_backtester import Macd_long_backtester
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### 1.1) Fast trial optimization for simple MACD

# %%
macd_simp_rec_side = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %% [markdown]
# ### "recent_sideways" period

# %%
macd_simp_rec_side.execute_opt(start_opt='2022-09-24-09:00', end_opt='2022-09-26-21:00', interval_opt=('5m', '15m'), ema_slow_opt=(15,40,5), ema_fast_opt=(3,15,5), ema_sign_opt=(3,21,3), trend_ref='ee_macd_simp', type_trend='recent_sideways')
# Out:
# 721
# 741
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986582          -0.008057          0.026189           -0.30764
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.98333          -0.010026          0.017601
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.569606                    0.870749              -0.082543
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.02123              -3.888005
# processed 1 out of a total 180
# 721
# 744
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986582          -0.008057          0.026189           -0.30764
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.984251          -0.009467          0.017715
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# ...

# %%
# macd_simp_rec_side.opt_results = pd.read_csv('recent_sideways.csv')

# %%
macd_simp_rec_side.opt_results[macd_simp_rec_side.opt_results.multiple_macd_strategy == macd_simp_rec_side.opt_results.multiple_macd_strategy.max()]
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 13           5m             15             13                6       0.986582
#
#     ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 13          -0.008057          0.026189           -0.30764
#
#     multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 13                1.005192           0.003088          0.017397
#
#     sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 13           0.177514                    0.950335              -0.030381
#
#     ann_log_std_macd_net  sharpe_ratio_macd_net     trend_ref  \
# 13              0.019005                -1.5986  ee_macd_simp
#
#            start_opt           end_opt
# 13  2022-09-24-09:00  2022-09-26-21:00

# %% [markdown]
# ### 1.2) Backtesting for optimized parameters for simple MACD

# %%
macd_simp_rec_side.prepare_data(start='2022-09-24-09:00', end='2022-09-26-21:00', interval='5m')
# Out:
# 721

# %%
macd_simp_rec_side.execute_backtest(start='2022-09-24-09:00', ema_slow=15, ema_fast=13, ema_signal=6)
# Out:
# 744
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986582          -0.008057          0.026189           -0.30764
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.005192           0.003088          0.017397
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.177514                    0.950335              -0.030381
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.019005                -1.5986
# (0.9865820354818746,
#  -0.008056718274623668,
#  0.026188754617355627,
#  -0.3076403743645136,
#  1.0051915221403633,
#  0.0030882415308051956,
#  0.0173971868485635,
#  0.1775138450651402,
#  0.9503349199902932,
#  -0.030381364939936616,
#  0.01900497977494846,
#  -1.5986002247676165)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 2.1) Fast trial optimization for peak MACD

# %%
macd_peak_rec_side = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
macd_peak_rec_side.execute_opt(start_opt='2022-09-24-09:00', end_opt='2022-09-26-21:00', interval_opt=('5m', '15m'), ema_slow_opt=(15,40,5), ema_fast_opt=(3,15,5), ema_sign_opt=(3,21,3), trend_ref='ee_macd_peak', type_trend='recent_sideways_peak')
# Out:
# 721
# 741
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986582          -0.008057          0.026189           -0.30764
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.980862               -0.011544               0.019627
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.588146                         0.933663
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041004                   0.020452
#
#    sharpe_ratio_macd_peak_net
# 0                    -2.00495
# processed 1 out of a total 180
# 721
# 744
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986582          -0.008057          0.026189           -0.30764
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# ...

# %%
# macd_peak_rec_side.opt_results = pd.read_csv('recent_sideways_peak.csv')

# %%
macd_peak_rec_side.opt_results
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0             5m             15              3                3
# 1             5m             15              3                6
# 2             5m             15              3                9
# 3             5m             15              3               12
# 4             5m             15              3               15
# 5             5m             15              3               18
# 6             5m             15              8                3
# 7             5m             15              8                6
# 8             5m             15              8                9
# 9             5m             15              8               12
# 10            5m             15              8               15
# 11            5m             15              8               18
# 12            5m             15             13                3
# 13            5m             15             13                6
# ...

# %%
macd_peak_rec_side.opt_results[macd_peak_rec_side.opt_results.multiple_macd_peak_strategy == macd_peak_rec_side.opt_results.multiple_macd_peak_strategy.max()]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 113          15m             20              3               18
# 130          15m             25              3               15
# 148          15m             30              3               15
# 156          15m             30             13                3
# 165          15m             35              3               12
# 174          15m             35             13                3
#
#      multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 113       0.988433          -0.020816          0.042701           -0.48748
# 130       0.988433          -0.020816          0.042701           -0.48748
# 148       0.988433          -0.020816          0.042701           -0.48748
# 156       0.988433          -0.020816          0.042701           -0.48748
# 165       0.988433          -0.020816          0.042701           -0.48748
# ...

# %% [markdown]
# ### 1.2) Backtesting for optimized parameters for peak MACD

# %%
macd_peak_rec_side.prepare_data(start='2022-09-24-09:00', end='2022-09-26-21:00', interval='15m')
# Out:
# 241

# %%
macd_peak_rec_side.execute_backtest(start='2022-09-24-09:00', ema_slow=20, ema_fast=3, ema_signal=18)
# Out:
# 281
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.988433          -0.020816          0.042701           -0.48748
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.016567                0.029544               0.029071
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                1.016273                         1.001979
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    0.003554                   0.030056
#
#    sharpe_ratio_macd_peak_net
# 0                     0.11825
# (0.9884332033746296,
#  -0.020816115283915023,
#  0.042701459965306804,
#  -0.4874801775121335,
#  1.0165673070085426,
#  0.02954444198448523,
#  0.029071375843617662,
#  1.016272574900215,
#  1.001978652671173,
#  0.0035541609185352806,
#  0.030056236701326993,
#  0.11825036360518026)

# %% [markdown]
# ### 3) Plot results of accumulated returns (gross)

# %%
macd_peak_rec_side.plot_backtest_results(start_plot='2022-09-24-09:00',end_plot='2022-09-26-21:00', width_bars=0.01)

# %%
macd_simp_rec_side.plot_backtest_results(start_plot='2022-09-24-09:00',end_plot='2022-09-26-21:00', width_bars=0.01)

# %% [markdown]
# ### Testing A downtrend for class peak

# %%
macd_simp_rec_side.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_simp_rec_side.data_init.macd_log_returns_acum.plot(figsize=(15,10))
macd_peak_rec_side.data_init.macd_peak_log_returns_acum.plot(figsize=(15,10))
plt.legend()
