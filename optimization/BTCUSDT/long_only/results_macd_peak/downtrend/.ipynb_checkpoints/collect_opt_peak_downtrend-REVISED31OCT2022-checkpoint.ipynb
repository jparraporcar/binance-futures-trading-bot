# %%
import pandas as pd
import sys
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = [file for file in os.listdir() if os.path.splitext(file)[1] == '.csv']

# %%
files
# Out:
# ['downtrend_peak_j.csv',
#  'downtrend_peak_f.csv',
#  'downtrend_peak_b.csv',
#  'downtrend_peak_c.csv',
#  'downtrend_peak_a.csv']

# %%
results_peak = []
for name in files:
    results_peak.append(utils.find_max(filename=name, type_max='max', type_trend='downtrend', strategy='peak'))
# Out:
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3615           1h             22              4               28
# 4011           1h             28              4               22
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3615       0.806879          -0.097537          0.112425          -0.867577
# 4011       0.806879          -0.097537          0.112425          -0.867577
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 3615                     1.108469                0.046867
# 4011                     1.108469                0.046867
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 3615               0.085073                0.550906
# 4011               0.085073                0.550906
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 3615                          1.06595                    0.029066
# 4011                          1.06595                    0.029066
#
#       ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net trend_ref  \
# 3615                   0.085601                    0.339557         J
# 4011                   0.085601                    0.339557         J
#
#              start_opt           end_opt
# 3615  2019-11-13-00:00  2019-12-17-00:00
# 4011  2019-11-13-00:00  2019-12-17-00:00
# newmax     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 398          15m             22              2                2
#
#      multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 398       0.501985          -0.070188          0.101641          -0.690546
#
#      multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 398                     0.922353               -0.008234
#
#      ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 398                0.06914                -0.11909
#
#      multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 398                         0.708032                   -0.035172
#
#      ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net trend_ref  \
# 398                   0.069463                   -0.506346         F
#
#             start_opt           end_opt
# 398  2018-11-07-00:00  2018-12-15-00:00
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 2806          30m             34              4                6
# 2824          30m             34              6                4
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2806       0.589082          -0.123342          0.170489          -0.723463
# 2824       0.589082          -0.123342          0.170489          -0.723463
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 2806                     1.162645                0.035147
# 2824                     1.162645                0.035147
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 2806               0.119681                 0.29367
# 2824               0.119681                 0.29367
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 2806                         1.033921                     0.00778
# 2824                         1.033921                     0.00778
#
#       ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net trend_ref  \
# 2806                   0.120386                    0.064625         B
# 2824                   0.120386                    0.064625         B
#
#              start_opt           end_opt
# 2806  2018-03-04-00:00  2018-04-06-00:00
# 2824  2018-03-04-00:00  2018-04-06-00:00
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1609          30m             16              4                6
# 1627          30m             16              6                4
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1609        0.61307          -0.071349          0.093882           -0.75998
# 1627        0.61307          -0.071349          0.093882           -0.75998
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 1609                     1.026427                0.003805
# 1627                     1.026427                0.003805
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 1609               0.062301                0.061077
# 1627               0.062301                0.061077
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 1609                         0.849141                   -0.023856
# 1627                         0.849141                   -0.023856
#
#       ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net trend_ref  \
# 1609                   0.063061                   -0.378306         C
# 1627                   0.063061                   -0.378306         C
#
#              start_opt           end_opt
# 1609  2018-05-06-00:00  2018-06-28-00:00
# 1627  2018-05-06-00:00  2018-06-28-00:00
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1464          15m             38              2                4
# 1482          15m             38              4                2
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1464       0.512629          -0.088753          0.204537          -0.433923
# 1482       0.512629          -0.088753          0.204537          -0.433923
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 1464                     1.629106                0.064846
# 1482                     1.629106                0.064846
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 1464               0.158022                0.410358
# 1482               0.158022                0.410358
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 1464                         1.317136                    0.036601
# 1482                         1.317136                    0.036601
#
#       ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net trend_ref  \
# 1464                   0.158425                    0.231031         A
# 1482                   0.158425                    0.231031         A
#
#              start_opt           end_opt
# 1464  2018-01-07-00:00  2018-02-05-00:00
# 1482  2018-01-07-00:00  2018-02-05-00:00

# %%
len(results_peak)
# Out:
# 5

# %%
results_peak_df = pd.DataFrame(data=results_peak[0])

# %%
results_peak_df = results_peak_df.append(results_peak[1])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_38584/2549901859.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[1])

# %%
results_peak_df = results_peak_df.append(results_peak[2])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_38584/2895677857.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[2])

# %%
results_peak_df = results_peak_df.append(results_peak[3])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_38584/2168530471.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[3])

# %%
results_peak_df = results_peak_df.append(results_peak[4])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_38584/3063767121.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[4])

# %%
results_peak_df
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3615           1h             22              4               28
# 4011           1h             28              4               22
# 398           15m             22              2                2
# 2806          30m             34              4                6
# 2824          30m             34              6                4
# 1609          30m             16              4                6
# 1627          30m             16              6                4
# 1464          15m             38              2                4
# 1482          15m             38              4                2
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3615       0.806879          -0.097537          0.112425          -0.867577
# 4011       0.806879          -0.097537          0.112425          -0.867577
# 398        0.501985          -0.070188          0.101641          -0.690546
# 2806       0.589082          -0.123342          0.170489          -0.723463
# 2824       0.589082          -0.123342          0.170489          -0.723463
# 1609       0.613070          -0.071349          0.093882          -0.759980
# 1627       0.613070          -0.071349          0.093882          -0.759980
# 1464       0.512629          -0.088753          0.204537          -0.433923
# 1482       0.512629          -0.088753          0.204537          -0.433923
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 3615                     1.108469                0.046867
# 4011                     1.108469                0.046867
# 398                      0.922353               -0.008234
# 2806                     1.162645                0.035147
# 2824                     1.162645                0.035147
# 1609                     1.026427                0.003805
# 1627                     1.026427                0.003805
# 1464                     1.629106                0.064846
# 1482                     1.629106                0.064846
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 3615               0.085073                0.550906
# 4011               0.085073                0.550906
# 398                0.069140               -0.119090
# 2806               0.119681                0.293670
# 2824               0.119681                0.293670
# 1609               0.062301                0.061077
# 1627               0.062301                0.061077
# 1464               0.158022                0.410358
# 1482               0.158022                0.410358
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 3615                         1.065950                    0.029066
# 4011                         1.065950                    0.029066
# 398                          0.708032                   -0.035172
# 2806                         1.033921                    0.007780
# 2824                         1.033921                    0.007780
# 1609                         0.849141                   -0.023856
# 1627                         0.849141                   -0.023856
# 1464                         1.317136                    0.036601
# 1482                         1.317136                    0.036601
#
#       ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net trend_ref  \
# 3615                   0.085601                    0.339557         J
# 4011                   0.085601                    0.339557         J
# 398                    0.069463                   -0.506346         F
# 2806                   0.120386                    0.064625         B
# 2824                   0.120386                    0.064625         B
# 1609                   0.063061                   -0.378306         C
# 1627                   0.063061                   -0.378306         C
# 1464                   0.158425                    0.231031         A
# 1482                   0.158425                    0.231031         A
#
#              start_opt           end_opt
# 3615  2019-11-13-00:00  2019-12-17-00:00
# 4011  2019-11-13-00:00  2019-12-17-00:00
# 398   2018-11-07-00:00  2018-12-15-00:00
# 2806  2018-03-04-00:00  2018-04-06-00:00
# 2824  2018-03-04-00:00  2018-04-06-00:00
# 1609  2018-05-06-00:00  2018-06-28-00:00
# 1627  2018-05-06-00:00  2018-06-28-00:00
# 1464  2018-01-07-00:00  2018-02-05-00:00
# 1482  2018-01-07-00:00  2018-02-05-00:00

# %%
results_peak_df.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     9.000000       9.000000       9.000000         9.000000
# mean   2204.000000      27.555556       4.000000         8.666667
# std    1173.693316       8.875685       1.414214         9.486833
# min     398.000000      16.000000       2.000000         2.000000
# 25%    1482.000000      22.000000       4.000000         4.000000
# 50%    1627.000000      28.000000       4.000000         4.000000
# 75%    2824.000000      34.000000       4.000000         6.000000
# max    4011.000000      38.000000       6.000000        28.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       9.000000           9.000000          9.000000           9.000000
# mean        0.616145          -0.092461          0.140478          -0.695604
# std         0.116569           0.020536          0.046681           0.160456
# min         0.501985          -0.123342          0.093882          -0.867577
# 25%         0.512629          -0.097537          0.101641          -0.759980
# 50%         0.589082          -0.088753          0.112425          -0.723463
# 75%         0.613070          -0.071349          0.170489          -0.690546
# max         0.806879          -0.070188          0.204537          -0.433923
#
#        multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# count                     9.000000                9.000000
# mean                      1.197294                0.032566
# std                       0.256195                0.026985
# min                       0.922353               -0.008234
# 25%                       1.026427                0.003805
# 50%                       1.108469                0.035147
# 75%                       1.162645                0.046867
# max                       1.629106                0.064846
#
#        ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# count               9.000000                9.000000
# mean                0.102144                0.279215
# std                 0.038254                0.233523
# min                 0.062301               -0.119090
# 25%                 0.069140                0.061077
# 50%                 0.085073                0.293670
# 75%                 0.119681                0.410358
# max                 0.158022                0.550906
#
#        multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# count                         9.000000                    9.000000
# mean                          1.026703                    0.007112
# std                           0.205090                    0.028307
# min                           0.708032                   -0.035172
# 25%                           0.849141                   -0.023856
# 50%                           1.033921                    0.007780
# 75%                           1.065950                    0.029066
# max                           1.317136                    0.036601
#
#        ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net
# count                   9.000000                    9.000000
# mean                    0.102712                    0.000830
# std                     0.038190                    0.333225
# min                     0.063061                   -0.506346
# 25%                     0.069463                   -0.378306
# 50%                     0.085601                    0.064625
# 75%                     0.120386                    0.231031
# max                     0.158425                    0.339557

# %%
results_peak_df.reset_index(inplace=True)

# %%
results_peak_df.rename(columns={'index': 'index_opt'}, inplace=True)

# %%
results_peak_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       3615           1h             22              4               28
# 1       4011           1h             28              4               22
# 2        398          15m             22              2                2
# 3       2806          30m             34              4                6
# 4       2824          30m             34              6                4
# 5       1609          30m             16              4                6
# 6       1627          30m             16              6                4
# 7       1464          15m             38              2                4
# 8       1482          15m             38              4                2
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
# 1       0.806879          -0.097537          0.112425          -0.867577
# 2       0.501985          -0.070188          0.101641          -0.690546
# 3       0.589082          -0.123342          0.170489          -0.723463
# 4       0.589082          -0.123342          0.170489          -0.723463
# 5       0.613070          -0.071349          0.093882          -0.759980
# 6       0.613070          -0.071349          0.093882          -0.759980
# 7       0.512629          -0.088753          0.204537          -0.433923
# 8       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.108469                0.046867               0.085073
# 1                     1.108469                0.046867               0.085073
# 2                     0.922353               -0.008234               0.069140
# 3                     1.162645                0.035147               0.119681
# 4                     1.162645                0.035147               0.119681
# 5                     1.026427                0.003805               0.062301
# 6                     1.026427                0.003805               0.062301
# 7                     1.629106                0.064846               0.158022
# 8                     1.629106                0.064846               0.158022
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.550906                         1.065950
# 1                0.550906                         1.065950
# 2               -0.119090                         0.708032
# 3                0.293670                         1.033921
# 4                0.293670                         1.033921
# 5                0.061077                         0.849141
# 6                0.061077                         0.849141
# 7                0.410358                         1.317136
# 8                0.410358                         1.317136
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    0.029066                   0.085601
# 1                    0.029066                   0.085601
# 2                   -0.035172                   0.069463
# 3                    0.007780                   0.120386
# 4                    0.007780                   0.120386
# 5                   -0.023856                   0.063061
# 6                   -0.023856                   0.063061
# 7                    0.036601                   0.158425
# 8                    0.036601                   0.158425
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 0                    0.339557         J  2019-11-13-00:00  2019-12-17-00:00
# 1                    0.339557         J  2019-11-13-00:00  2019-12-17-00:00
# 2                   -0.506346         F  2018-11-07-00:00  2018-12-15-00:00
# 3                    0.064625         B  2018-03-04-00:00  2018-04-06-00:00
# 4                    0.064625         B  2018-03-04-00:00  2018-04-06-00:00
# 5                   -0.378306         C  2018-05-06-00:00  2018-06-28-00:00
# 6                   -0.378306         C  2018-05-06-00:00  2018-06-28-00:00
# 7                    0.231031         A  2018-01-07-00:00  2018-02-05-00:00
# 8                    0.231031         A  2018-01-07-00:00  2018-02-05-00:00

# %% [markdown]
# ### Filter duplicated and make priority HIGH-LOW-HIGH

# %%
cond1 = results_peak_df.index != 0
cond2 = results_peak_df.index != 4
cond3 = results_peak_df.index != 6
cond4 = results_peak_df.index != 8

results_peak_df = results_peak_df[cond1&cond2&cond3&cond4]

# %%
results_peak_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1       4011           1h             28              4               22
# 2        398          15m             22              2                2
# 3       2806          30m             34              4                6
# 5       1609          30m             16              4                6
# 7       1464          15m             38              2                4
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1       0.806879          -0.097537          0.112425          -0.867577
# 2       0.501985          -0.070188          0.101641          -0.690546
# 3       0.589082          -0.123342          0.170489          -0.723463
# 5       0.613070          -0.071349          0.093882          -0.759980
# 7       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 1                     1.108469                0.046867               0.085073
# 2                     0.922353               -0.008234               0.069140
# 3                     1.162645                0.035147               0.119681
# 5                     1.026427                0.003805               0.062301
# 7                     1.629106                0.064846               0.158022
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 1                0.550906                         1.065950
# 2               -0.119090                         0.708032
# 3                0.293670                         1.033921
# 5                0.061077                         0.849141
# 7                0.410358                         1.317136
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 1                    0.029066                   0.085601
# 2                   -0.035172                   0.069463
# 3                    0.007780                   0.120386
# 5                   -0.023856                   0.063061
# 7                    0.036601                   0.158425
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 1                    0.339557         J  2019-11-13-00:00  2019-12-17-00:00
# 2                   -0.506346         F  2018-11-07-00:00  2018-12-15-00:00
# 3                    0.064625         B  2018-03-04-00:00  2018-04-06-00:00
# 5                   -0.378306         C  2018-05-06-00:00  2018-06-28-00:00
# 7                    0.231031         A  2018-01-07-00:00  2018-02-05-00:00

# %%
cond1 = results_peak_df.index == 1
results_peak_df_1h = results_peak_df[cond1]
results_peak_df_1h
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1       4011           1h             28              4               22
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 1                     1.108469                0.046867               0.085073
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 1                0.550906                          1.06595
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 1                    0.029066                   0.085601
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 1                    0.339557         J  2019-11-13-00:00  2019-12-17-00:00

# %% [markdown]
# Find the average of these 2 combinations

# %% [markdown]
# ##  Parameters for 1h -> 28, 4, 22 (returns < 1)

# %%
cond1 = results_peak_df.index == 3
cond2 = results_peak_df.index == 5
results_peak_df_30m = results_peak_df[cond1|cond2]
results_peak_df_30m
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3       2806          30m             34              4                6
# 5       1609          30m             16              4                6
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3       0.589082          -0.123342          0.170489          -0.723463
# 5       0.613070          -0.071349          0.093882          -0.759980
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 3                     1.162645                0.035147               0.119681
# 5                     1.026427                0.003805               0.062301
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 3                0.293670                         1.033921
# 5                0.061077                         0.849141
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 3                    0.007780                   0.120386
# 5                   -0.023856                   0.063061
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 3                    0.064625         B  2018-03-04-00:00  2018-04-06-00:00
# 5                   -0.378306         C  2018-05-06-00:00  2018-06-28-00:00

# %%
results_peak_df_30m.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     2.000000       2.000000            2.0              2.0
# mean   2207.500000      25.000000            4.0              6.0
# std     846.406817      12.727922            0.0              0.0
# min    1609.000000      16.000000            4.0              6.0
# 25%    1908.250000      20.500000            4.0              6.0
# 50%    2207.500000      25.000000            4.0              6.0
# 75%    2506.750000      29.500000            4.0              6.0
# max    2806.000000      34.000000            4.0              6.0
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       2.000000           2.000000          2.000000           2.000000
# mean        0.601076          -0.097346          0.132186          -0.741721
# std         0.016962           0.036765          0.054169           0.025821
# min         0.589082          -0.123342          0.093882          -0.759980
# 25%         0.595079          -0.110344          0.113034          -0.750851
# 50%         0.601076          -0.097346          0.132186          -0.741721
# 75%         0.607073          -0.084347          0.151337          -0.732592
# max         0.613070          -0.071349          0.170489          -0.723463
#
#        multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# count                     2.000000                2.000000
# mean                      1.094536                0.019476
# std                       0.096321                0.022162
# min                       1.026427                0.003805
# 25%                       1.060481                0.011641
# 50%                       1.094536                0.019476
# 75%                       1.128590                0.027311
# max                       1.162645                0.035147
#
#        ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# count               2.000000                2.000000
# mean                0.090991                0.177374
# std                 0.040574                0.164468
# min                 0.062301                0.061077
# 25%                 0.076646                0.119226
# 50%                 0.090991                0.177374
# 75%                 0.105336                0.235522
# max                 0.119681                0.293670
#
#        multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# count                         2.000000                    2.000000
# mean                          0.941531                   -0.008038
# std                           0.130659                    0.022370
# min                           0.849141                   -0.023856
# 25%                           0.895336                   -0.015947
# 50%                           0.941531                   -0.008038
# 75%                           0.987726                   -0.000129
# max                           1.033921                    0.007780
#
#        ann_log_std_macd_peak_net  sharpe_ratio_macd_peak_net
# count                   2.000000                    2.000000
# mean                    0.091724                   -0.156840
# std                     0.040535                    0.313199
# min                     0.063061                   -0.378306
# 25%                     0.077392                   -0.267573
# 50%                     0.091724                   -0.156840
# 75%                     0.106055                   -0.046108
# max                     0.120386                    0.064625

# %% [markdown]
# ## Parameters for 30m (only one measure) -> 25, 4, 6

# %%
cond1 = results_peak_df.index == 7
results_peak_df_15 = results_peak_df[cond1]
results_peak_df_15
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 7       1464          15m             38              2                4
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 7       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 7                     1.629106                0.064846               0.158022
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 7                0.410358                         1.317136
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 7                    0.036601                   0.158425
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 7                    0.231031         A  2018-01-07-00:00  2018-02-05-00:00

# %% [markdown]
# ## Parameters for 15m (only one measure) -> 38, 2, 4
