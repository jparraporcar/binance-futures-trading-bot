# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_opt_c = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
df = pd.read_csv('downtrend_c.csv')
macd_opt_c.opt_results = df

# %%
# macd_opt_c.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-05-06-00:00', end_opt='2018-06-28-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='C', type_trend='downtrend_c')

# %% [markdown]
# ### 2) Extract combinations of max

# %%
macd_opt_c.opt_results[macd_opt_c.opt_results.multiple_macd_strategy == macd_opt_c.opt_results.multiple_macd_strategy.max()]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 234          15m             18              2                2
# 816          15m             18              2                2
#
#      multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 234       0.617234          -0.035188          0.065108          -0.540453
# 816       0.617234          -0.035188          0.065108          -0.540453
#
#      multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 234                1.030872           0.002217          0.043799
# 816                1.030872           0.002217          0.043799
#
#      sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 234           0.050625                    0.280921              -0.092594
# 816           0.050625                    0.280921              -0.092594
#
#      ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 234              0.047019              -1.969276         C  2018-05-06-00:00
# 816              0.047019              -1.969276         C  2018-05-06-00:00
#
#               end_opt
# 234  2018-06-28-00:00
# 816  2018-06-28-00:00

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
macd_opt_c_15m = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_c_15m.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='15m')
# Out:
# 5042

# %%
macd_opt_c_15m.execute_backtest(start='2018-05-06-00:00', ema_slow=18, ema_fast=2, ema_signal=2)
# Out:
# 5064
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.030872           0.002217          0.043799
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.050625                    0.280921              -0.092594
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.047019              -1.969276
# (0.6172342276718868,
#  -0.035187801565633066,
#  0.06510793074568187,
#  -0.5404533850581147,
#  1.0308719257304984,
#  0.0022173457542515127,
#  0.04379934421838977,
#  0.050625090256957064,
#  0.28092068257115,
#  -0.09259425874968137,
#  0.04701944730743323,
#  -1.969275779535658)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
macd_opt_c_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_c_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
macd_opt_c.opt_results[macd_opt_c.opt_results.multiple_macd_strategy_net == macd_opt_c.opt_results.multiple_macd_strategy_net.max()]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4134           1h             18             14               28
# 4793           1h             28             14               18
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4134       0.613704          -0.142339          0.133825          -1.063616
# 4793       0.613704          -0.142339          0.133825          -1.063616
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4134                0.919114          -0.024589          0.080987
# 4793                0.919114          -0.024589          0.080987
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 4134          -0.303619                    0.877867              -0.037975
# 4793          -0.303619                    0.877867              -0.037975
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 4134              0.081592               -0.46543         C  2018-05-06-00:00
# 4793              0.081592               -0.46543         C  2018-05-06-00:00
#
#                end_opt
# 4134  2018-06-28-00:00
# 4793  2018-06-28-00:00

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %%
macd_opt_c_1h = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_c_1h.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='1h')
# Out:
# 1262

# %%
macd_opt_c_1h.execute_backtest(start='2018-05-06-00:00', ema_slow=28, ema_fast=14, ema_signal=18)
# Out:
# 1310
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.919114          -0.024589          0.080987
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.303619                    0.877867              -0.037975
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.081592               -0.46543
# (0.6137043896794723,
#  -0.14233889747043804,
#  0.13382540163491147,
#  -1.063616441509006,
#  0.9191144715702373,
#  -0.024589281334284997,
#  0.08098722027486929,
#  -0.3036192778419778,
#  0.8778670956628022,
#  -0.037975179710762294,
#  0.08159158304003893,
#  -0.4654301129581831)

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %%
macd_opt_c_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_c_1h.data_init.macd_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 8) Carry out backtest with optimized strategy macd_peak with same parameters and see results

# %%
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm')
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm

# %% [markdown]
# ### 9) Plot results of macd_peak acum vs macd acum vs hold

# %%
macd_opt_c_15m_peak = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
macd_opt_c_15m_peak.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='15m')
# Out:
# 5042

# %%
macd_opt_c_15m_peak.execute_backtest(start='2018-05-06-00:00', ema_slow=18, ema_fast=2, ema_signal=2)
# Out:
# 5064
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.811632               -0.015224               0.046005
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.33091                         0.578121
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03997                    0.04633
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.862719
# (0.6172342276718868,
#  -0.035187801565633066,
#  0.06510793074568187,
#  -0.5404533850581147,
#  0.8116319795315029,
#  -0.015223524797954757,
#  0.04600499601337499,
#  -0.3309102514328843,
#  0.5781207403644357,
#  -0.03997001931409194,
#  0.046330279538816015,
#  -0.8627191485128991)

# %%
macd_opt_c_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_c_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
macd_opt_c_15m_peak.data_init.macd_peak_log_returns_acum.plot()
plt.legend()

# %% [markdown]
# ### 10) Try the calculated average for the emas in the collect_opt file

# %% [markdown]
# __meanbest_1h_par = 26,14,26__

# %%
macd_opt_meanbest_1h_par = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_meanbest_1h_par.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='1h')
# Out:
# 1262

# %%
macd_opt_meanbest_1h_par.execute_backtest(start='2018-05-06-00:00', ema_slow=26, ema_fast=14, ema_signal=26)
# Out:
# 1316
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.818583          -0.058359          0.080148
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.728146                    0.784511              -0.070754
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.080629              -0.877523
# (0.6137043896794723,
#  -0.14233889747043804,
#  0.13382540163491147,
#  -1.063616441509006,
#  0.8185829967279866,
#  -0.05835932707630481,
#  0.08014788074094288,
#  -0.7281456045598524,
#  0.7845109053766277,
#  -0.0707536774248949,
#  0.08062888612077064,
#  -0.8775226947686704)

# %% [markdown]
# ### results with the opt parameters of 1h are better than buy and hold but lower than those coming from the own optimization of the interval

# %% [markdown]
# __meanbest_15m_par = 20,6,36__

# %%
macd_opt_meanbest_15m_par = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_meanbest_15m_par.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='15m')
# Out:
# 5042

# %%
macd_opt_meanbest_15m_par.execute_backtest(start='2018-05-06-00:00', ema_slow=20, ema_fast=6, ema_signal=36)
# Out:
# 5100
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.772127          -0.018859          0.042866
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.439964                    0.569493              -0.041059
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.043816              -0.937076
# (0.6172342276718868,
#  -0.035187801565633066,
#  0.06510793074568187,
#  -0.5404533850581147,
#  0.7721265618810106,
#  -0.018859437118642963,
#  0.04286584406773134,
#  -0.4399642076064943,
#  0.5694926910666719,
#  -0.04105862247665952,
#  0.04381567390006386,
#  -0.9370761378749369)
