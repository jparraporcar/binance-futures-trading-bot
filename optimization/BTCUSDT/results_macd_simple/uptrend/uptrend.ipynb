# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
up = Macd_long_backtester('BTCUSDT')

# %%
up.prepare_data(start='2018-01-01-00:00', end='2022-09-20-00:00', interval='1d')
# Out:
# 1723

# %%
up.assign_trends(window_size=20,plot=True)

# %%
'ABEFG'
# Out:
# 'ABEFG'

# %%
a_up = up.get_trend_dates(type_trend='Up Trend', trend_ref='A', do_plot=True)
a_up
# Out:
# date_init: 2018-02-05 00:00:00 1517788800000
# date_end: 2018-03-04 00:00:00 1520121600000
# (1517788800000, 1520121600000)

# %%
b_up = up.get_trend_dates(type_trend='Up Trend', trend_ref='B', do_plot=True)
b_up
# Out:
# date_init: 2018-04-10 00:00:00 1523318400000
# date_end: 2018-05-05 00:00:00 1525478400000
# (1523318400000, 1525478400000)

# %%
e_up = up.get_trend_dates(type_trend='Up Trend', trend_ref='E', do_plot=True)
e_up
# Out:
# date_init: 2020-01-03 00:00:00 1578009600000
# date_end: 2020-02-14 00:00:00 1581638400000
# (1578009600000, 1581638400000)

# %%
f_up = up.get_trend_dates(type_trend='Up Trend', trend_ref='F', do_plot=True)
f_up
# Out:
# date_init: 2020-04-20 00:00:00 1587340800000
# date_end: 2020-05-07 00:00:00 1588809600000
# (1587340800000, 1588809600000)

# %%
g_up = up.get_trend_dates(type_trend='Up Trend', trend_ref='G', do_plot=True)
g_up
# Out:
# date_init: 2020-07-21 00:00:00 1595289600000
# date_end: 2020-08-17 00:00:00 1597622400000
# (1595289600000, 1597622400000)
