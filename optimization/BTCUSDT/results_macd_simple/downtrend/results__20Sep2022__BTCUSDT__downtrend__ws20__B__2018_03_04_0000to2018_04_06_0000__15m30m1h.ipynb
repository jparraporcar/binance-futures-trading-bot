# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_opt_b = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
# macd_opt_b.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-03-04-00:00', end_opt='2018-04-06-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='B', type_trend='downtrend_b')

# %%
df = pd.read_csv('downtrend_b.csv')
macd_opt_b.opt_results = df

# %% [markdown]
# ### 2) Extract combinations of max

# %%
macd_opt_b.opt_results[macd_opt_b.opt_results.multiple_macd_strategy == macd_opt_b.opt_results.multiple_macd_strategy.max()]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4623           1h             24             14               24
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4623       0.593626          -0.243103          0.241127          -1.008196
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4623                0.870843          -0.064466          0.168428
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 4623          -0.382752                    0.845309              -0.078339
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 4623              0.169046              -0.463417         B  2018-03-04-00:00
#
#                end_opt
# 4623  2018-04-06-00:00

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
macd_opt_b_1h = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_b_1h.prepare_data(start='2018-03-04-00:00', end='2018-04-06-00:00', interval='1h')
# Out:
# 793

# %%
macd_opt_b_1h.execute_backtest(start='2018-03-04-00:00', ema_slow=24, ema_fast=14, ema_signal=24)
# Out:
# 843
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.870843          -0.064466          0.168428
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.382752                    0.845309              -0.078339
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.169046              -0.463417
# (0.5936256872245473,
#  -0.24310319894026708,
#  0.24112694101369866,
#  -1.0081959233516595,
#  0.8708433684604713,
#  -0.06446615449067762,
#  0.1684281900736389,
#  -0.3827515718270927,
#  0.8453088871153147,
#  -0.07833896246705611,
#  0.16904639267243318,
#  -0.46341694270197253)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
macd_opt_b_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_b_1h.data_init.macd_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
macd_opt_b.opt_results[macd_opt_b.opt_results.multiple_macd_strategy_net == macd_opt_b.opt_results.multiple_macd_strategy_net.max()]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4623           1h             24             14               24
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4623       0.593626          -0.243103          0.241127          -1.008196
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4623                0.870843          -0.064466          0.168428
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 4623          -0.382752                    0.845309              -0.078339
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 4623              0.169046              -0.463417         B  2018-03-04-00:00
#
#                end_opt
# 4623  2018-04-06-00:00

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %% [markdown]
# max and max_net are the same combination

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %% [markdown]
# ### 8) Carry out backtest with optimized strategy macd_peak with same parameters and see results

# %%
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm')
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm

# %%
macd_opt_b_1h_peak = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
macd_opt_b_1h_peak.prepare_data(start='2018-03-04-00:00', end='2018-04-06-00:00', interval='1h')
# Out:
# 793

# %%
macd_opt_b_1h_peak.execute_backtest(start='2018-03-04-00:00', ema_slow=24, ema_fast=14, ema_signal=24)
# Out:
# 843
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.720106               -0.153261               0.195767
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.782877                         0.701969
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.165168                   0.196235
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.841682
# (0.5936256872245473,
#  -0.24310319894026708,
#  0.24112694101369866,
#  -1.0081959233516595,
#  0.7201055829042291,
#  -0.15326146253476863,
#  0.195767035399751,
#  -0.7828767607468381,
#  0.7019690062783428,
#  -0.1651676466547953,
#  0.19623518167198803,
#  -0.8416821349133874)

# %% [markdown]
# ### 9) Plot results of macd_peak acum vs macd acum vs hold

# %%
macd_opt_b_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_b_1h.data_init.macd_log_returns_acum.plot(figsize=(15,10))
macd_opt_b_1h_peak.data_init.macd_peak_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 10) Try the calculated average for the emas in the collect_opt file

# %% [markdown]
# __meanbest_1h_par = 26,14,26__

# %%
macd_opt_meanbest_1h_par = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_meanbest_1h_par.prepare_data(start='2018-03-04-00:00', end='2018-04-06-00:00', interval='1h')
# Out:
# 793

# %%
macd_opt_meanbest_1h_par.execute_backtest(start='2018-03-04-00:00', ema_slow=26, ema_fast=14, ema_signal=26)
# Out:
# 847
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.809779          -0.098356          0.157768
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.623421                    0.786035              -0.112229
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.158479              -0.708162
# (0.5936256872245473,
#  -0.24310319894026708,
#  0.24112694101369866,
#  -1.0081959233516595,
#  0.8097789499091159,
#  -0.09835606515449756,
#  0.1577682787679502,
#  -0.6234210446015089,
#  0.7860349722444421,
#  -0.11222887313087603,
#  0.15847916825582561,
#  -0.7081616742820743)

# %% [markdown]
# ### results with combination parameters of 1h give better results than those with 15m, compared with the optimized own results

# %% [markdown]
# __meanbest_15m_par = 20,6,36__

# %%
macd_opt_meanbest_15m_par = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_meanbest_15m_par.prepare_data(start='2018-03-04-00:00', end='2018-04-06-00:00', interval='15m')
# Out:
# 3169

# %%
macd_opt_meanbest_15m_par.execute_backtest(start='2018-03-04-00:00', ema_slow=20, ema_fast=6, ema_signal=36)
# Out:
# 3227
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.671956          -0.046332          0.083798
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.552893                    0.550251              -0.069618
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.084809              -0.820885
# (0.5913272010512473,
#  -0.06122790801740818,
#  0.11967507178084093,
#  -0.5116178925677511,
#  0.6719557663266147,
#  -0.04633154823072624,
#  0.0837984230720685,
#  -0.5528928413232798,
#  0.5502513713003917,
#  -0.06961804733393302,
#  0.08480855454028241,
#  -0.8208847292741654)
