# %%
import pandas as pd
import sys
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = [file for file in os.listdir() if os.path.splitext(file)[1] == '.csv']

# %%
files
# Out:
# ['downtrend_f.csv',
#  'downtrend_A.csv',
#  'downtrend_b.csv',
#  'downtrend_c.csv',
#  'downtrend_j.csv']

# %%
results = []
for name in files:
    results.append(utils.find_max(filename=name, type_max='max', type_trend='downtrend'))
# Out:
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4902           1h             28             14               28
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4902       0.496724          -0.285042          0.200333          -1.422842
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4902                0.898919           -0.04341          0.125823
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 4902          -0.345009                     0.87479              -0.054494
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 4902              0.126051              -0.432317         F  2018-11-07-00:00
#
#                end_opt
# 4902  2018-12-15-00:00
# newmax    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 2           15m             16              2                6       0.512629
# ...

# %%
len(results)
# Out:
# 5

# %%
results_df = pd.DataFrame(data=results[0])

# %%
results_df = results_df.append(results[1])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27899/2045268720.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[1])

# %%
results_df = results_df.append(results[2])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27899/2906862804.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[2])

# %%
results_df = results_df.append(results[3])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27899/669286345.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[3])

# %%
results_df = results_df.append(results[4])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27899/996747469.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[4])

# %%
results_df
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4902           1h             28             14               28
# 2             15m             16              2                6
# 38            15m             16              6                2
# 4623           1h             24             14               24
# 234           15m             18              2                2
# 388           15m             20              6               36
# 2133          15m             36              6               20
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4902       0.496724          -0.285042          0.200333          -1.422842
# 2          0.512629          -0.088753          0.204537          -0.433923
# 38         0.512629          -0.088753          0.204537          -0.433923
# 4623       0.593626          -0.243103          0.241127          -1.008196
# ...

# %%
results_df.describe()
# Out:
#        macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# count       7.000000       7.000000         7.000000       7.000000
# mean       22.571429       7.142857        16.857143       0.621471
# std         7.367884       5.014265        13.606721       0.135511
# min        16.000000       2.000000         2.000000       0.496724
# 25%        17.000000       4.000000         4.000000       0.512629
# 50%        20.000000       6.000000        20.000000       0.593626
# 75%        26.000000      10.000000        26.000000       0.712981
# max        36.000000      14.000000        36.000000       0.808728
#
#        ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count           7.000000          7.000000           7.000000
# mean           -0.112729          0.147062          -0.669658
# std             0.107665          0.082935           0.393762
# min            -0.285042          0.056896          -1.422842
# ...

# %%
results_df.reset_index(inplace=True)

# %%
results_df.rename(columns={'index': 'index_opt'}, inplace=True)

# %%
results_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       4902           1h             28             14               28
# 1          2          15m             16              2                6
# 2         38          15m             16              6                2
# 3       4623           1h             24             14               24
# 4        234          15m             18              2                2
# 5        388          15m             20              6               36
# 6       2133          15m             36              6               20
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.496724          -0.285042          0.200333          -1.422842
# 1       0.512629          -0.088753          0.204537          -0.433923
# 2       0.512629          -0.088753          0.204537          -0.433923
# 3       0.593626          -0.243103          0.241127          -1.008196
# ...

# %%
plt.bar(x=results_df.index, height=results_df.multiple_macd_strategy)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# - Eliminate 5 because is duplicated with 6
# - Eliminate 0, 1, 2 and 4 because the max are low

# %%
cond1 = results_df.index != 0
cond2 = results_df.index != 1
cond3 = results_df.index != 2
cond4 = results_df.index != 4
cond6 = results_df.index != 5

results_df = results_df[cond1&cond2&cond3&cond4]

# %%
results_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3       4623           1h             24             14               24
# 5        388          15m             20              6               36
# 6       2133          15m             36              6               20
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3       0.593626          -0.243103          0.241127          -1.008196
# 5       0.808728          -0.024132          0.056896          -0.424134
# 6       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 3                0.870843          -0.064466          0.168428
# 5                1.106890           0.011544          0.039581
# 6                1.106890           0.011544          0.039581
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# ...

# %% [markdown]
# 2 different parameters are extracted.
# - First one regarding the paramters of index 3 for 1h
# - Second, parameters for 1h are the ones of 5,6 for 15m

# %%
cond1 = results_df.index == 3
results_df_1h = results_df[cond1]
results_df_1h
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3       4623           1h             24             14               24
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 3                0.870843          -0.064466          0.168428
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 3          -0.382752                    0.845309              -0.078339
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 3              0.169046              -0.463417         B  2018-03-04-00:00
#
#             end_opt
# 3  2018-04-06-00:00

# %% [markdown]
# Find the average of these 2 combinations

# %% [markdown]
# ##  Parameters for 1h -> 26, 14, 24 (returns < 1)

# %%
cond1 = results_df.index == 6
results_df_15 = results_df[cond1]
results_df_15
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 6       2133          15m             36              6               20
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 6       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 6                 1.10689           0.011544          0.039581
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 6           0.291651                    0.931412              -0.008077
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 6              0.040276              -0.200537         J  2019-11-13-00:00
#
#             end_opt
# 6  2019-12-17-00:00

# %% [markdown]
# ## Parameters for 15m (only one measure) -> 36, 6, 20
