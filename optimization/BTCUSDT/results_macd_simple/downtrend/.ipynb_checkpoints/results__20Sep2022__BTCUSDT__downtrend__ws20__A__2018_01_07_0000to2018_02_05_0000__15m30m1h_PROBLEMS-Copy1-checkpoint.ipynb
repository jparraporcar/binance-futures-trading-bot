# %%
import sys
sys.path.append('C:\\Users\\jparra\\Desktop\\Invs\\trading_BOT\\macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_opt_a = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_a.opt_results = pd.read_csv('downtrend.csv')

# %%
# macd_opt_a.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-01-07-00:00', end_opt='2018-02-05-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='A', type_trend='downtrend')
# Out:
# 2785
# 2805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.769161           -0.03486          0.139048
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.250707                    0.373365              -0.130858
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.14239              -0.919007
# processed 1 out of a total 4788
# 2785
# 2807
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.788733          -0.031523          0.133465
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.236187                    0.450762              -0.105836
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.136206              -0.777031
# processed 2 out of a total 4788
# 2785
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903444          -0.013487          0.134027
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.10063                     0.55549              -0.078088
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.136434              -0.572347
# processed 3 out of a total 4788
# 2785
# 2811
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.888743          -0.015666          0.133314
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.117514                    0.568248              -0.075072
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.135492              -0.554069
# processed 4 out of a total 4788
# 2785
# 2813
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.748734          -0.038435          0.128258
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.299672                    0.490263              -0.094679
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.130341              -0.726391
# processed 5 out of a total 4788
# 2785
# 2815
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.759459          -0.036546           0.12816
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.285162                    0.506244              -0.090418
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.130161              -0.694663
# processed 6 out of a total 4788
# 2785
# 2817
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.711883          -0.045139          0.126358
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.357232                    0.484314                -0.0963
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128278              -0.750713
# processed 7 out of a total 4788
# 2785
# 2819
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.702936          -0.046819          0.126747
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.36939                    0.488087               -0.09527
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128572               -0.74098
# processed 8 out of a total 4788
# 2785
# 2821
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.747859          -0.038591          0.127316
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.303109                    0.524604              -0.085686
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129114              -0.663647
# processed 9 out of a total 4788
# 2785
# 2823
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.701272          -0.047134          0.127516
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.369631                    0.493601              -0.093777
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129343              -0.725025
# processed 10 out of a total 4788
# 2785
# 2825
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.666233          -0.053942          0.127541
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.422936                    0.469737              -0.100359
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129326               -0.77602
# processed 11 out of a total 4788
# 2785
# 2827
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.656893          -0.055817          0.127352
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.438288                    0.468698              -0.100654
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129046              -0.779985
# processed 12 out of a total 4788
# 2785
# 2829
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.606436          -0.066433          0.127275
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.521962                    0.429763              -0.112173
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128983              -0.869672
# processed 13 out of a total 4788
# 2785
# 2831
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.591569          -0.069729           0.12702
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.548965                    0.417803              -0.115921
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128737               -0.90045
# processed 14 out of a total 4788
# 2785
# 2833
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.555053          -0.078192          0.127189
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.614774                    0.393349              -0.123932
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12891              -0.961384
# processed 15 out of a total 4788
# 2785
# 2835
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.559609          -0.077107          0.127635
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.604119                    0.399285              -0.121943
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129353              -0.942717
# processed 16 out of a total 4788
# 2785
# 2837
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.584899          -0.071236          0.127546
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.558509                    0.417329              -0.116072
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129266              -0.897931
# processed 17 out of a total 4788
# 2785
# 2839
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.615996          -0.064355          0.127933
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.503035                    0.440266              -0.108966
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12965               -0.84046
# processed 18 out of a total 4788
# 2785
# 2841
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.58946          -0.070204           0.12745
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.550833                    0.422016              -0.114589
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129153              -0.887229
# processed 19 out of a total 4788
# 2785
# 2805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.788733          -0.031523          0.133465
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.236187                    0.450762              -0.105836
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.136206              -0.777031
# processed 20 out of a total 4788
# 2785
# 2807
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.797707           -0.03002          0.130018
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.230891                    0.517907              -0.087393
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.132048              -0.661826
# processed 21 out of a total 4788
# 2785
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.852079          -0.021262          0.127363
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.16694                    0.594165              -0.069148
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129053              -0.535807
# processed 22 out of a total 4788
# 2785
# 2811
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.712036          -0.045111          0.125286
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.360061                    0.514126              -0.088366
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126843              -0.696653
# processed 23 out of a total 4788
# 2785
# 2813
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.679097          -0.051402          0.124682
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.412264                    0.504725              -0.090817
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126066              -0.720393
# processed 24 out of a total 4788
# 2785
# 2815
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.607205          -0.066264          0.125742
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.526987                    0.459033              -0.103421
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127078              -0.813838
# processed 25 out of a total 4788
# 2785
# 2817
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.573687          -0.073806          0.126516
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.583375                    0.432222              -0.111415
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127839              -0.871526
# processed 26 out of a total 4788
# 2785
# 2819
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.562055          -0.076527          0.127379
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.600784                    0.429258              -0.112329
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128615              -0.873369
# processed 27 out of a total 4788
# 2785
# 2821
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.525024           -0.08558           0.12736
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.671951                    0.402343               -0.12093
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12862              -0.940208
# processed 28 out of a total 4788
# 2785
# 2823
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.489115           -0.09499          0.127776
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.743411                    0.374825               -0.13034
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129042              -1.010054
# processed 29 out of a total 4788
# 2785
# 2825
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.519045          -0.087101          0.127471
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.683304                     0.39641              -0.122903
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.1287              -0.954951
# processed 30 out of a total 4788
# 2785
# 2827
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.531934          -0.083843          0.127566
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.657252                    0.411119              -0.118064
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128761              -0.916924
# processed 31 out of a total 4788
# 2785
# 2829
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.572899          -0.073989          0.128718
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.574814                    0.441277              -0.108661
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12993              -0.836305
# processed 32 out of a total 4788
# 2785
# 2831
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.541622          -0.081446          0.127948
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.636554                    0.415769               -0.11657
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129182              -0.902371
# processed 33 out of a total 4788
# 2785
# 2833
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.540729          -0.081665          0.127972
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.63815                    0.417916              -0.115885
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129185              -0.897053
# processed 34 out of a total 4788
# 2785
# 2835
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.552475          -0.078811          0.128703
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.612344                    0.432844              -0.111224
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129888              -0.856303
# processed 35 out of a total 4788
# 2785
# 2837
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.598634          -0.068153          0.128315
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.531135                    0.473012              -0.099436
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129454              -0.768124
# processed 36 out of a total 4788
# 2785
# 2839
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.634384          -0.060448          0.127496
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.474117                    0.506401              -0.090377
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12855              -0.703048
# processed 37 out of a total 4788
# 2785
# 2841
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.647214          -0.057789          0.127454
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.453409                    0.518403              -0.087266
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.1285              -0.679112
# processed 38 out of a total 4788
# 2785
# 2805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903444          -0.013487          0.134027
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.10063                     0.55549              -0.078088
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.136434              -0.572347
# processed 39 out of a total 4788
# 2785
# 2807
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.852079          -0.021262          0.127363
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.16694                    0.594165              -0.069148
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.129053              -0.535807
# processed 40 out of a total 4788
# 2785
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.713384          -0.044859          0.125544
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.357318                     0.52751              -0.084952
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126977              -0.669035
# processed 41 out of a total 4788
# 2785
# 2811
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.56396          -0.076078          0.125251
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.607404                    0.424894              -0.113686
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126575               -0.89817
# processed 42 out of a total 4788
# 2785
# 2813
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.548072          -0.079873          0.126749
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.630168                    0.423592              -0.114094
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127873              -0.892246
# processed 43 out of a total 4788
# 2785
# 2815
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.545955          -0.080388          0.126996
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.632992                    0.424113               -0.11393
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128094              -0.889428
# processed 44 out of a total 4788
# 2785
# 2817
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.561065          -0.076761          0.127026
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.604295                    0.438081              -0.109626
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128162              -0.855375
# processed 45 out of a total 4788
# 2785
# 2819
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.514045          -0.088387          0.126689
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.697668                    0.404107              -0.120349
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127838              -0.941415
# processed 46 out of a total 4788
# 2785
# 2821
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.528414          -0.084725          0.127159
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.666292                    0.412587               -0.11759
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128213              -0.917149
# processed 47 out of a total 4788
# 2785
# 2823
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.539852          -0.081881          0.126831
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.645587                    0.428018              -0.112713
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127856              -0.881564
# processed 48 out of a total 4788
# 2785
# 2825
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.568666          -0.074974          0.127358
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.588689                    0.457039              -0.103999
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128383              -0.810069
# processed 49 out of a total 4788
# 2785
# 2827
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                  0.6317          -0.061011          0.127365
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.479029                    0.511165              -0.089133
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128279              -0.694837
# processed 50 out of a total 4788
# 2785
# 2829
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.672214          -0.052755          0.127664
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.413231                    0.548594              -0.079747
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128539               -0.62041
# processed 51 out of a total 4788
# 2785
# 2831
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.606567          -0.066404          0.127223
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.521951                     0.49502              -0.093396
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128086              -0.729167
# processed 52 out of a total 4788
# 2785
# 2833
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.626983          -0.062007          0.126448
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.490376                    0.515174              -0.088096
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12729              -0.692088
# processed 53 out of a total 4788
# 2785
# 2835
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.614004          -0.064785          0.125937
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.514428                    0.506228              -0.090422
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.12677              -0.713277
# processed 54 out of a total 4788
# 2785
# 2837
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.61012          -0.065628           0.12727
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.515664                    0.506459              -0.090362
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128173              -0.704997
# processed 55 out of a total 4788
# 2785
# 2839
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.57455          -0.073607          0.125229
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.587779                    0.480188              -0.097437
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126103              -0.772676
# processed 56 out of a total 4788
# 2785
# 2841
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.589352          -0.070228          0.125033
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.561676                    0.494237              -0.093606
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.1259              -0.743496
# processed 57 out of a total 4788
# 2785
# 2805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.888743          -0.015666          0.133314
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.117514                    0.568248              -0.075072
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.135492              -0.554069
# processed 58 out of a total 4788
# 2785
# 2807
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.712036          -0.045111          0.125286
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.360061                    0.514126              -0.088366
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126843              -0.696653
# processed 59 out of a total 4788
# 2785
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.56396          -0.076078          0.125251
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.607404                    0.424894              -0.113686
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126575               -0.89817
# processed 60 out of a total 4788
# 2785
# Something went wrong. Error occured at 2022-09-22 16:58:56.232281+00:00. Wait for 60 min.
# 2785
# 2813
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.524559          -0.085698          0.126538
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.67725                    0.411672              -0.117885
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127579              -0.924014
# processed 61 out of a total 4788
# 2785
# 2815
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                  0.5408          -0.081648          0.126625
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.644797                    0.427314              -0.112932
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127655              -0.884665
# processed 62 out of a total 4788
# 2785
# 2817
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.539507          -0.081966          0.126948
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.645663                    0.431397              -0.111668
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127951              -0.872743
# processed 63 out of a total 4788
# 2785
# 2819
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.551842          -0.078963          0.126796
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.622756                    0.442765              -0.108214
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127709              -0.847344
# processed 64 out of a total 4788
# 2785
# 2821
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.604022          -0.066963          0.125666
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.53286                    0.494621              -0.093503
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126533               -0.73896
# processed 65 out of a total 4788
# 2785
# 2823
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.616707          -0.064202          0.127771
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.502477                    0.510188              -0.089387
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128674              -0.694678
# processed 66 out of a total 4788
# 2785
# 2825
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.61608          -0.064337           0.12505
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.51449                    0.511406              -0.089071
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.125864              -0.707671
# processed 67 out of a total 4788
# 2785
# 2827
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.536766          -0.082642          0.125631
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.657818                    0.445568              -0.107376
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126453              -0.849134
# processed 68 out of a total 4788
# 2785
# 2829
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.573482          -0.073854          0.125038
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.590651                    0.477667              -0.098136
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.125836              -0.779869
# processed 69 out of a total 4788
# 2785
# 2831
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.594653          -0.069039          0.125104
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.551851                    0.499531              -0.092191
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.125905               -0.73223
# processed 70 out of a total 4788
# 2785
# 2833
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.571891          -0.074223          0.125451
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.591649                    0.482046              -0.096924
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126261              -0.767643
# processed 71 out of a total 4788
# 2785
# 2835
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.589625          -0.070167          0.125182
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.560516                    0.501239              -0.091738
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.125942              -0.728416
# processed 72 out of a total 4788
# 2785
# 2837
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.574961          -0.073512          0.125485
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.585823                    0.489604              -0.094857
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126237              -0.751423
# processed 73 out of a total 4788
# 2785
# 2839
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.602868          -0.067216           0.12566
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.534906                    0.513369              -0.088562
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126385               -0.70073
# processed 74 out of a total 4788
# 2785
# 2841
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.602847          -0.067221          0.125485
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.535692                      0.5151              -0.088115
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126224               -0.69808
# processed 75 out of a total 4788
# 2785
# 2805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.748734          -0.038435          0.128258
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.299672                    0.490263              -0.094679
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.130341              -0.726391
# processed 76 out of a total 4788
# 2785
# 2807
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.679097          -0.051402          0.124682
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.412264                    0.504725              -0.090817
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126066              -0.720393
# processed 77 out of a total 4788
# 2785
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.548072          -0.079873          0.126749
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.630168                    0.423592              -0.114094
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127873              -0.892246
# processed 78 out of a total 4788
# 2785
# 2811
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.524559          -0.085698          0.126538
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.67725                    0.411672              -0.117885
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127579              -0.924014
# processed 79 out of a total 4788
# 2785
# 2813
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.512623          -0.088755          0.126067
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.704031                    0.407122              -0.119361
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.127083              -0.939236
# processed 80 out of a total 4788
# 2785
# 2815
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.51961          -0.086957          0.127191
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.683668                    0.414782              -0.116885
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.128134              -0.912212
# processed 81 out of a total 4788
# 2785
# 2817
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.62738          -0.061923           0.12562
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.49294                    0.512876              -0.088689
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126473              -0.701249
# processed 82 out of a total 4788
# 2785
# 2819
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.575147          -0.073469          0.125324
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.586231                    0.475807              -0.098654
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# ...
# 0                0.674784          -0.208992          0.244631
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.854313                    0.656672              -0.223448
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.24514              -0.911511
# processed 4756 out of a total 4788
# 697
# 760
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.729953          -0.167238           0.23904
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.699626                     0.71036              -0.181695
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.239446              -0.758813
# processed 4757 out of a total 4788
# 697
# 762
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.79203          -0.123875          0.240638
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.514778                    0.772081              -0.137428
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.2409              -0.570476
# processed 4758 out of a total 4788
# 697
# 764
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.74649          -0.155336          0.239878
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.647563                    0.727689              -0.168889
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.240199              -0.703119
# processed 4759 out of a total 4788
# 697
# 766
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.743717          -0.157314          0.241737
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.650765                    0.727455               -0.16906
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.242205              -0.698003
# processed 4760 out of a total 4788
# 697
# 768
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.750926          -0.152189          0.242102
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.628613                    0.734507              -0.163934
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.242561              -0.675848
# processed 4761 out of a total 4788
# 697
# 770
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.742905          -0.157894          0.242255
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.65177                    0.726661               -0.16964
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.242668              -0.699062
# processed 4762 out of a total 4788
# 697
# 772
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.730232          -0.167036          0.238661
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.699888                    0.714265              -0.178781
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.239044              -0.747901
# processed 4763 out of a total 4788
# 697
# 774
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.769152          -0.139447          0.235818
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.591333                    0.753615              -0.150289
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.236085              -0.636588
# processed 4764 out of a total 4788
# 697
# 739
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.552013          -0.315687          0.233848
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.349965                    0.506155              -0.361766
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.235443              -1.536535
# processed 4765 out of a total 4788
# 697
# 741
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.641107          -0.236192          0.245245
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.963087                     0.60922              -0.263297
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.246269              -1.069147
# processed 4766 out of a total 4788
# 697
# 743
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.665986          -0.215965          0.245153
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.880938                    0.636098               -0.24036
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.245988              -0.977118
# processed 4767 out of a total 4788
# 697
# 745
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.751167          -0.152018          0.248983
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.610558                    0.724814              -0.170992
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.249569               -0.68515
# processed 4768 out of a total 4788
# 697
# 747
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.680933          -0.204172          0.250711
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.814372                    0.655929              -0.224049
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.251503              -0.890842
# processed 4769 out of a total 4788
# 697
# 749
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.72529          -0.170644          0.253939
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.671988                    0.703425              -0.186907
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.254765              -0.733643
# processed 4770 out of a total 4788
# 697
# 751
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.611124          -0.261639           0.25613
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -1.02151                    0.591694              -0.278806
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.25708              -1.084509
# processed 4771 out of a total 4788
# 697
# 753
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.60426           -0.26764          0.256924
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -1.04171                    0.585048              -0.284807
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.257749               -1.10498
# processed 4772 out of a total 4788
# 697
# 755
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.63449          -0.241705          0.254194
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.950866                    0.616409              -0.257064
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.254982              -1.008167
# processed 4773 out of a total 4788
# 697
# 756
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.688614          -0.198212          0.244261
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.811478                    0.671271              -0.211765
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.244741              -0.865262
# processed 4774 out of a total 4788
# 697
# 758
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.76434          -0.142782          0.239842
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.595316                     0.74509              -0.156334
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.240248              -0.650719
# processed 4775 out of a total 4788
# 697
# 760
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.780541          -0.131638          0.240391
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            -0.5476                    0.760882              -0.145191
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.240684              -0.603241
# processed 4776 out of a total 4788
# 697
# 762
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.722077          -0.173002          0.241307
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.716938                    0.705089              -0.185651
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.241735              -0.767996
# processed 4777 out of a total 4788
# 697
# 764
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.745578          -0.155986          0.242227
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.643965                    0.729276              -0.167731
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.242653              -0.691241
# processed 4778 out of a total 4788
# 697
# 766
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.754075          -0.149965          0.242123
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.619375                    0.737588              -0.161711
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.24255              -0.666711
# processed 4779 out of a total 4788
# 697
# 768
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.746168          -0.155566          0.237397
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.655296                    0.731096              -0.166408
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.237775              -0.699854
# processed 4780 out of a total 4788
# 697
# 770
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.713715          -0.179191           0.23863
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.750915                    0.699297              -0.190033
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.239036              -0.794997
# processed 4781 out of a total 4788
# 697
# 772
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.687203          -0.199303          0.236017
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.844442                    0.673321              -0.210145
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.23638              -0.889014
# processed 4782 out of a total 4788
# 697
# 774
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.697621          -0.191309          0.235449
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.812527                    0.683529              -0.202151
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.235764               -0.85743
# processed 4783 out of a total 4788

# %% [markdown]
# ### 2) Extract combinations of max

# %%
macd_opt_a.opt_results[macd_opt_a.opt_results.multiple_macd_strategy == macd_opt_a.opt_results.multiple_macd_strategy.max()]
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 2           15m             16              2                6       0.512629
# 38          15m             16              6                2       0.512629
#
#     ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2           -0.088753          0.204537          -0.433923
# 38          -0.088753          0.204537          -0.433923
#
#     multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 2                 0.903444          -0.013487          0.134027
# 38                0.903444          -0.013487          0.134027
#
#     sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 2            -0.10063                     0.55549              -0.078088
# 38           -0.10063                     0.55549              -0.078088
#
#     ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 2               0.136434              -0.572347         A  2018-01-07-00:00
# 38              0.136434              -0.572347         A  2018-01-07-00:00
#
#              end_opt
# 2   2018-02-05-00:00
# 38  2018-02-05-00:00

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
macd_opt_a_15m = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_a_15m.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='15m')
# Out:
# 2785

# %%
macd_opt_a_15m.execute_backtest(start='2018-01-07-00:00', ema_slow=16, ema_fast=2, ema_signal=6)
# Out:
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903444          -0.013487          0.134027
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.10063                     0.55549              -0.078088
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.136434              -0.572347
# (0.5126287594686112,
#  -0.08875335770051367,
#  0.20453708666144463,
#  -0.43392305595620734,
#  0.903443724633705,
#  -0.013487129458050202,
#  0.13402732217048002,
#  -0.10062970176256188,
#  0.5554896663394265,
#  -0.07808785461118477,
#  0.13643438537440042,
#  -0.5723473184336756)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
macd_opt_a_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_a_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
macd_opt_a.opt_results[macd_opt_a.opt_results.multiple_macd_strategy_net == macd_opt_a.opt_results.multiple_macd_strategy_net.max()]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4744           1h             38             10               28
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4744       0.495027          -0.373577          0.385361          -0.969419
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4744                0.805829          -0.114698          0.239172
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 4744          -0.479562                     0.78821              -0.126443
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 4744              0.239482              -0.527987         A  2018-01-07-00:00
#
#                end_opt
# 4744  2018-02-05-00:00

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %%
macd_opt_a_1h = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_a_1h.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='1h')
# Out:
# 697

# %%
macd_opt_a_1h.execute_backtest(start='2018-01-07-00:00', ema_slow=38, ema_fast=10, ema_signal=28)
# Out:
# 764
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.74709           -0.15491          0.239874
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.645795                    0.728274              -0.168462
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.240249              -0.701198
# (0.4950270708191909,
#  -0.3735766124098908,
#  0.38536121710917515,
#  -0.9694193287334733,
#  0.7470901007777561,
#  -0.154909551330593,
#  0.23987425273502333,
#  -0.6457948260987959,
#  0.72827389218158,
#  -0.1684621510130688,
#  0.24024894543376582,
#  -0.7011982954135884)

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %% [markdown]
# ### 8) Further...
