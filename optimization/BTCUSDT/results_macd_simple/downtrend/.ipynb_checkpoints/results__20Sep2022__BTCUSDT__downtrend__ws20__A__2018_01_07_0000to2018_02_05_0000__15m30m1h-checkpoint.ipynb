# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_opt_a = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
df = pd.read_csv('downtrend_a.csv')

# %%
macd_opt_a.opt_results = df

# %%
# macd_opt_a.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-01-07-00:00', end_opt='2018-02-05-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='A', type_trend='downtrend_A')

# %% [markdown]
# ### 2) Extract combinations of max

# %%
macd_opt_a.opt_results[macd_opt_a.opt_results.multiple_macd_strategy == macd_opt_a.opt_results.multiple_macd_strategy.max()]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 2            15m             16              2                6
# 38           15m             16              6                2
# 331          15m             16              2                6
# 367          15m             16              6                2
#
#      multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2         0.512629          -0.088753          0.204537          -0.433923
# 38        0.512629          -0.088753          0.204537          -0.433923
# 331       0.512629          -0.088753          0.204537          -0.433923
# 367       0.512629          -0.088753          0.204537          -0.433923
#
#      multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 2                  0.903444          -0.013487          0.134027
# 38                 0.903444          -0.013487          0.134027
# 331                0.903444          -0.013487          0.134027
# 367                0.903444          -0.013487          0.134027
#
#      sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 2             -0.10063                     0.55549              -0.078088
# 38            -0.10063                     0.55549              -0.078088
# 331           -0.10063                     0.55549              -0.078088
# 367           -0.10063                     0.55549              -0.078088
#
#      ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 2                0.136434              -0.572347         A  2018-01-07-00:00
# 38               0.136434              -0.572347         A  2018-01-07-00:00
# 331              0.136434              -0.572347         A  2018-01-07-00:00
# 367              0.136434              -0.572347         A  2018-01-07-00:00
#
#               end_opt
# 2    2018-02-05-00:00
# 38   2018-02-05-00:00
# 331  2018-02-05-00:00
# 367  2018-02-05-00:00

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
macd_opt_a_15m = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_a_15m.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='15m')
# Out:
# 2785

# %%
macd_opt_a_15m.execute_backtest(start='2018-01-07-00:00', ema_slow=16, ema_fast=2, ema_signal=6)
# Out:
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903444          -0.013487          0.134027
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.10063                     0.55549              -0.078088
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.136434              -0.572347
# (0.5126287594686112,
#  -0.08875335770051367,
#  0.20453708666144463,
#  -0.43392305595620734,
#  0.903443724633705,
#  -0.013487129458050202,
#  0.13402732217048002,
#  -0.10062970176256188,
#  0.5554896663394265,
#  -0.07808785461118477,
#  0.13643438537440042,
#  -0.5723473184336756)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
macd_opt_a_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_a_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
macd_opt_a.opt_results[macd_opt_a.opt_results.multiple_macd_strategy_net == macd_opt_a.opt_results.multiple_macd_strategy_net.max()]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 5061           1h             38             10               38
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 5061       0.495027          -0.373577          0.385361          -0.969419
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 5061                0.805829          -0.114698          0.239172
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 5061          -0.479562                     0.78821              -0.126443
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# 5061              0.239482              -0.527987         A  2018-01-07-00:00
#
#                end_opt
# 5061  2018-02-05-00:00

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %%
macd_opt_a_1h = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_a_1h.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='1h')
# Out:
# 697

# %%
macd_opt_a_1h.execute_backtest(start='2018-01-07-00:00', ema_slow=38, ema_fast=10, ema_signal=38)
# Out:
# 774
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.805829          -0.114698          0.239172
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.479562                     0.78821              -0.126443
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.239482              -0.527987
# (0.4950270708191909,
#  -0.3735766124098908,
#  0.38536121710917515,
#  -0.9694193287334733,
#  0.8058292842087433,
#  -0.11469785773262814,
#  0.23917207030762636,
#  -0.47956208927364385,
#  0.7882099337093821,
#  -0.12644344412410705,
#  0.2394823220091027,
#  -0.5279865464111416)

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %%
macd_opt_a_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_a_1h.data_init.macd_log_returns_net_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 8) Carry out backtest with optimized strategy macd_peak with same parameters and see results

# %%
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm')
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm

# %%
macd_opt_a_15m_peak = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
macd_opt_a_15m_peak.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='15m')
# Out:
# 2785

# %%
macd_opt_a_15m_peak.execute_backtest(start='2018-01-07-00:00', ema_slow=16, ema_fast=2, ema_signal=6)
# Out:
# 2809
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.098097                0.012434               0.155257
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.080086                         0.884799
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.016263                    0.15569
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.104457
# (0.5126287594686112,
#  -0.08875335770051367,
#  0.20453708666144463,
#  -0.43392305595620734,
#  1.098096745681845,
#  0.012433976796473881,
#  0.15525734562609161,
#  0.08008623840844734,
#  0.8847994292313618,
#  -0.016262801985138388,
#  0.15568954313552902,
#  -0.10445661062144351)

# %% [markdown]
# ### 9) Plot results of macd_peak acum vs macd acum vs hold

# %%
macd_opt_a_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
macd_opt_a_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
macd_opt_a_15m_peak.data_init.macd_peak_log_returns_acum.plot(figsize=(15,10))
plt.legend()

# %% [markdown]
# ### 10) Try the calculated average for the emas in the collect_opt file

# %% [markdown]
# __meanbest_1h_par = 26,14,26__

# %%
macd_opt_meanbest_1h_par = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_meanbest_1h_par.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='1h')
# Out:
# 697

# %%
macd_opt_meanbest_1h_par.execute_backtest(start='2018-01-07-00:00', ema_slow=26, ema_fast=14, ema_signal=26)
# Out:
# 751
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.495027          -0.373577          0.385361          -0.969419
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.649393           -0.22937          0.254769
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.900305                    0.629816              -0.245633
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.2556              -0.961004
# (0.4950270708191909,
#  -0.3735766124098908,
#  0.38536121710917515,
#  -0.9694193287334733,
#  0.6493926198087389,
#  -0.22936971057236058,
#  0.2547690080969584,
#  -0.9003046025326145,
#  0.6298156672439336,
#  -0.2456328301913317,
#  0.2556003234714544,
#  -0.9610035967687816)

# %% [markdown]
# ### results with combination parameters of 1h give better results than those with 15m, compared with the optimized own results

# %% [markdown]
# __meanbest_15m_par = 20,6,36__

# %%
macd_opt_meanbest_15m_par = Macd_long_backtester('BTCUSDT')
# Out:
# class version 1.1 is being used

# %%
macd_opt_meanbest_15m_par.prepare_data(start='2018-01-07-00:00', end='2018-02-05-00:00', interval='15m')
# Out:
# 2785

# %%
macd_opt_meanbest_15m_par.execute_backtest(start='2018-01-07-00:00', ema_slow=20, ema_fast=6, ema_signal=36)
# Out:
# 2843
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.602143          -0.067376          0.125227
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.538032                    0.512751              -0.088722
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.126047              -0.703878
# (0.5126287594686112,
#  -0.08875335770051367,
#  0.20453708666144463,
#  -0.43392305595620734,
#  0.602143190206516,
#  -0.06737623785732201,
#  0.12522729885383663,
#  -0.5380315512192155,
#  0.5127514098862778,
#  -0.08872158235722141,
#  0.12604686971707282,
#  -0.7038777127616699)
