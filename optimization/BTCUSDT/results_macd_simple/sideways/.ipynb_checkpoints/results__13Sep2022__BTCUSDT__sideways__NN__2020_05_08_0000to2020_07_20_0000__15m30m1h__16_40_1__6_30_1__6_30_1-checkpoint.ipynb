# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_td = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_td.prepare_data(start='2018-01-29-20:00', end='2022-09-11-20:00', interval='1d')
# Out:
# 1686

# %%
macd_td.assign_trends(window_size=20, plot=True)

# %% [markdown]
# ## Analysis of 'sideways' trend 'NN'

# %%
macd_td.get_trend_dates(type='sideways', trend_ref='NN', do_plot=True)
# Out:
# date_init: 2020-05-08 00:00:00 1588896000000
# date_end: 2020-07-20 00:00:00 1595203200000
# (1588896000000, 1595203200000)

# %%
macd_opt_nn = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_n.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2020-05-08-00:00', end_opt='2020-07-20-00:00', ema_fast_opt=(4,16,4), ema_slow_opt=(16,40,1), ema_sign_opt=(6, 30, 4), int_for_max='15m')
# Out:
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# 3498
# ...

# %%
macd_opt_n.opt_results
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0            15m             16              4                6
# 1            15m             16              4               10
# 2            15m             16              4               14
# 3            15m             16              4               18
# 4            15m             16              4               22
# 5            15m             16              4               26
# 6            15m             16              8                6
# 7            15m             16              8               10
# 8            15m             16              8               14
# 9            15m             16              8               18
# 10           15m             16              8               22
# 11           15m             16              8               26
# 12           15m             16             12                6
# 13           15m             16             12               10
# ...

# %%
macd_opt_n.multiple_macd_strategy_max
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 87          15m             32             12               18       0.957502
#
#     multiple_macd_strategy  multiple_macd_strategy_net
# 87                1.023624                    0.739109

# %%
macd_opt_nn1 = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_opt_nn1.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2020-05-08-00:00', end_opt='2020-07-20-00:00', ema_fast_opt=(4,16,1), ema_slow_opt=(16,40,1), ema_sign_opt=(6, 30, 1), int_for_max='1h')
# Out:
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# 6995
# ...

# %%
df_imported = pd.read_csv('sideways.csv')

# %%
df_complete = pd.concat([df_imported, macd_opt_n.opt_results], axis = 0)

# %%
df_complete.to_csv('sideways.csv', mode='w', index=False, header=True)
