# %%
import pandas as pd
import sys
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = [file for file in os.listdir() if os.path.splitext(file)[1] == '.csv']

# %%
files
# Out:
# ['sideways_ee.csv',
#  'sideways_mm.csv',
#  'sideways_nn.csv',
#  'sideways_oo.csv',
#  'sideways_gg.csv']

# %%
results = []
for name in files:
    results.append(utils.find_max(filename=name, type_max='max', type_trend='sideways'))
# Out:
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3848           1h             24             14               28
# 4112           1h             28             14               24
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3848       1.048038           0.011042          0.103187           0.107008
# 4112       1.048038           0.011042          0.103187           0.107008
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 3848                1.190512           0.041038          0.075868
# 4112                1.190512           0.041038          0.075868
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 3848           0.540911                    1.132261               0.029232
# 4112           0.540911                    1.132261               0.029232
#
#       ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# ...

# %%
len(results)
# Out:
# 5

# %%
results_df = pd.DataFrame(data=results[0])

# %%
results_df = results_df.append(results[1])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27765/2045268720.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[1])

# %%
results_df = results_df.append(results[2])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27765/2906862804.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[2])

# %%
results_df = results_df.append(results[3])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27765/669286345.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[3])

# %%
results_df = results_df.append(results[4])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_27765/996747469.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(results[4])

# %%
results_df
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3848           1h             24             14               28
# 4112           1h             28             14               24
# 3804           1h             24             10               14
# 3840           1h             24             14               10
# 2386          30m             26             14               28
# 2518          30m             28             14               26
# 4713           1h             38              8               10
# 4731           1h             38             10                8
# 2743          30m             32             10               18
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3848       1.048038           0.011042          0.103187           0.107008
# 4112       1.048038           0.011042          0.103187           0.107008
# 3804       0.700988          -0.085254          0.272273          -0.313120
# ...

# %%
results_df.describe()
# Out:
#        macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# count       9.000000        9.00000         9.000000       9.000000
# mean       29.111111       12.00000        18.444444       0.923215
# std         5.666667        2.44949         8.232726       0.171642
# min        24.000000        8.00000         8.000000       0.700988
# 25%        24.000000       10.00000        10.000000       0.869411
# 50%        28.000000       14.00000        18.000000       0.916410
# 75%        32.000000       14.00000        26.000000       1.048038
# max        38.000000       14.00000        28.000000       1.239242
#
#        ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count           9.000000          9.000000           9.000000
# mean           -0.026411          0.130202          -0.155926
# std             0.039963          0.081020           0.262907
# min            -0.085254          0.077706          -0.491230
# ...

# %%
results_df.reset_index(inplace=True)

# %%
results_df.rename(columns={'index': 'index_opt'}, inplace=True)

# %%
results_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       3848           1h             24             14               28
# 1       4112           1h             28             14               24
# 2       3804           1h             24             10               14
# 3       3840           1h             24             14               10
# 4       2386          30m             26             14               28
# 5       2518          30m             28             14               26
# 6       4713           1h             38              8               10
# 7       4731           1h             38             10                8
# 8       2743          30m             32             10               18
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.048038           0.011042          0.103187           0.107008
# 1       1.048038           0.011042          0.103187           0.107008
# ...

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index_opt                   9 non-null      int64
#  1   interval_opt                9 non-null      object
#  2   macd_slow_opt               9 non-null      int64
#  3   macd_fast_opt               9 non-null      int64
#  4   macd_signal_opt             9 non-null      int64
#  5   multiple_hold               9 non-null      float64
#  6   ann_log_mean_hold           9 non-null      float64
#  7   ann_log_std_hold            9 non-null      float64
#  8   sharpe_ratio_hold           9 non-null      float64
#  9   multiple_macd_strategy      9 non-null      float64
#  10  ann_log_mean_macd           9 non-null      float64
#  11  ann_log_std_macd            9 non-null      float64
#  12  sharpe_ratio_macd           9 non-null      float64
# ...

# %%
plt.bar(x=results_df.index, height=results_df.multiple_macd_strategy)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# - Separate into 2 dataframes 1 for 30m and another for 1h

# %%
results_df_30m = results_df[results_df.interval_opt == '30m']
results_df_30m
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4       2386          30m             26             14               28
# 5       2518          30m             28             14               26
# 8       2743          30m             32             10               18
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4       0.916410          -0.009158          0.082497          -0.111013
# 5       0.916410          -0.009158          0.082497          -0.111013
# 8       1.239242           0.016580          0.077706           0.213374
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4                1.170375           0.016506          0.048791
# 5                1.170375           0.016506          0.048791
# 8                1.369850           0.024326          0.056645
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# ...

# %%
results_df_1h = results_df[results_df.interval_opt == '1h']
results_df_1h
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       3848           1h             24             14               28
# 1       4112           1h             28             14               24
# 2       3804           1h             24             10               14
# 3       3840           1h             24             14               10
# 6       4713           1h             38              8               10
# 7       4731           1h             38             10                8
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.048038           0.011042          0.103187           0.107008
# 1       1.048038           0.011042          0.103187           0.107008
# 2       0.700988          -0.085254          0.272273          -0.313120
# 3       0.700988          -0.085254          0.272273          -0.313120
# 6       0.869411          -0.043768          0.089100          -0.491230
# ...

# %% [markdown]
# - Since there are duplicated results, the ones that have the combination of parameters in the shape HIGH - LOW - HIGH are the ones chosen (just for shape preference taking into account other combinations observed that have same shape in other trends)

# %%
results_df_1h_filt = results_df_1h.drop([0,3,7], axis=0, errors='ignore')
results_df_1h_filt
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1       4112           1h             28             14               24
# 2       3804           1h             24             10               14
# 6       4713           1h             38              8               10
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1       1.048038           0.011042          0.103187           0.107008
# 2       0.700988          -0.085254          0.272273          -0.313120
# 6       0.869411          -0.043768          0.089100          -0.491230
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 1                1.190512           0.041038          0.075868
# 2                1.384670           0.078102          0.161237
# 6                1.007487           0.002333          0.051501
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# ...

# %%
results_df_1h_filt.index
# Out:
# Int64Index([1, 2, 6], dtype='int64')

# %%
results_df_1h_filt.multiple_macd_strategy
# Out:
# 1    1.190512
# 2    1.384670
# 6    1.007487
# Name: multiple_macd_strategy, dtype: float64

# %%
plt.bar(x=results_df_1h_filt.index, height=results_df_1h_filt.multiple_macd_strategy)
# Out:
# <BarContainer object of 3 artists>

# %%
results_df_1h.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     6.000000       6.000000       6.000000         6.000000
# mean   4174.666667      29.333333      11.666667        15.666667
# std     438.028157       6.889606       2.658320         8.334667
# min    3804.000000      24.000000       8.000000         8.000000
# 25%    3842.000000      24.000000      10.000000        10.000000
# 50%    3980.000000      26.000000      12.000000        12.000000
# 75%    4562.750000      35.500000      14.000000        21.500000
# max    4731.000000      38.000000      14.000000        28.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       6.000000           6.000000          6.000000           6.000000
# mean        0.872812          -0.039327          0.154853          -0.232448
# std         0.155228           0.043202          0.091171           0.274741
# ...

# %% [markdown]
# # 29,12,16 for 1h interval as parameters average

# %%
results_df_30m_filt = results_df_30m.drop([4], axis=0, errors='ignore')
results_df_30m_filt
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 5       2518          30m             28             14               26
# 8       2743          30m             32             10               18
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 5       0.916410          -0.009158          0.082497          -0.111013
# 8       1.239242           0.016580          0.077706           0.213374
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 5                1.170375           0.016506          0.048791
# 8                1.369850           0.024326          0.056645
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 5           0.338292                    1.035498               0.003660
# 8           0.429441                    1.065951               0.004937
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net trend_ref         start_opt  \
# ...

# %%
plt.bar(x=results_df_30m_filt.index, height=results_df_30m_filt.multiple_macd_strategy)
# Out:
# <BarContainer object of 2 artists>

# %%
results_df_30m_filt.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     2.000000       2.000000       2.000000         2.000000
# mean   2630.500000      30.000000      12.000000        22.000000
# std     159.099026       2.828427       2.828427         5.656854
# min    2518.000000      28.000000      10.000000        18.000000
# 25%    2574.250000      29.000000      11.000000        20.000000
# 50%    2630.500000      30.000000      12.000000        22.000000
# 75%    2686.750000      31.000000      13.000000        24.000000
# max    2743.000000      32.000000      14.000000        26.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       2.000000           2.000000          2.000000           2.000000
# mean        1.077826           0.003711          0.080101           0.051180
# std         0.228277           0.018200          0.003388           0.229376
# ...

# %% [markdown]
# # 30,12,22 for 30m interval as parameters average
