# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/macd_ls_backtester_sma')
from macd_ls_backtester_sma import Macd_ls_backtester_sma
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
#macd_ls_sma_15m = Macd_ls_backtester_sma('BTCUSDT','15m')

# %%
#macd_ls_sma_15m.execute_opt(start_opt='2022-04-15-00:00', end_opt='2022-06-01-00:00', ema_fast_opt=(2,18,4), ema_slow_opt=(15,40,5), ema_sign_opt=(2, 30, 6), sma_slow=(60,200,40), sma_fast=(10,60,20))

# %%
#macd_ls_sma_15m.opt_max

# %%
#macd_ls_sma_15m.opt_results.iloc[240]

# %%
macd_ls_sma_15m_imported = Macd_ls_backtester_sma('BTCUSDT','15m')
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_15m_imported.opt_results = pd.read_csv('macd_ls_sma_2022-11-15-00:13_15m_BTCUSDT.csv')

# %%
macd_ls_sma_15m_imported.opt_results.iloc[240]
# Out:
# macd_slow_opt                               20
# macd_fast_opt                                2
# macd_signal_opt                              2
# sma_slow                                    60
# sma_fast                                    10
# multiple_hold                         0.781834
# ann_log_mean_hold                      -1.9113
# ann_log_std_hold                      0.702926
# sharpe_ratio_hold                    -2.719062
# multiple_macd_strategy                1.383317
# ann_log_mean_macd                     2.519931
# ann_log_std_macd                       0.70221
# sharpe_ratio_macd                     3.588573
# multiple_macd_strategy_net            1.286866
# ann_log_mean_macd_net                 1.958652
# ann_log_std_macd_net                  0.704747
# sharpe_ratio_macd_net                 2.779225
# success_trades_net                          26
# failure_trades_net                          59
# success_trades_net_pct                    30.6
# failure_trades_net_pct                    69.4
# total_trades                                85
# start_opt                     2022-04-15-00:00
# end_opt                       2022-06-01-00:00
# Name: 240, dtype: object

# %%
macd_ls_sma_15m_imported.prepare_data(start='2022-04-15-00:00', end='2022-06-01-00:00')
# Out:
# 4513

# %%
macd_ls_sma_15m_imported.execute_backtest(start='2022-04-15-00:00',ema_slow=20, ema_fast=2, ema_signal=2, sma_slow=60, sma_fast=10)
# Out:
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.383317           2.519931           0.70221
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           3.588573                    1.286866               1.958652
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704747               2.779225                  26
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  59                    30.6                    69.4
#
#    total_trades
# 0            85
# (0.7818342109793787,
#  -1.9112997250375028,
#  0.7029262446307408,
#  -2.7190615511041862,
#  1.3833171050867143,
#  2.5199313765685294,
#  0.7022098684689483,
#  3.58857300320034,
#  1.2868662135112576,
#  1.9586519024847147,
#  0.7047474506008293,
#  2.7792252399279693,
#  26,
#  59,
#  30.6,
#  69.4,
#  85)

# %%
macd_ls_sma_15m_imported.plot_backtest_results(start_plot='2022-05-08-00:00', end_plot='2022-05-15-00:00', width_bars=0.003)

# %% [markdown]
# __It seems that due to the more oscillatory behaviour of the price, there have been wrong signals and the performance has been worse than buy and hold. This seems to indicate that the strategy performs better in trending markets, rather than sideways oscillatory markets__

# %%
macd_ls_sma_15m_imported.plot_backtest_results(start_plot='2022-05-04-00:00', end_plot='2022-05-15-00:00', width_bars=0.003)
