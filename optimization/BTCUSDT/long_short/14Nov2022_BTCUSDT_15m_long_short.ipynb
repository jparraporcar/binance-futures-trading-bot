# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/macd_ls_backtester_sma')
from macd_ls_backtester_sma import Macd_ls_backtester_sma
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
macd_ls_sma_15m = Macd_ls_backtester_sma('BTCUSDT','15m')
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_15m.execute_opt(start_opt='2022-04-15-00:00', end_opt='2022-06-01-00:00', ema_fast_opt=(2,18,4), ema_slow_opt=(15,40,5), ema_sign_opt=(2, 30, 6), sma_slow=(60,200,40), sma_fast=(10,60,20))
# Out:
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.364313             2.4125          0.702221
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            3.43553                     1.26703               1.838014
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70486                2.60763                  31
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  56                    35.6                    64.4
#
#    total_trades
# 0            87
# processed 1 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.129824           0.947927          0.702321
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.349706                    1.049262               0.373441
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.705119               0.529613                  31
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  56                    35.6                    64.4
#
#    total_trades
# 0            87
# processed 2 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.289129           1.972296           0.70226
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.808498                    1.180027               1.285554
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704774               1.824065                  36
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  68                    34.6                    65.4
#
#    total_trades
# 0           104
# processed 3 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.169768           1.217747          0.702309
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            1.73392                    1.104051               0.768723
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704484               1.091186                  25
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  43                    36.8                    63.2
#
#    total_trades
# 0            68
# processed 4 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.273336            1.87657          0.702267
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.672159                    1.222413               1.559612
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704074               2.215126                  19
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    39.6                    60.4
#
#    total_trades
# 0            48
# processed 5 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.169696           1.217265          0.702309
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.733233                    1.128661               0.939927
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703643               1.335801                  14
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    33.3                    66.7
#
#    total_trades
# 0            42
# processed 6 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.954258          -0.363611          0.702336
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.517717                    0.917654              -0.667362
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704173              -0.947725                  21
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  25                    45.7                    54.3
#
#    total_trades
# 0            46
# processed 7 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.018569           0.142883          0.702015
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.203533                    0.989544              -0.081629
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702993              -0.116116                  12
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  22                    35.3                    64.7
#
#    total_trades
# 0            34
# processed 8 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.96209           -0.30013          0.702334
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.427332                     0.93547              -0.518038
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703354              -0.736526                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    39.4                    60.6
#
#    total_trades
# 0            33
# processed 9 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.863957          -1.135633          0.702313
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.616991                    0.835067              -1.399765
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703887               -1.98862                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  27                    32.5                    67.5
#
#    total_trades
# 0            40
# processed 10 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.731903          -2.423812          0.702217
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.451658                    0.710442              -2.654927
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703534              -3.773699                  15
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    42.9                    57.1
#
#    total_trades
# 0            35
# processed 11 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.814096          -1.597277          0.702284
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.274403                    0.791571              -1.815186
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703319              -2.580884                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    39.4                    60.6
#
#    total_trades
# 0            33
# processed 12 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.208872           1.473108          0.702295
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.097564                    1.118862               0.872209
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704185               1.238608                  26
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  65                    28.6                    71.4
#
#    total_trades
# 0            91
# processed 13 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.030631           0.234311          0.702338
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.333616                    0.955516              -0.353381
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70461              -0.501527                  33
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  56                    37.1                    62.9
#
#    total_trades
# 0            89
# processed 14 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.243795           1.694279          0.702281
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.412539                    1.142409               1.033951
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704139                1.46839                  37
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  63                    37.0                    63.0
#
#    total_trades
# 0           100
# processed 15 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.134544           0.980302          0.702319
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.395807                    1.078114               0.584105
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703781               0.829952                  19
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  41                    31.7                    68.3
#
#    total_trades
# 0            60
# processed 16 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.326902           2.196576          0.702241
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           3.127953                    1.276004               1.892825
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703247                2.69155                  16
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  30                    34.8                    65.2
#
#    total_trades
# 0            46
# processed 17 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.106902           0.788754          0.702326
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.123059                     1.06807               0.511416
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703565               0.726892                  16
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  26                    38.1                    61.9
#
#    total_trades
# 0            42
# processed 18 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.918343          -0.661536           0.70233
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.941916                    0.883117              -0.965287
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703799              -1.371538                  21
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  25                    45.7                    54.3
#
#    total_trades
# 0            46
# processed 19 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.973808          -0.206117          0.702999
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.293196                    0.945254              -0.437232
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704008              -0.621061                  12
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  23                    34.3                    65.7
#
#    total_trades
# 0            35
# processed 20 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.904288          -0.781315          0.702988
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -1.11142                    0.879267              -0.999223
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704076              -1.419198                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  23                    30.3                    69.7
#
#    total_trades
# 0            33
# processed 21 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.84626          -1.296364          0.702966
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.844135                    0.818657              -1.553892
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704236              -2.206492                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  26                    33.3                    66.7
#
#    total_trades
# 0            39
# processed 22 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.749775          -2.236455          0.702899
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.181761                    0.729029              -2.454364
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70385              -3.487053                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    39.4                    60.6
#
#    total_trades
# 0            33
# processed 23 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.774043          -1.989082           0.70292
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.829742                    0.752625               -2.20699
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70385              -3.135597                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  22                    33.3                    66.7
#
#    total_trades
# 0            33
# processed 24 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.222607           1.560846          0.701966
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.223536                    1.127732               0.933534
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703794                1.32643                  29
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  66                    30.5                    69.5
#
#    total_trades
# 0            95
# processed 25 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.038988           0.297028          0.702014
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.423109                    0.964903              -0.277458
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704069              -0.394077                  37
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  50                    42.5                    57.5
#
#    total_trades
# 0            87
# processed 26 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.260798           1.799722           0.70195
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.563891                    1.161971               1.165806
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703839               1.656354                  34
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  62                    35.4                    64.6
#
#    total_trades
# 0            96
# processed 27 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.110808           0.816104          0.702002
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.162539                    1.051975               0.393494
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703206               0.559571                  24
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  40                    37.5                    62.5
#
#    total_trades
# 0            64
# processed 28 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.282114           1.929923           0.70194
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.749414                    1.235033               1.639378
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702944               2.332161                  16
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    36.4                    63.6
#
#    total_trades
# 0            44
# processed 29 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.075706           0.566741          0.702009
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.807314                    1.037969               0.289403
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703186                0.41156                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    31.0                    69.0
#
#    total_trades
# 0            42
# processed 30 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.942166          -0.462647          0.702011
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.659032                    0.906026              -0.766399
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703266              -1.089771                  25
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                    54.3                    45.7
#
#    total_trades
# 0            46
# processed 31 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.969008          -0.244491          0.702335
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.348111                    0.941395              -0.469002
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703318              -0.666843                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  23                    32.4                    67.6
#
#    total_trades
# 0            34
# processed 32 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.948558          -0.410135          0.702261
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.584021                    0.922312              -0.628044
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703202               -0.89312                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    27.3                    72.7
#
#    total_trades
# 0            33
# processed 33 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.857468          -1.194181           0.70231
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.700361                    0.828795              -1.458312
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703431              -2.073142                  12
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    30.0                    70.0
#
#    total_trades
# 0            40
# processed 34 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.796442          -1.767536          0.702201
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.517137                    0.774405              -1.985444
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703087              -2.823896                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  22                    33.3                    66.7
#
#    total_trades
# 0            33
# processed 35 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.764056          -2.089925          0.702175
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.976357                    0.742915              -2.307834
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703121              -3.282269                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    27.3                    72.7
#
#    total_trades
# 0            33
# processed 36 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.254589           1.761381          0.701952
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            2.50926                    1.155266               1.120862
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703648               1.592931                  30
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  67                    30.9                    69.1
#
#    total_trades
# 0            97
# processed 37 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.020015           0.153899          0.702015
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.219225                    0.947283              -0.420587
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704136              -0.597309                  35
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  52                    40.2                    59.8
#
#    total_trades
# 0            87
# processed 38 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.193673           1.374849          0.701977
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.958538                    1.100107               0.740933
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703797               1.052765                  30
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  66                    31.2                    68.8
#
#    total_trades
# 0            96
# processed 39 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.089456           0.665374          0.702006
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.947817                    1.030001               0.229557
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703291               0.326404                  24
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  42                    36.4                    63.6
#
#    total_trades
# 0            66
# processed 40 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.22086           1.549738          0.701967
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            2.20771                    1.176028               1.259194
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703127               1.790848                  14
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  30                    31.8                    68.2
#
#    total_trades
# 0            44
# processed 41 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.044348           0.336989          0.702013
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.480032                    1.007711               0.059651
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703287               0.084817                  14
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    33.3                    66.7
#
#    total_trades
# 0            42
# processed 42 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.954308          -0.363201          0.702013
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.517371                    0.916144              -0.680159
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703187              -0.967252                  24
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    50.0                    50.0
#
#    total_trades
# 0            48
# processed 43 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.980308          -0.154451          0.702336
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.21991                    0.952374              -0.378963
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703136              -0.538961                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  23                    32.4                    67.6
#
#    total_trades
# 0            34
# processed 44 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.943969            -0.4478           0.70225
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.637665                     0.91785              -0.665709
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703158              -0.946741                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    27.3                    72.7
#
#    total_trades
# 0            33
# processed 45 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.859326          -1.177372          0.702311
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.676426                    0.830591              -1.441504
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703391              -2.049364                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    27.5                    72.5
#
#    total_trades
# 0            40
# processed 46 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.831507          -1.432939          0.701974
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.041301                    0.809187              -1.644244
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70271              -2.339863                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                    34.4                    65.6
#
#    total_trades
# 0            32
# processed 47 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.761541           -2.11553          0.702163
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.012874                     0.74047              -2.333438
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703037              -3.319082                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  22                    33.3                    66.7
#
#    total_trades
# 0            33
# processed 48 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.274038            1.88085          0.701943
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.679489                    1.171182               1.227124
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0                0.7035               1.744313                  31
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  68                    31.3                    68.7
#
#    total_trades
# 0            99
# processed 49 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.976843          -0.181951          0.702015
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.259184                    0.907189              -0.756437
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.704122              -1.074297                  34
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  53                    39.1                    60.9
#
#    total_trades
# 0            87
# processed 50 out of a total 1200
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.168416           1.208763          0.701986
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.721919                     1.07683               0.574847
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703949               0.816603                  30
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  66                    31.2                    68.8
#
#    total_trades
# 0            96
# processed 51 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.114627           0.842759          0.702001
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.200509                    1.053798               0.406942
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703104               0.578778                  23
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  43                    34.8                    65.2
#
#    total_trades
# 0            66
# processed 52 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.221364           1.552942          0.701966
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.212274                    1.176513               1.262397
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703035                1.79564                  15
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    34.1                    65.9
#
#    total_trades
# 0            44
# processed 53 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.06036           0.455153          0.702011
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.648356                    1.023161               0.177815
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703298                0.25283                  17
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  25                    40.5                    59.5
#
#    total_trades
# 0            42
# processed 54 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.954186          -0.364197          0.702013
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.51879                    0.916026              -0.681155
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703184              -0.968673                  24
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    50.0                    50.0
#
#    total_trades
# 0            48
# processed 55 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.987954           -0.09412          0.702336
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.13401                    0.959801              -0.318632
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703047              -0.453215                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    29.4                    70.6
#
#    total_trades
# 0            34
# processed 56 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.922561          -0.625952           0.70224
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.891365                    0.897034              -0.843861
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70321              -1.200012                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  25                    24.2                    75.8
#
#    total_trades
# 0            33
# processed 57 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.862267          -1.150841          0.702312
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.638647                    0.832017              -1.428179
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703356              -2.030522                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                    26.2                    73.8
#
#    total_trades
# 0            42
# processed 58 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
# ...
# 0              0.701985               0.073649                  15
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    34.9                    65.1
#
#    total_trades
# 0            43
# processed 1181 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.963213          -0.291074          0.700821
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.415332                    0.932588              -0.541999
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.701451              -0.772682                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  25                    34.2                    65.8
#
#    total_trades
# 0            38
# processed 1182 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.950752          -0.392197           0.70082
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.559626                     0.90963              -0.735568
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0                 0.702              -1.047819                  23
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    44.2                    55.8
#
#    total_trades
# 0            52
# processed 1183 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.996728          -0.025448          0.702336
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.036233                    0.969974              -0.236753
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702729              -0.336905                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                    34.4                    65.6
#
#    total_trades
# 0            32
# processed 1184 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.885794          -0.941786          0.702198
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.341198                    0.862017              -1.153091
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702814              -1.640678                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    25.0                    75.0
#
#    total_trades
# 0            32
# processed 1185 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.81585          -1.580569          0.702288
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.250598                    0.783222              -1.897526
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703305              -2.698012                  14
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  34                    29.2                    70.8
#
#    total_trades
# 0            48
# processed 1186 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.757555          -2.156288           0.70216
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.070937                    0.735968                -2.3808
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702858              -3.387315                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                    38.2                    61.8
#
#    total_trades
# 0            34
# processed 1187 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.735441          -2.386364          0.701876
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.399979                    0.718138              -2.571256
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702589              -3.659689                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    28.6                    71.4
#
#    total_trades
# 0            28
# processed 1188 out of a total 1200
# 4513
# 2022-04-14 08:15:00
# 4576
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.381447           2.509423           0.70133
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           3.578091                    1.279674               1.915128
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702629               2.725658                  29
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  61                    32.2                    67.8
#
#    total_trades
# 0            90
# processed 1189 out of a total 1200
# 4513
# 2022-04-14 08:15:00
# 4576
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.998413          -0.012331          0.701444
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -0.01758                    0.932757              -0.540594
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702755               -0.76925                  32
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                    40.0                    60.0
#
#    total_trades
# 0            80
# processed 1190 out of a total 1200
# 4513
# 2022-04-14 08:15:00
# 4576
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.074055           0.554811          0.701398
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.791008                    1.006843               0.052961
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702174               0.075425                  26
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  50                    34.2                    65.8
#
#    total_trades
# 0            76
# processed 1191 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.07231            0.54218          0.700884
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.773566                    1.011208               0.086554
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.701601               0.123366                  28
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  41                    40.6                    59.4
#
#    total_trades
# 0            69
# processed 1192 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.087288           0.649904          0.700824
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.927343                    1.048252               0.365963
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.701966                0.52134                  15
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    34.9                    65.1
#
#    total_trades
# 0            43
# processed 1193 out of a total 1200
# 4513
# 2022-04-13 23:00:00
# 4613
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.988674          -0.088459          0.700194
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.126334                    0.958054               -0.33278
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.700709              -0.474919                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  24                    35.1                    64.9
#
#    total_trades
# 0            37
# processed 1194 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.94928          -0.404232          0.700808
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.576809                    0.908222              -0.747603
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.701941              -1.065051                  23
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    44.2                    55.8
#
#    total_trades
# 0            52
# processed 1195 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.998608          -0.010817          0.702336
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.015401                    0.971803              -0.222122
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.70269              -0.316103                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    40.6                    59.4
#
#    total_trades
# 0            32
# processed 1196 out of a total 1200
# 4513
# 2022-04-13 13:00:00
# 4653
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.888654          -0.916753          0.702199
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.305546                      0.8648              -1.128058
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702753              -1.605198                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  25                    21.9                    78.1
#
#    total_trades
# 0            32
# processed 1197 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.810364          -1.632965          0.702285
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.325218                    0.777956              -1.949923
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.703334              -2.772399                  14
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  34                    29.2                    70.8
#
#    total_trades
# 0            48
# processed 1198 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.753503          -2.197943          0.702156
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.130277                    0.732031              -2.422454
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702894              -3.446401                  13
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                    38.2                    61.8
#
#    total_trades
# 0            34
# processed 1199 out of a total 1200
# 4513
# 2022-04-13 03:00:00
# 4693
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.74313          -2.305593          0.701884
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.284864                    0.725646              -2.490485
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.702503              -3.545159                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    35.7                    64.3
#
#    total_trades
# 0            28
# processed 1200 out of a total 1200

# %%
macd_ls_sma_15m.opt_max
# Out:
# 240    1.383317
# Name: multiple_macd_strategy, dtype: float64

# %%
macd_ls_sma_15m.opt_results.iloc[240]
# Out:
# macd_slow_opt                               20
# macd_fast_opt                                2
# macd_signal_opt                              2
# sma_slow                                    60
# sma_fast                                    10
# multiple_hold                         0.781834
# ann_log_mean_hold                      -1.9113
# ann_log_std_hold                      0.702926
# sharpe_ratio_hold                    -2.719062
# multiple_macd_strategy                1.383317
# ann_log_mean_macd                     2.519931
# ann_log_std_macd                       0.70221
# sharpe_ratio_macd                     3.588573
# multiple_macd_strategy_net            1.286866
# ann_log_mean_macd_net                 1.958652
# ann_log_std_macd_net                  0.704747
# sharpe_ratio_macd_net                 2.779225
# success_trades_net                          26
# failure_trades_net                          59
# success_trades_net_pct                    30.6
# failure_trades_net_pct                    69.4
# total_trades                                85
# start_opt                     2022-04-15-00:00
# end_opt                       2022-06-01-00:00
# Name: 240, dtype: object
