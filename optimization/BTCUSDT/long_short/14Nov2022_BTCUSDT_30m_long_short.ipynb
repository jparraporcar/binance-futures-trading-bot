# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/macd_ls_backtester_sma')
from macd_ls_backtester_sma import Macd_ls_backtester_sma
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
#macd_ls_sma_30m = Macd_ls_backtester_sma('BTCUSDT','30m')
# Out:
# class version 0.0 is being used

# %%
#macd_ls_sma_30m.execute_opt(start_opt='2022-03-01-00:00', end_opt='2022-06-01-00:00', ema_fast_opt=(2,18,4), ema_slow_opt=(15,40,5), ema_sign_opt=(2, 30, 6), sma_slow=(60,200,40), sma_fast=(10,60,20))
# Out:
# 4417
# 2022-02-27 18:00:00
# 4477
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.782538          -0.972854          0.653239          -1.489279
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.211201           0.760201          0.652267
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.165475                    1.115312                0.43298
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.654626               0.661415                  46
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  51                    47.4                    52.6
#
#    total_trades
# 0            97
# processed 1 out of a total 1200
# 4417
# 2022-02-27 18:00:00
# 4477
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# ...

# %%
#macd_ls_sma_30m.opt_max
# Out:
# 692    1.286456
# Name: multiple_macd_strategy, dtype: float64

# %%
#macd_ls_sma_30m.opt_results.iloc[692]
# Out:
# macd_slow_opt                               25
# macd_fast_opt                               14
# macd_signal_opt                             14
# sma_slow                                   140
# sma_fast                                    50
# multiple_hold                         0.782538
# ann_log_mean_hold                    -0.972854
# ann_log_std_hold                      0.653239
# sharpe_ratio_hold                    -1.489279
# multiple_macd_strategy                1.286456
# ann_log_mean_macd                     0.999349
# ann_log_std_macd                      0.651496
# sharpe_ratio_macd                     1.533931
# multiple_macd_strategy_net            1.246613
# ann_log_mean_macd_net                 0.874533
# ann_log_std_macd_net                  0.651902
# sharpe_ratio_macd_net                 1.341511
# success_trades_net                          10
# failure_trades_net                          27
# success_trades_net_pct                    27.0
# ...

# %%
macd_ls_sma_30m_imported = Macd_ls_backtester_sma('BTCUSDT','30m')
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_30m_imported.opt_results = pd.read_csv('macd_sma_2022-11-15-00:13_30m_BTCUSDT.csv')

# %%
macd_ls_sma_30m_imported.opt_results.iloc[692]
# Out:
# macd_slow_opt                               25
# macd_fast_opt                               14
# macd_signal_opt                             14
# sma_slow                                   140
# sma_fast                                    50
# multiple_hold                         0.782538
# ann_log_mean_hold                    -0.972854
# ann_log_std_hold                      0.653239
# sharpe_ratio_hold                    -1.489279
# multiple_macd_strategy                1.286456
# ann_log_mean_macd                     0.999349
# ann_log_std_macd                      0.651496
# sharpe_ratio_macd                     1.533931
# multiple_macd_strategy_net            1.246613
# ann_log_mean_macd_net                 0.874533
# ann_log_std_macd_net                  0.651902
# sharpe_ratio_macd_net                 1.341511
# success_trades_net                          10
# failure_trades_net                          27
# success_trades_net_pct                    27.0
# ...

# %%
macd_ls_sma_30m_imported.prepare_data(start='2022-03-01-00:00', end='2022-06-01-00:00')
# Out:
# 4417

# %%
macd_ls_sma_30m_imported.execute_backtest(start='2022-03-01-00:00',ema_slow=25, ema_fast=14, ema_signal=14, sma_slow=140, sma_fast=50)
# Out:
# 2022-02-26 02:00:00
# 4557
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.782538          -0.972854          0.653239          -1.489279
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.286456           0.999349          0.651496
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.533931                    1.246613               0.874533
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.651902               1.341511                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  27                    27.0                    73.0
#
#    total_trades
# 0            37
# (0.7825381231678782,
#  -0.9728544879206626,
#  0.6532385984305196,
#  -1.4892789407393512,
#  1.2864555402538485,
#  0.9993493436150245,
#  0.6514956445538682,
#  1.5339309663372498,
# ...

# %%
macd_ls_sma_30m_imported.plot_backtest_results(start_plot='2022-03-01-00:00', end_plot='2022-06-01-00:00', width_bars=0.003)
