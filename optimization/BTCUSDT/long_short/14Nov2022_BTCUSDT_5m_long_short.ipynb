# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/long_short/macd_ls_backtester_sma')
from macd_ls_backtester_sma import Macd_ls_backtester_sma
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
macd_ls_sma_5m = Macd_ls_backtester_sma('BTCUSDT','5m')
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_5m.execute_opt(start_opt='2022-01-01-00:00', end_opt='2022-01-06-00:00', ema_fast_opt=(2,18,4), ema_slow_opt=(15,40,5), ema_sign_opt=(2, 30, 6), sma_slow=(60,200,40), sma_fast=(10,50,20))
# Out:
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.940279          -4.495206           0.49685
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -9.047418                    0.911158               -6.79183
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.506171             -13.418044                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  27                    27.0                    73.0
#
#    total_trades
# 0            37
# processed 1 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.020613           1.489472          0.497022
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.996794                    0.999147                -0.0623
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503182              -0.123813                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  14                    44.0                    56.0
#
#    total_trades
# 0            25
# processed 2 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.952452          -3.556227          0.497099
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -7.153967                    0.931627              -5.170071
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.502536             -10.287969                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    34.6                    65.4
#
#    total_trades
# 0            26
# processed 3 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.942181          -4.347716          0.497039
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -8.747238                    0.923149              -5.837418
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501544             -11.638894                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    25.0                    75.0
#
#    total_trades
# 0            24
# processed 4 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.931808          -5.155871          0.496965
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.374715                    0.911434              -6.769715
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501698             -13.493611                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    34.6                    65.4
#
#    total_trades
# 0            26
# processed 5 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.915969          -6.407447          0.496827
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -12.89675                    0.900524              -7.648865
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500473             -15.283271                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    20.0                    80.0
#
#    total_trades
# 0            20
# processed 6 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.900706          -7.634075          0.496661
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -15.370781                    0.883262              -9.061705
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.502316             -18.039858                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    26.1                    69.6
#
#    total_trades
# 0            23
# processed 7 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.898109          -7.844841           0.49663
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -15.796142                    0.887482              -8.713834
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499435             -17.447394                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  13                     7.1                    92.9
#
#    total_trades
# 0            14
# processed 8 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.931078          -5.213085          0.496783
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.493691                    0.903777              -7.385567
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.50505             -14.623427                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  27                    22.9                    77.1
#
#    total_trades
# 0            35
# processed 9 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.017618            1.27494          0.497028
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.565128                    0.996215              -0.276833
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503053              -0.550306                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  14                    44.0                    56.0
#
#    total_trades
# 0            25
# processed 10 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.96086          -2.914656          0.497137
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -5.862889                    0.939851                -4.5285
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500212               -9.05316                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    26.9                    73.1
#
#    total_trades
# 0            26
# processed 11 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.929207          -5.359913          0.496943
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.785775                    0.910437              -6.849615
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501585             -13.655943                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    20.8                    79.2
#
#    total_trades
# 0            24
# processed 12 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.917504          -6.285146           0.49684
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -12.650253                    0.897443               -7.89899
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500327             -15.787648                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 13 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.91528          -6.462332          0.496818
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -13.007446                    0.899847              -7.703751
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500824             -15.382138                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    15.0                    85.0
#
#    total_trades
# 0            20
# processed 14 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.898673          -7.799016          0.496635
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -15.703709                    0.881269              -9.226647
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501623             -18.393601                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    26.1                    69.6
#
#    total_trades
# 0            23
# processed 15 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.880148            -9.3196          0.496386
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -18.774915                    0.869732             -10.188593
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.49937             -20.402882                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  12                    14.3                    85.7
#
#    total_trades
# 0            14
# processed 16 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.930576          -5.252466           0.49672
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.574308                     0.90329              -7.424947
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.504547             -14.716063                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  27                    22.9                    77.1
#
#    total_trades
# 0            35
# processed 17 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.000485           0.035397          0.496984
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.071223                    0.979442              -1.516376
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.502259              -3.019113                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    40.0                    60.0
#
#    total_trades
# 0            25
# processed 18 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.962151          -2.816629          0.497144
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -5.665623                    0.941114              -4.430472
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498959               -8.87943                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    34.6                    65.4
#
#    total_trades
# 0            26
# processed 19 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                  0.9268          -5.549285          0.496925
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.167253                    0.908078              -7.038987
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501237             -14.043233                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    25.0                    75.0
#
#    total_trades
# 0            24
# processed 20 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.926562          -5.568004          0.496923
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.204969                    0.906303              -7.181848
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499972             -14.364503                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 21 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.91497          -6.487102          0.496817
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -13.057336                    0.899541               -7.72852
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500274             -15.448569                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    25.0                    75.0
#
#    total_trades
# 0            20
# processed 22 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903761          -7.386904          0.496697
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -14.872051                    0.886258              -8.814535
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501568             -17.573972                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    30.4                    65.2
#
#    total_trades
# 0            23
# processed 23 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.906456          -7.169548          0.496727
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -14.433568                    0.895729              -8.038541
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498461             -16.126721                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  11                    21.4                    78.6
#
#    total_trades
# 0            14
# processed 24 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.923357          -5.820986          0.496659
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -11.72028                     0.89476              -8.117609
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.504528             -16.089508                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    24.3                    75.7
#
#    total_trades
# 0            37
# processed 25 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.00863           0.627309           0.49698
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.262242                    0.989097              -0.800322
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501732              -1.595118                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  12                    47.8                    52.2
#
#    total_trades
# 0            23
# processed 26 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                  0.9649          -2.608358          0.497155
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -5.246573                    0.943802              -4.222201
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498849              -8.463882                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    34.6                    65.4
#
#    total_trades
# 0            26
# processed 27 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.929516          -5.335659          0.496947
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.736876                     0.91074              -6.825361
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500784             -13.629348                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    33.3                    66.7
#
#    total_trades
# 0            24
# processed 28 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.930515          -5.257226          0.496955
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.578876                     0.91017              -6.871069
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499503             -13.755809                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 29 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.922168          -5.915016          0.496885
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.904204                    0.909707              -6.908151
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499898             -13.819127                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  13                    18.8                    81.2
#
#    total_trades
# 0            16
# processed 30 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903761          -7.386904          0.496697
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -14.872051                    0.886258              -8.814535
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501568             -17.573972                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    30.4                    65.2
#
#    total_trades
# 0            23
# processed 31 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.913686          -6.589596          0.496804
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -13.26398                    0.904411              -7.334447
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498306             -14.718754                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  10                    16.7                    83.3
#
#    total_trades
# 0            12
# processed 32 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.92772          -5.476867          0.496697
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.026587                     0.89746              -7.897633
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.50385             -15.674579                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    25.6                    74.4
#
#    total_trades
# 0            39
# processed 33 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.004525           0.329567          0.496983
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.663135                    0.985071              -1.098064
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501875              -2.187921                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  14                    39.1                    60.9
#
#    total_trades
# 0            23
# processed 34 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.95862          -3.084996          0.497129
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -6.20563                    0.936067              -4.822981
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498871              -9.667785                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    32.1                    67.9
#
#    total_trades
# 0            28
# processed 35 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.928415          -5.422185          0.496938
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.911186                    0.909661              -6.911886
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500958             -13.797341                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    29.2                    70.8
#
#    total_trades
# 0            24
# processed 36 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.932514          -5.100573          0.496971
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.263329                    0.912125              -6.714416
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499514             -13.441887                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 37 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.922168          -5.915016          0.496885
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.904204                    0.909707              -6.908151
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499898             -13.819127                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  13                    18.8                    81.2
#
#    total_trades
# 0            16
# processed 38 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.903761          -7.386904          0.496697
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -14.872051                    0.886258              -8.814535
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501568             -17.573972                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    30.4                    65.2
#
#    total_trades
# 0            23
# processed 39 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.913396           -6.61273          0.496801
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -13.310623                    0.904124               -7.35758
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498161              -14.76949                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  10                    16.7                    83.3
#
#    total_trades
# 0            12
# processed 40 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.928683          -5.401087          0.496764
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.872548                    0.901453              -7.573569
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.505377             -14.985977                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  27                    22.9                    77.1
#
#    total_trades
# 0            35
# processed 41 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.022817           1.646925          0.497017
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           3.313617                    1.001304               0.095152
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503032               0.189157                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    36.0                    64.0
#
#    total_trades
# 0            25
# processed 42 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.962684          -2.776186          0.497144
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -5.584268                    0.941635               -4.39003
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500128              -8.777815                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    26.9                    73.1
#
#    total_trades
# 0            26
# processed 43 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.923262          -5.828512          0.496893
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.729923                    0.904612              -7.318213
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.50177             -14.584804                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    20.8                    79.2
#
#    total_trades
# 0            24
# processed 44 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.919221          -6.148723          0.496856
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -12.375267                    0.899122              -7.762567
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500905             -15.497092                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 45 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.915177          -6.470541          0.496817
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -13.023995                    0.899746               -7.71196
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501169             -15.387953                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    15.0                    85.0
#
#    total_trades
# 0            20
# processed 46 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.898673          -7.799016          0.496635
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -15.703709                    0.881269              -9.226647
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501623             -18.393601                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    26.1                    69.6
#
#    total_trades
# 0            23
# processed 47 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.887665          -8.698769          0.496493
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -17.520427                    0.877161              -9.567762
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500178             -19.128727                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  12                    14.3                    85.7
#
#    total_trades
# 0            14
# processed 48 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.921798          -5.944297          0.496645
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.968897                    0.891732              -8.365062
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503446              -16.61562                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    28.2                    71.8
#
#    total_trades
# 0            39
# processed 49 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.015694           1.136794          0.496971
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.287443                    0.996024              -0.290837
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.50227              -0.579045                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    30.4                    69.6
#
#    total_trades
# 0            23
# processed 50 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.953264          -3.494042          0.497101
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -7.028837                    0.929255              -5.356169
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.49886             -10.736818                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                    30.0                    70.0
#
#    total_trades
# 0            30
# processed 51 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.940003          -4.516702          0.497023
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -9.08752                    0.921014              -6.006404
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501042             -11.987823                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    25.0                    75.0
#
#    total_trades
# 0            24
# processed 52 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.925917          -5.618822          0.496916
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.307398                    0.905672              -7.232666
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499562             -14.478012                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    42.3                    57.7
#
#    total_trades
# 0            26
# processed 53 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.927224          -5.515917          0.496927
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.100064                     0.91314              -6.633193
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.50027             -13.259216                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  13                    27.8                    72.2
#
#    total_trades
# 0            18
# processed 54 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.906079           -7.19992          0.496721
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -14.494887                    0.890043              -8.503409
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501409             -16.959021                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  14                    28.6                    66.7
#
#    total_trades
# 0            21
# processed 55 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.907545          -7.081853          0.496738
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -14.25673                    0.896806              -7.950846
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498553             -15.947842                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  11                    21.4                    78.6
#
#    total_trades
# 0            14
# processed 56 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.921841          -5.940929          0.496646
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.962107                    0.890258              -8.485836
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503202             -16.863682                  12
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    29.3                    70.7
#
#    total_trades
# 0            41
# processed 57 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.998794          -0.088067          0.496984
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.177204                    0.979451              -1.515698
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.50161              -3.021666                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    21.7                    78.3
#
#    total_trades
# 0            23
# processed 58 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# ...
# 0              0.501227              -3.389308                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    21.7                    78.3
#
#    total_trades
# 0            23
# processed 74 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.952808          -3.528968          0.496849
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -7.102694                    0.928021              -5.453166
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498664             -10.935553                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  22                    29.0                    71.0
#
#    total_trades
# 0            31
# processed 75 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.951194          -3.652741          0.496851
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -7.351788                     0.93436               -4.95623
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499412              -9.924122                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    28.6                    71.4
#
#    total_trades
# 0            21
# processed 76 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.933768          -5.002524          0.496086
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.083985                     0.91025              -6.864652
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498406             -13.773222                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    33.3                    66.7
#
#    total_trades
# 0            30
# processed 77 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.923686          -5.794948          0.496004
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -11.68327                    0.911205              -6.788083
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498052             -13.629266                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  14                    12.5                    87.5
#
#    total_trades
# 0            16
# processed 78 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.896741          -7.956172          0.495719
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -16.049773                     0.88087              -9.259661
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500565             -18.498415                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    19.0                    76.2
#
#    total_trades
# 0            21
# processed 79 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.922628          -5.878619          0.495995
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.852185                    0.913262               -6.62347
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.496905             -13.329455                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  10                    16.7                    83.3
#
#    total_trades
# 0            12
# processed 80 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.927993          -5.455351          0.496758
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.981907                    0.900783              -7.627833
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.504767             -15.111587                   7
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  28                    20.0                    80.0
#
#    total_trades
# 0            35
# processed 81 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.014153           1.025959          0.497033
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.064167                    0.992823              -0.525813
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503121              -1.045104                  11
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  14                    44.0                    56.0
#
#    total_trades
# 0            25
# processed 82 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.962288           -2.80625          0.497142
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -5.64476                    0.941247              -4.420094
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500041              -8.839457                   8
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    30.8                    69.2
#
#    total_trades
# 0            26
# processed 83 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.935892          -4.836597          0.496994
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -9.731703                    0.916987              -6.326299
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501195             -12.622428                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    20.8                    79.2
#
#    total_trades
# 0            24
# processed 84 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.926418          -5.579396           0.49692
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -11.22796                    0.906162              -7.193239
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.499969             -14.387383                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 85 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.916584          -6.358379          0.496831
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -12.797878                    0.901129              -7.599797
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500673             -15.179158                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  15                    25.0                    75.0
#
#    total_trades
# 0            20
# processed 86 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.904092          -7.360134          0.496699
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -14.818096                    0.886583              -8.787765
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501559             -17.520888                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    26.1                    69.6
#
#    total_trades
# 0            23
# processed 87 out of a total 800
# 1441
# 2021-12-31 09:00:00
# 1621
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.889823          -8.521497          0.496522
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -17.162366                    0.879293              -9.390489
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498943             -18.820748                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  12                    14.3                    85.7
#
#    total_trades
# 0            14
# processed 88 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.917451          -6.289435          0.496605
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -12.664867                    0.886018              -8.834342
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.503496             -17.545987                  12
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                    29.3                    70.7
#
#    total_trades
# 0            41
# processed 89 out of a total 800
# 1441
# 2021-12-31 19:00:00
# 1501
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.000098           0.007175          0.496984
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.014436                     0.98073              -1.420456
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.501256              -2.833792                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    26.1                    73.9
#
#    total_trades
# 0            23
# processed 90 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.954799          -3.376607          0.496859
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -6.795902                    0.931543              -5.176664
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498531             -10.383836                   9
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                    31.0                    69.0
#
#    total_trades
# 0            29
# processed 91 out of a total 800
# 1441
# 2021-12-31 15:40:00
# 1541
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.947519           -3.93532           0.49683
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -7.920858                    0.929169              -5.362951
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.500289             -10.719716                   6
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    26.1                    73.9
#
#    total_trades
# 0            23
# processed 92 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.974426          -1.891214          0.497255          -3.803309
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.932542          -5.098436          0.496117
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.276689                    0.912152               -6.71228
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.498747              -13.45828                  10
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    38.5                    61.5
#
#    total_trades
# 0            26
# processed 93 out of a total 800
# 1441
# 2021-12-31 12:20:00
# 1581

# %%
#macd_ls_sma_15m.opt_max

# %%
#macd_ls_sma_15m.opt_results.iloc[240]

# %%
#macd_ls_sma_15m_imported = Macd_ls_backtester_sma('BTCUSDT','15m')

# %%
#macd_ls_sma_15m_imported.opt_results = pd.read_csv('macd_ls_sma_2022-11-15-00:13_15m_BTCUSDT.csv')

# %%
#macd_ls_sma_15m_imported.opt_results.iloc[240]

# %%
#macd_ls_sma_15m_imported.prepare_data(start='2022-04-15-00:00', end='2022-06-01-00:00')

# %%
#macd_ls_sma_15m_imported.execute_backtest(start='2022-04-15-00:00',ema_slow=20, ema_fast=2, ema_signal=2, sma_slow=60, sma_fast=10)

# %%
#macd_ls_sma_15m_imported.plot_backtest_results(start_plot='2022-05-08-00:00', end_plot='2022-05-15-00:00', width_bars=0.003)

# %%
#macd_ls_sma_15m_imported.plot_backtest_results(start_plot='2022-05-04-00:00', end_plot='2022-05-15-00:00', width_bars=0.003)
