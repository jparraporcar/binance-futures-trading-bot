# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/long_short/macd_ls_backtester_sma')
from macd_ls_backtester_sma import Macd_ls_backtester_sma
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
macd_ls_sma_1m = Macd_ls_backtester_sma('BTCUSDT','1m')
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_1m.execute_opt(start_opt='2022-01-01-00:00', end_opt='2022-01-02-12:00', ema_fast_opt=(2,18,4), ema_slow_opt=(15,40,5), ema_sign_opt=(2, 30, 6), sma_slow=(50,200,40), sma_fast=(10,50,20))
# Out:
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.995363          -1.130982          0.528388
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.140436                    0.942644             -14.372775
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.551272             -26.072008                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  59                     7.8                    92.2
#
#    total_trades
# 0            64
# processed 1 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.013109           3.169219          0.528256
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           5.999398                    0.969291              -7.589738
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.54762             -13.859508                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     7.7                    92.3
#
#    total_trades
# 0            52
# processed 2 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.998039           -0.47767          0.527814
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.904997                     0.95894             -10.202112
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.548035             -18.615789                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  45                     4.3                    95.7
#
#    total_trades
# 0            47
# processed 3 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.958966          -10.19553          0.528087
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -19.306534                    0.934814             -16.402621
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541048             -30.316413                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  29                     3.3                    96.7
#
#    total_trades
# 0            30
# processed 4 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.020619           4.966201           0.52777
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           9.409778                    0.989851              -2.482308
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.542536              -4.575378                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  34                     5.6                    94.4
#
#    total_trades
# 0            36
# processed 5 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.953043         -11.703302          0.528028
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -22.16419                     0.93538             -16.255169
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.540547             -30.071682                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    18.2                    81.8
#
#    total_trades
# 0            22
# processed 6 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.977685          -5.491517          0.527339
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.413629                    0.948211             -12.940026
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541193             -23.910207                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  34                     5.6                    94.4
#
#    total_trades
# 0            36
# processed 7 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.946435         -13.396305          0.527951
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -25.374147                    0.928895             -17.948171
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.540012             -33.236598                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    13.6                    86.4
#
#    total_trades
# 0            22
# processed 8 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.00743           1.801298          0.528385
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           3.409064                    0.960584              -9.785271
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544627             -17.966936                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  54                     3.6                    96.4
#
#    total_trades
# 0            56
# processed 9 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.017502            4.22204          0.528242
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           7.992621                     0.97515              -6.123111
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.546142             -11.211563                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     4.0                    96.0
#
#    total_trades
# 0            50
# processed 10 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.995804          -1.023227          0.527813
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.938617                    0.956793             -10.747669
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544077             -19.753935                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  45                     4.3                    95.7
#
#    total_trades
# 0            47
# processed 11 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.953116         -11.684578          0.528028
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -22.128695                    0.927532             -18.305475
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541449              -33.80829                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                     3.1                    96.9
#
#    total_trades
# 0            32
# processed 12 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.003582           0.870049          0.527813
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.648403                    0.973327               -6.57846
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541978             -12.137867                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  34                     5.6                    94.4
#
#    total_trades
# 0            36
# processed 13 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.95311         -11.686184          0.528028
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -22.13174                    0.937038             -15.824245
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541431             -29.226733                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    15.0                    85.0
#
#    total_trades
# 0            20
# processed 14 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.973639          -6.500633          0.527738
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -12.317906                    0.944287             -13.949142
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539736             -25.844387                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  34                     5.6                    94.4
#
#    total_trades
# 0            36
# processed 15 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.946486         -13.383194          0.527952
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -25.349284                    0.928945             -17.935061
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539775             -33.226902                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                     4.5                    95.5
#
#    total_trades
# 0            22
# processed 16 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.994084           -1.44374          0.528387
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.732353                    0.944641             -13.857921
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.545071             -25.424042                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  57                     5.0                    95.0
#
#    total_trades
# 0            60
# processed 17 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.021181           5.100161          0.528032
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           9.658805                    0.978676               -5.24499
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.546882               -9.59072                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     4.0                    96.0
#
#    total_trades
# 0            50
# processed 18 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.997323          -0.652267          0.528274
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.234714                    0.955811             -10.997418
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544989             -20.179139                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     4.0                    96.0
#
#    total_trades
# 0            50
# processed 19 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.949753          -12.54467          0.527796
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -23.768049                    0.924259             -19.165566
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541766             -35.376098                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                     3.1                    96.9
#
#    total_trades
# 0            32
# processed 20 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.006065           1.471359           0.52827
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.785237                    0.974906              -6.184053
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.54111             -11.428453                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  35                     5.4                    94.6
#
#    total_trades
# 0            37
# processed 21 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.95196         -11.979878           0.52782
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -22.696879                    0.935908             -16.117938
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.540545              -29.81794                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    15.0                    85.0
#
#    total_trades
# 0            20
# processed 22 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.975023          -6.155022          0.528206
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.652691                    0.946433             -13.396628
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539757             -24.819752                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     5.7                    94.3
#
#    total_trades
# 0            35
# processed 23 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.946711         -13.325232          0.527759
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -25.248702                    0.929166             -17.877099
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539285             -33.149648                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                     4.5                    95.5
#
#    total_trades
# 0            22
# processed 24 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.993509           -1.58463          0.528386
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.998999                     0.94249             -14.412617
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544842             -26.452851                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  58                     6.5                    93.5
#
#    total_trades
# 0            62
# processed 25 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.036521           8.728301          0.527942
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          16.532693                    0.993377               -1.61685
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.543689               -2.97385                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  47                     6.0                    94.0
#
#    total_trades
# 0            50
# processed 26 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.992057          -1.940539          0.528268
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.673402                    0.947536             -13.113302
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0                0.5455             -24.039038                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  51                     5.6                    94.4
#
#    total_trades
# 0            54
# processed 27 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                  0.9542         -11.407973          0.527845
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -21.61237                    0.928587              -18.02887
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541247             -33.309877                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                     3.1                    96.9
#
#    total_trades
# 0            32
# processed 28 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.021657            5.21369          0.528225
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0             9.8702                    0.991701              -2.027916
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.53896              -3.762645                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     5.7                    94.3
#
#    total_trades
# 0            35
# processed 29 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.960445          -9.820611          0.527905
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -18.602977                     0.94425             -13.958672
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.53936             -25.880056                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    20.0                    80.0
#
#    total_trades
# 0            20
# processed 30 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.97775           -5.47536           0.52822
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -10.365673                    0.949081             -12.716965
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539428             -23.574889                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     5.7                    94.3
#
#    total_trades
# 0            35
# processed 31 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.947704          -13.07028          0.527771
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -24.765048                     0.93014             -17.622146
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.538238             -32.740412                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                     4.5                    95.5
#
#    total_trades
# 0            22
# processed 32 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.994826          -1.262327          0.528388
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.389016                    0.943739             -14.090315
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544626             -25.871553                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  58                     6.5                    93.5
#
#    total_trades
# 0            62
# processed 33 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.05645          13.362552          0.527757
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          25.319501                    1.017656               4.258819
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541819               7.860228                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  41                     6.8                    93.2
#
#    total_trades
# 0            44
# processed 34 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.991922          -1.973513          0.528267
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.735823                    0.947408             -13.146277
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.545646             -24.093066                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  51                     5.6                    94.4
#
#    total_trades
# 0            54
# processed 35 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.961321          -9.598675          0.527913
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -18.182299                    0.937109             -15.805765
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.540181             -29.260122                   0
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  30                     0.0                   100.0
#
#    total_trades
# 0            30
# processed 36 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.020428           4.920619          0.528231
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           9.315284                    0.988824              -2.734793
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.53863              -5.077315                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  36                     2.7                    97.3
#
#    total_trades
# 0            37
# processed 37 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.960295          -9.858579          0.527904
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -18.674946                    0.944103              -13.99664
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539065             -25.964659                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  16                    20.0                    80.0
#
#    total_trades
# 0            20
# processed 38 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.978913          -5.186058          0.528226
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -9.81788                     0.95021             -12.427664
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539108             -23.052261                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     5.7                    94.3
#
#    total_trades
# 0            35
# processed 39 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.945116         -13.735531          0.527739
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -26.027124                    0.927601             -18.287397
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.538301             -33.972452                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                     4.5                    95.5
#
#    total_trades
# 0            22
# processed 40 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.004217           1.024005          0.528389
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.937975                    0.957521             -10.562565
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.545501             -19.363063                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  55                     1.8                    98.2
#
#    total_trades
# 0            56
# processed 41 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.013283           3.211023          0.528256
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           6.078539                    0.971107              -7.134128
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.547675             -13.026196                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  47                     6.0                    94.0
#
#    total_trades
# 0            50
# processed 42 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.995194          -1.172361          0.527812
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -2.221171                    0.956207             -10.896803
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544771             -20.002539                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  45                     4.3                    95.7
#
#    total_trades
# 0            47
# processed 43 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.953797         -11.510633          0.528036
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -21.798972                    0.928195              -18.13153
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541285             -33.497223                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                     3.1                    96.9
#
#    total_trades
# 0            32
# processed 44 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.013148           3.178441          0.527797
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           6.022095                    0.984277              -3.856262
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.542117              -7.113339                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     2.9                    97.1
#
#    total_trades
# 0            34
# processed 45 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.934179         -16.567987           0.52778
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -31.391867                    0.916866             -21.119853
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.542027             -38.964554                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    13.6                    86.4
#
#    total_trades
# 0            22
# processed 46 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.974381          -6.315136          0.527743
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -11.966315                    0.946615             -13.349839
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.540925             -24.679636                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     2.9                    97.1
#
#    total_trades
# 0            34
# processed 47 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.950964          -12.23459          0.528005
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -23.171369                     0.93334             -16.786456
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.538477             -31.173941                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                     9.1                    90.9
#
#    total_trades
# 0            22
# processed 48 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.990645           -2.28704          0.528381
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -4.328388                    0.938177             -15.528833
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.54482              -28.50267                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  59                     7.8                    92.2
#
#    total_trades
# 0            64
# processed 49 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.021835           5.256064          0.528029
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           9.954111                    0.979303              -5.089087
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.546056              -9.319725                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     4.0                    96.0
#
#    total_trades
# 0            50
# processed 50 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.989952          -2.457383          0.528263
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -4.651814                    0.948747             -12.802535
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544506              -23.51219                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  47                     6.0                    94.0
#
#    total_trades
# 0            50
# processed 51 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.95661         -10.794203          0.527869
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -20.448633                    0.930932               -17.4151
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541018             -32.189498                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                     3.1                    96.9
#
#    total_trades
# 0            32
# processed 52 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.014251           3.443289          0.528253
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           6.518258                    0.984512              -3.798317
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0               0.53948              -7.040695                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  33                     5.7                    94.3
#
#    total_trades
# 0            35
# processed 53 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.954887         -11.232704          0.527852
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -21.280035                    0.938786             -15.370764
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.540058             -28.461339                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    15.0                    85.0
#
#    total_trades
# 0            20
# processed 54 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.978492          -5.290654          0.528224
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -10.01593                    0.951418             -12.118453
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.538539             -22.502482                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  31                     6.1                    93.9
#
#    total_trades
# 0            33
# processed 55 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.948603         -12.839466          0.527782
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -24.327212                    0.931023             -17.391332
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.537987             -32.326659                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  21                     4.5                    95.5
#
#    total_trades
# 0            22
# processed 56 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.992878          -1.739327          0.528385
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -3.291777                    0.940291              -14.98112
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544479              -27.51459                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  59                     7.8                    92.2
#
#    total_trades
# 0            64
# processed 57 out of a total 800
# 2161
# 2021-12-31 23:10:00
# 2211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.033682           8.060962          0.527958
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          15.268179                    0.995724              -1.042771
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.541976              -1.924017                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  41                     6.8                    93.2
#
#    total_trades
# 0            44
# processed 58 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# ...
# 0              0.539424             -11.379774                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  40                     2.4                    97.6
#
#    total_trades
# 0            41
# processed 781 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.959003         -10.186148          0.527628
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -19.305565                    0.942833             -14.324208
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.537724             -26.638595                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  17                    15.0                    85.0
#
#    total_trades
# 0            20
# processed 782 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.982277          -4.351229           0.52824
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -8.237215                    0.951855              -12.00664
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.538517             -22.295745                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  35                     5.4                    94.6
#
#    total_trades
# 0            37
# processed 783 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.951627         -12.065088          0.527552
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -22.869944                     0.93558             -16.203148
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.536063             -30.226207                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    10.0                    90.0
#
#    total_trades
# 0            20
# processed 784 out of a total 800
# 2161
# 2021-12-31 23:03:00
# 2218
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 0.99581          -1.021669          0.528389
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -1.933556                    0.944673             -13.849657
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.543447             -25.484853                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  58                     6.5                    93.5
#
#    total_trades
# 0            62
# processed 785 out of a total 800
# 2161
# 2021-12-31 23:03:00
# 2218
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.004529           1.099545          0.527812
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.083212                    0.965997              -8.417994
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539972             -15.589686                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  43                     6.5                    93.5
#
#    total_trades
# 0            46
# processed 786 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.990304          -2.370901          0.528264
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -4.488096                    0.947472             -13.129858
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.544761             -24.102046                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     7.7                    92.3
#
#    total_trades
# 0            52
# processed 787 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.949084         -12.716171          0.527102
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -24.124689                    0.923608             -19.337068
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.537214             -35.995125                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  30                     6.2                    93.8
#
#    total_trades
# 0            32
# processed 788 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.008246           1.998371          0.528267
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            3.78288                    0.973703              -6.484652
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539694             -12.015433                   1
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  40                     2.4                    97.6
#
#    total_trades
# 0            41
# processed 789 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.942805         -14.331292          0.527023
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -27.192912                    0.925333             -18.883159
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.537713             -35.117556                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  19                    13.6                    86.4
#
#    total_trades
# 0            22
# processed 790 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.978649          -5.251736          0.528225
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           -9.94224                    0.948339             -12.907148
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539079             -23.942946                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  35                     5.4                    94.6
#
#    total_trades
# 0            37
# processed 791 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.949763         -12.541981           0.52711
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -23.793864                    0.932162             -17.093848
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.535872             -31.899097                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                     9.1                    90.9
#
#    total_trades
# 0            22
# processed 792 out of a total 800
# 2161
# 2021-12-31 22:57:00
# 2224
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.004254           1.032865          0.528389
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           1.954744                    0.954304             -11.381316
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.543114             -20.955678                   5
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  55                     8.3                    91.7
#
#    total_trades
# 0            60
# processed 793 out of a total 800
# 2161
# 2021-12-31 22:57:00
# 2224
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.004733           1.149053          0.527812
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.177011                    0.966194              -8.368486
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539423             -15.513773                   3
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  43                     6.5                    93.5
#
#    total_trades
# 0            46
# processed 794 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.986462            -3.3167          0.528255
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -6.278602                    0.943796             -14.075657
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.545682             -25.794627                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  48                     7.7                    92.3
#
#    total_trades
# 0            52
# processed 795 out of a total 800
# 2161
# 2021-12-31 22:30:00
# 2251
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.951247         -12.162191          0.527127
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -23.072607                    0.925713             -18.783087
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.537147             -34.968221                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  30                     6.2                    93.8
#
#    total_trades
# 0            32
# processed 796 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.006857           1.662937          0.528269
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           3.147895                    0.972361              -6.820087
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.539955             -12.630851                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  39                     4.9                    95.1
#
#    total_trades
# 0            41
# processed 797 out of a total 800
# 2161
# 2021-12-31 21:50:00
# 2291
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.942455         -14.421669          0.527018
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -27.364641                    0.924989             -18.973536
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.537619             -35.291793                   4
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  18                    18.2                    81.8
#
#    total_trades
# 0            22
# processed 798 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.979562          -5.024744          0.528229
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -9.512437                    0.949224             -12.680156
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.538715             -23.537795                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  35                     5.4                    94.6
#
#    total_trades
# 0            37
# processed 799 out of a total 800
# 2161
# 2021-12-31 21:10:00
# 2331
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.986462          -3.316812          0.528938            -6.2707
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.949763         -12.541981           0.52711
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0         -23.793864                    0.932162             -17.093848
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.535872             -31.899097                   2
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  20                     9.1                    90.9
#
#    total_trades
# 0            22
# processed 800 out of a total 800

# %%
macd_ls_sma_1m.opt_max
# Out:
# 33    1.05645
# Name: multiple_macd_strategy, dtype: float64

# %%
macd_ls_sma_1m.opt_results.iloc[33]
# Out:
# macd_slow_opt                               15
# macd_fast_opt                                2
# macd_signal_opt                             26
# sma_slow                                    50
# sma_fast                                    30
# multiple_hold                         0.986462
# ann_log_mean_hold                    -3.316812
# ann_log_std_hold                      0.528938
# sharpe_ratio_hold                      -6.2707
# multiple_macd_strategy                 1.05645
# ann_log_mean_macd                    13.362552
# ann_log_std_macd                      0.527757
# sharpe_ratio_macd                    25.319501
# multiple_macd_strategy_net            1.017656
# ann_log_mean_macd_net                 4.258819
# ann_log_std_macd_net                  0.541819
# sharpe_ratio_macd_net                 7.860228
# success_trades_net                           3
# failure_trades_net                          41
# success_trades_net_pct                     6.8
# failure_trades_net_pct                    93.2
# total_trades                                44
# start_opt                     2022-01-01-00:00
# end_opt                       2022-01-02-12:00
# Name: 33, dtype: object

# %%
macd_ls_sma_1m.opt_max_net
# Out:
# 97    1.019845
# Name: multiple_macd_strategy_net, dtype: float64

# %%
macd_ls_sma_1m.opt_results.iloc[97]
# Out:
# macd_slow_opt                               15
# macd_fast_opt                               10
# macd_signal_opt                             14
# sma_slow                                    50
# sma_fast                                    30
# multiple_hold                         0.986462
# ann_log_mean_hold                    -3.316812
# ann_log_std_hold                      0.528938
# sharpe_ratio_hold                      -6.2707
# multiple_macd_strategy                1.055128
# ann_log_mean_macd                    13.057699
# ann_log_std_macd                      0.527537
# sharpe_ratio_macd                    24.752176
# multiple_macd_strategy_net            1.019845
# ann_log_mean_macd_net                 4.781578
# ann_log_std_macd_net                  0.538059
# sharpe_ratio_macd_net                 8.886709
# success_trades_net                           2
# failure_trades_net                          38
# success_trades_net_pct                     5.0
# failure_trades_net_pct                    95.0
# total_trades                                40
# start_opt                     2022-01-01-00:00
# end_opt                       2022-01-02-12:00
# Name: 97, dtype: object

# %%
#macd_ls_sma_1h.plot_backtest_results(start_plot='2022-01-01-00:00', end_plot='2022-06-01-00:00', width_bars=0.003)
