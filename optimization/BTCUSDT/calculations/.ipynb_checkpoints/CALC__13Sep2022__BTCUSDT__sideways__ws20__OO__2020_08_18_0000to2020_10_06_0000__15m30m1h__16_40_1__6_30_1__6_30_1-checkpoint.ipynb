# %% [markdown]
# # Optimization of the MACD parameters in up trend is going to be carried out

# %% [markdown]
# ### 1) 3 up trend date ranges (period = '1d') are going to be extracted from the BTCUSDT historic data and an optimization will be conducted in all three intervals. Similar MACD parameters are expected to be obtained.

# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_td = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_td.prepare_data(start='2018-01-29-20:00', end='2022-09-11-20:00', interval='1d')
# Out:
# 1686

# %%
macd_td.assign_trends(window_size=20, plot=True)

# %% [markdown]
# ## Analysis of 'sideways' trend 'OO'

# %%
macd_td.get_trend_dates(type='sideways', trend_ref='OO', do_plot=True)
# Out:
# date_init: 2020-08-18 00:00:00 1597708800000
# date_end: 2020-10-06 00:00:00 1601942400000
# (1597708800000, 1601942400000)

# %%
macd_opt_oo = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_oo.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2020-08-18-00:00', end_opt='2020-10-06-00:00', ema_fast_opt=(4,16,4), ema_slow_opt=(16,40,1), ema_sign_opt=(6, 30, 4), int_for_max='15m')
# Out:
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# 4705
# ...

# %%
macd_opt_oo.opt_comb_num
# Out:
# 1296

# %%
macd_opt_oo.multiple_macd_strategy_max
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 102          15m             21             12                6
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 102       0.882206                0.988512                    0.682885

# %%
macd_opt_oo.multiple_macd_strategy_net_max
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 394          15m             37             12               22
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 394       0.882206                0.945772                    0.778435

# %%
filt30m = macd_opt_oo.opt_results.loc[macd_opt_oo.opt_results.interval_opt == '30m']
filt30m.loc[filt30m.multiple_macd_strategy ==filt30m.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 736          30m             32             12               22
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 736       0.880107                 1.00117                    0.912551

# %%
filt30m.loc[filt30m.multiple_macd_strategy_net ==filt30m.multiple_macd_strategy_net.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 736          30m             32             12               22
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 736       0.880107                 1.00117                    0.912551

# %%
filt1h= macd_opt_oo.opt_results.loc[macd_opt_oo.opt_results.interval_opt == '1h']
filt1h.loc[filt1h.multiple_macd_strategy ==filt1h.multiple_macd_strategy.max() ]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1267           1h             38              8               10
#
#       multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 1267       0.863501                1.032738                    0.959099

# %%
filt1h.loc[filt1h.multiple_macd_strategy_net ==filt1h.multiple_macd_strategy_net.max() ]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1267           1h             38              8               10
#
#       multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 1267       0.863501                1.032738                    0.959099
