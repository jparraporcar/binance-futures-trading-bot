# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/macd_ls_backtester_sma_sltp/')
from macd_ls_backtester_sma_sltp import Macd_ls_backtester_sma_sltp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
macd_ls_sma_sltp_15m = Macd_ls_backtester_sma_sltp('BTCUSDT','15m', trading_cost_fees=0.0004, trading_cost_others=0.00001)
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_sltp_15m.execute_opt(start_opt='2022-04-15-00:00', end_opt='2022-06-01-00:00', ema_fast_opt=2, ema_slow_opt=20, ema_sign_opt=2, sma_slow=60, sma_fast=10, sl=np.linspace(0.001, 0.02, 15), tp=np.linspace(0.02, 0.09, 15))
# Out:
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.781834            -1.9113          0.702926          -2.719062
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.727596            4.24589          0.701489
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           6.052683                    1.512033               3.210874
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.705694               4.549953                 107
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                 218                    32.9                    67.1
#
#    total_trades
# 0           325
# processed 1 out of a total 225
# 4513
# 2022-04-14 09:00:00
# 4573
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# ...

# %%
macd_ls_sma_sltp_15m.opt_max
# Out:
# 0    1.727596
# Name: multiple_macd_strategy, dtype: float64

# %%
macd_ls_sma_sltp_15m.opt_results.iloc[0]
# Out:
# macd_slow_opt                               20
# macd_fast_opt                                2
# macd_signal_opt                              2
# sma_slow                                    60
# sma_fast                                    10
# sl_opt                                   0.001
# tp_opt                                    0.02
# multiple_hold                         0.781834
# ann_log_mean_hold                      -1.9113
# ann_log_std_hold                      0.702926
# sharpe_ratio_hold                    -2.719062
# multiple_macd_strategy                1.727596
# ann_log_mean_macd                      4.24589
# ann_log_std_macd                      0.701489
# sharpe_ratio_macd                     6.052683
# multiple_macd_strategy_net            1.512033
# ann_log_mean_macd_net                 3.210874
# ann_log_std_macd_net                  0.705694
# sharpe_ratio_macd_net                 4.549953
# success_trades_net                         107
# ...
