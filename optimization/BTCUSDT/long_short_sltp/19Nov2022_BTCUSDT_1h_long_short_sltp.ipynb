# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/macd_ls_backtester_sma_sltp/')
from macd_ls_backtester_sma_sltp import Macd_ls_backtester_sma_sltp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
macd_ls_sma_sltp_1h = Macd_ls_backtester_sma_sltp('BTCUSDT','1h', trading_cost_fees=0.00004, trading_cost_others=0.00001)
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_sltp_1h.execute_opt(start_opt='2022-01-01-00:00', end_opt='2022-06-01-00:00', ema_fast_opt=14, ema_slow_opt=20, ema_sign_opt=20, sma_slow=180, sma_fast=50, sl=np.linspace(0.001, 0.02, 15), tp=np.linspace(0.02, 0.09, 15))
# Out:
# 3625
# 2021-12-24 12:00:00
# 3805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.667811          -0.975951          0.673414          -1.449257
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.093055           0.215076           0.65243
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.329653                    1.087005                0.20166
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.652497               0.309059                  38
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  72                    34.2                    64.9
#
#    total_trades
# 0           111
# processed 1 out of a total 225
# 3625
# 2021-12-24 12:00:00
# 3805
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# ...

# %%
macd_ls_sma_sltp_1h.opt_max
# Out:
# 208    1.986501
# 209    1.986501
# Name: multiple_macd_strategy, dtype: float64

# %%
macd_ls_sma_sltp_1h.opt_results.iloc[208
                                    ]
# Out:
# macd_slow_opt                               20
# macd_fast_opt                               14
# macd_signal_opt                             20
# sma_slow                                   180
# sma_fast                                    50
# sl_opt                                0.018643
# tp_opt                                   0.085
# multiple_hold                         0.667811
# ann_log_mean_hold                    -0.975951
# ann_log_std_hold                      0.673414
# sharpe_ratio_hold                    -1.449257
# multiple_macd_strategy                1.986501
# ann_log_mean_macd                     1.659118
# ann_log_std_macd                      0.670584
# sharpe_ratio_macd                     2.474138
# multiple_macd_strategy_net            1.981541
# ann_log_mean_macd_net                 1.653075
# ann_log_std_macd_net                  0.670625
# sharpe_ratio_macd_net                 2.464977
# success_trades_net                          20
# ...
