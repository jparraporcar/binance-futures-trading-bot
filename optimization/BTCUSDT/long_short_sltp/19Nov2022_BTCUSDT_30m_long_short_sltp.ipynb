# %%
import sys
from datetime import datetime, timedelta, timezone
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/backtest/macd_ls_backtester_sma_sltp/')
from macd_ls_backtester_sma_sltp import Macd_ls_backtester_sma_sltp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
macd_ls_sma_sltp_30m = Macd_ls_backtester_sma_sltp('BTCUSDT','30m', trading_cost_fees=0.00004, trading_cost_others=0.00001)
# Out:
# class version 0.0 is being used

# %%
macd_ls_sma_sltp_30m.execute_opt(start_opt='2022-03-01-00:00', end_opt='2022-06-01-00:00', ema_fast_opt=14, ema_slow_opt=25, ema_sign_opt=14, sma_slow=140, sma_fast=50, sl=np.linspace(0.001, 0.02, 15), tp=np.linspace(0.02, 0.09, 15))
# Out:
# 4417
# 2022-02-26 02:00:00
# 4557
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.782538          -0.972854          0.653239          -1.489279
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.410152           1.363583          0.641425
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           2.125866                    1.400736               1.337001
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net  success_trades_net  \
# 0              0.641543                2.08404                  52
#
#    failure_trades_net  success_trades_net_pct  failure_trades_net_pct  \
# 0                  82                    38.8                    61.2
#
#    total_trades
# 0           134
# processed 1 out of a total 225
# 4417
# 2022-02-26 02:00:00
# 4557
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# ...

# %%
macd_ls_sma_sltp_30m.opt_max
# Out:
# 59    1.925522
# Name: multiple_macd_strategy, dtype: float64

# %%
macd_ls_sma_sltp_30m.opt_results.iloc[59]
# Out:
# macd_slow_opt                               25
# macd_fast_opt                               14
# macd_signal_opt                             14
# sma_slow                                   140
# sma_fast                                    50
# sl_opt                                0.005071
# tp_opt                                    0.09
# multiple_hold                         0.782538
# ann_log_mean_hold                    -0.972854
# ann_log_std_hold                      0.653239
# sharpe_ratio_hold                    -1.489279
# multiple_macd_strategy                1.925522
# ann_log_mean_macd                     2.599424
# ann_log_std_macd                      0.651243
# sharpe_ratio_macd                     3.991479
# multiple_macd_strategy_net             1.91889
# ann_log_mean_macd_net                 2.585736
# ann_log_std_macd_net                  0.651314
# sharpe_ratio_macd_net                 3.970028
# success_trades_net                          21
# ...
