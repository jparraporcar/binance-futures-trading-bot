# %%
import pandas as pd
import sys
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = [file for file in os.listdir() if os.path.splitext(file)[1] == '.csv']

# %%
files
# Out:
# ['sideways_peak_ee.csv',
#  'sideways_peak_mm.csv',
#  'sideways_peak_nn.csv',
#  'sideways_peak_oo.csv',
#  'sideways_peak_gg.csv']

# %%
results_peak = []
for name in files:
    results_peak.append(utils.find_max(filename=name, type_max='max', type_trend='sideways', strategy='peak'))
# Out:
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 2662          30m             32              2               10
# 2734          30m             32             10                2
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2662        1.03916            0.00452          0.075988           0.059481
# 2734        1.03916            0.00452          0.075988           0.059481
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 2662                     1.160205                 0.01749
# 2734                     1.160205                 0.01749
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 2662               0.047161                0.370867
# 2734               0.047161                0.370867
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 2662                         0.960629                   -0.004728
# ...

# %%
results_peak_df = pd.DataFrame(data=results_peak[0])

# %%
results_peak_df = results_peak_df.append(results_peak[1])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_89297/2549901859.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[1])

# %%
results_peak_df = results_peak_df.append(results_peak[2])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_89297/2895677857.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[2])

# %%
results_peak_df = results_peak_df.append(results_peak[3])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_89297/2168530471.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[3])

# %%
results_peak_df = results_peak_df.append(results_peak[4])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_89297/3063767121.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[4])

# %%
results_peak_df
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 2662          30m             32              2               10
# 2734          30m             32             10                2
# 1924          30m             20              8               12
# 1960          30m             20             12                8
# 256           15m             18             14               22
# 520           15m             22             14               18
# 3945           1h             26             10               30
# 4077           1h             28             10               28
# 4209           1h             30             10               26
# 593           15m             24              8               12
# 629           15m             24             12                8
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2662       1.039160           0.004520          0.075988           0.059481
# ...

# %% [markdown]
# ### REMARK: as stated in the correponded calculation file, the combinations with index 2662 and 2734 from the trend curve EE are considered invalid and not taken into account

# %%
results_peak_df.drop([2662,2734], axis=0, errors='ignore', inplace=True)

# %%
results_peak_df
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1924          30m             20              8               12
# 1960          30m             20             12                8
# 256           15m             18             14               22
# 520           15m             22             14               18
# 3945           1h             26             10               30
# 4077           1h             28             10               28
# 4209           1h             30             10               26
# 593           15m             24              8               12
# 629           15m             24             12                8
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1924       0.698155          -0.043155          0.185884          -0.232163
# 1960       0.698155          -0.043155          0.185884          -0.232163
# 256        0.921833          -0.004270          0.056452          -0.075632
# ...

# %%
results_peak_df.describe()
# Out:
#        macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# count       9.000000       9.000000         9.000000       9.000000
# mean       23.555556      10.888889        18.222222       0.925998
# std         3.972125       2.260777         8.628119       0.198212
# min        18.000000       8.000000         8.000000       0.698155
# 25%        20.000000      10.000000        12.000000       0.869411
# 50%        24.000000      10.000000        18.000000       0.869411
# 75%        26.000000      12.000000        26.000000       0.921833
# max        30.000000      14.000000        30.000000       1.242887
#
#        ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count           9.000000          9.000000           9.000000
# mean           -0.023261          0.095528          -0.197489
# std             0.024444          0.053589           0.259995
# min            -0.043768          0.053890          -0.491230
# ...

# %%
results_peak_df.reset_index(inplace=True)

# %%
results_peak_df.rename(columns={'index': 'index_opt'}, inplace=True)

# %%
results_peak_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       1924          30m             20              8               12
# 1       1960          30m             20             12                8
# 2        256          15m             18             14               22
# 3        520          15m             22             14               18
# 4       3945           1h             26             10               30
# 5       4077           1h             28             10               28
# 6       4209           1h             30             10               26
# 7        593          15m             24              8               12
# 8        629          15m             24             12                8
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.698155          -0.043155          0.185884          -0.232163
# 1       0.698155          -0.043155          0.185884          -0.232163
# ...

# %%
results_peak_df['macd_hold_diff'] = results_peak_df.multiple_macd_peak_strategy -results_peak_df.multiple_hold

# %%
results_peak_df.sort_values(by='macd_hold_diff', ascending=False )
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       1924          30m             20              8               12
# 1       1960          30m             20             12                8
# 4       3945           1h             26             10               30
# 5       4077           1h             28             10               28
# 6       4209           1h             30             10               26
# 2        256          15m             18             14               22
# 3        520          15m             22             14               18
# 7        593          15m             24              8               12
# 8        629          15m             24             12                8
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.698155          -0.043155          0.185884          -0.232163
# 1       0.698155          -0.043155          0.185884          -0.232163
# ...

# %%
results_peak_df.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     9.000000       9.000000       9.000000         9.000000
# mean   2012.555556      23.555556      10.888889        18.222222
# std    1661.092194       3.972125       2.260777         8.628119
# min     256.000000      18.000000       8.000000         8.000000
# 25%     593.000000      20.000000      10.000000        12.000000
# 50%    1924.000000      24.000000      10.000000        18.000000
# 75%    3945.000000      26.000000      12.000000        26.000000
# max    4209.000000      30.000000      14.000000        30.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       9.000000           9.000000          9.000000           9.000000
# mean        0.925998          -0.023261          0.095528          -0.197489
# std         0.198212           0.024444          0.053589           0.259995
# ...

# %% [markdown]
# # "Global" average taking into account all intervals is 25,10,16

# %% [markdown]
# - Separate into 3 dataframes: 1h, 30m and 15m

# %%
results_peak_df_1h = results_peak_df[results_peak_df.interval_opt == '1h']
results_peak_df_1h
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4       3945           1h             26             10               30
# 5       4077           1h             28             10               28
# 6       4209           1h             30             10               26
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4       0.869411          -0.043768            0.0891           -0.49123
# 5       0.869411          -0.043768            0.0891           -0.49123
# 6       0.869411          -0.043768            0.0891           -0.49123
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 4                     1.154041                0.044848               0.060238
# 5                     1.154041                0.044848               0.060238
# 6                     1.154041                0.044848               0.060238
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# ...

# %%
results_peak_df_1h.describe()
# Out:
#        index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count        3.0            3.0            3.0              3.0
# mean      4077.0           28.0           10.0             28.0
# std        132.0            2.0            0.0              2.0
# min       3945.0           26.0           10.0             26.0
# 25%       4011.0           27.0           10.0             27.0
# 50%       4077.0           28.0           10.0             28.0
# 75%       4143.0           29.0           10.0             29.0
# max       4209.0           30.0           10.0             30.0
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       3.000000           3.000000            3.0000            3.00000
# mean        0.869411          -0.043768            0.0891           -0.49123
# std         0.000000           0.000000            0.0000            0.00000
# min         0.869411          -0.043768            0.0891           -0.49123
# ...

# %% [markdown]
# # 28,10, 28 for 1h interval as parameters average

# %% [markdown]
# # -------------

# %%
results_peak_df_30m = results_peak_df[results_peak_df.interval_opt == '30m']
results_peak_df_30m
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       1924          30m             20              8               12
# 1       1960          30m             20             12                8
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.698155          -0.043155          0.185884          -0.232163
# 1       0.698155          -0.043155          0.185884          -0.232163
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.585557                0.055379               0.143353
# 1                     1.585557                0.055379               0.143353
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.386311                         1.337602
# 1                0.386311                         1.337602
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# ...

# %% [markdown]
# Give priority to combinations type HIGH-LOW-HIGH

# %%
results_peak_df_30m.drop([1], axis=0, errors='ignore', inplace=True)
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_89297/3754968139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_peak_df_30m.drop([1], axis=0, errors='ignore', inplace=True)

# %%
results_peak_df_30m
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       1924          30m             20              8               12
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.698155          -0.043155          0.185884          -0.232163
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.585557                0.055379               0.143353
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.386311                         1.337602
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    0.034948                   0.143857
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 0                    0.242933        MM  2020-02-15-00:00  2020-04-19-00:00

# %% [markdown]
# # 20,8,12 for 30m (ideally find more combinations to average with)

# %%
results_peak_df_15m = results_peak_df[results_peak_df.interval_opt == '15m']
results_peak_df_15m
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 2        256          15m             18             14               22
# 3        520          15m             22             14               18
# 7        593          15m             24              8               12
# 8        629          15m             24             12                8
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2       0.921833          -0.004270          0.056452          -0.075632
# 3       0.921833          -0.004270          0.056452          -0.075632
# 7       1.242887           0.008404          0.053890           0.155941
# 8       1.242887           0.008404          0.053890           0.155941
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 2                     1.151061                0.007381               0.042781
# ...

# %%
results_peak_df_15m_filt = results_peak_df_15m.drop([2,8], axis=0, errors='ignore')
results_peak_df_15m_filt
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3        520          15m             22             14               18
# 7        593          15m             24              8               12
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3       0.921833          -0.004270          0.056452          -0.075632
# 7       1.242887           0.008404          0.053890           0.155941
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 3                     1.151061                0.007381               0.042781
# 7                     1.351336                0.011638               0.039303
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 3                 0.17253                         0.871657
# 7                 0.29611                         0.823845
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# ...

# %%
results_peak_df_15m_filt.describe()
# Out:
#         index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count    2.000000       2.000000       2.000000         2.000000
# mean   556.500000      23.000000      11.000000        15.000000
# std     51.618795       1.414214       4.242641         4.242641
# min    520.000000      22.000000       8.000000        12.000000
# 25%    538.250000      22.500000       9.500000        13.500000
# 50%    556.500000      23.000000      11.000000        15.000000
# 75%    574.750000      23.500000      12.500000        16.500000
# max    593.000000      24.000000      14.000000        18.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       2.000000           2.000000          2.000000           2.000000
# mean        1.082360           0.002067          0.055171           0.040154
# std         0.227019           0.008961          0.001811           0.163747
# ...

# %% [markdown]
# ## Regarding 15m interval, better results are 23,11,15 for average
