# %%
import pandas as pd
import sys
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = [file for file in os.listdir() if os.path.splitext(file)[1] == '.csv']

# %%
files
# Out:
# ['sideways_peak_ee.csv',
#  'sideways_peak_mm.csv',
#  'sideways_peak_nn.csv',
#  'sideways_peak_oo.csv',
#  'sideways_peak_gg.csv']

# %%
results_peak = []
for name in files:
    results_peak.append(utils.find_max(filename=name, type_max='max', type_trend='sideways', strategy='peak'))
# Out:
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 2662          30m             32              2               10
# 2734          30m             32             10                2
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 2662        1.03916            0.00452          0.075988           0.059481
# 2734        1.03916            0.00452          0.075988           0.059481
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 2662                     1.160205                 0.01749
# 2734                     1.160205                 0.01749
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 2662               0.047161                0.370867
# 2734               0.047161                0.370867
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 2662                         0.960629                   -0.004728
# ...

# %%
len(results)
# Out:
# 5

# %%
results_peak_df = pd.DataFrame(data=results[0])

# %%
results_peak_df = results_df.append(results[1])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28025/1667506964.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_df.append(results[1])

# %%
results_peak_df = results_df.append(results[2])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28025/377166083.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_df.append(results[2])

# %%
results_peak_df = results_df.append(results[3])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28025/1414158044.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_df.append(results[3])

# %%
results_peak_df = results_df.append(results[4])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28025/2895676197.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_df.append(results[4])

# %%
results_peak_df
# Out:
#      index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       2662.0          30m             32              2               10
# 1       2734.0          30m             32             10                2
# 2       1924.0          30m             20              8               12
# 3       1960.0          30m             20             12                8
# 4        256.0          15m             18             14               22
# 5        520.0          15m             22             14               18
# 6       3945.0           1h             26             10               30
# 7       4077.0           1h             28             10               28
# 8       4209.0           1h             30             10               26
# 9        593.0          15m             24              8               12
# 10       629.0          15m             24             12                8
# ...

# %%
results_peak_df.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count    11.000000      13.000000      13.000000        13.000000
# mean   2137.181818      24.923077      10.000000        15.076923
# std    1511.463848       4.517771       3.162278         8.854957
# min     256.000000      18.000000       2.000000         2.000000
# 25%     611.000000      22.000000       8.000000         8.000000
# 50%    1960.000000      24.000000      10.000000        12.000000
# 75%    3339.500000      28.000000      12.000000        22.000000
# max    4209.000000      32.000000      14.000000        30.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count      13.000000          13.000000         13.000000          13.000000
# mean        0.992160          -0.014115          0.086116          -0.103581
# std         0.200800           0.024565          0.046595           0.259491
# ...

# %%
results_peak_df.reset_index(inplace=True)

# %%
results_peak_df.rename(columns={'index': 'index_opt'}, inplace=True)

# %%
results_peak_df
# Out:
#     index_opt  index_opt interval_opt  macd_slow_opt  macd_fast_opt  \
# 0           0     2662.0          30m             32              2
# 1           1     2734.0          30m             32             10
# 2           2     1924.0          30m             20              8
# 3           3     1960.0          30m             20             12
# 4           4      256.0          15m             18             14
# 5           5      520.0          15m             22             14
# 6           6     3945.0           1h             26             10
# 7           7     4077.0           1h             28             10
# 8           8     4209.0           1h             30             10
# 9           9      593.0          15m             24              8
# 10         10      629.0          15m             24             12
# 11        593        NaN          15m             24              8
# 12        629        NaN          15m             24             12
#
# ...

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   index_opt                        11 non-null     int64
#  1   interval_opt                     11 non-null     object
#  2   macd_slow_opt                    11 non-null     int64
#  3   macd_fast_opt                    11 non-null     int64
#  4   macd_signal_opt                  11 non-null     int64
#  5   multiple_hold                    11 non-null     float64
#  6   ann_log_mean_hold                11 non-null     float64
#  7   ann_log_std_hold                 11 non-null     float64
#  8   sharpe_ratio_hold                11 non-null     float64
#  9   multiple_macd_peak_strategy      11 non-null     float64
#  10  ann_log_mean_macd_peak           11 non-null     float64
#  11  ann_log_std_macd_peak            11 non-null     float64
# ...

# %%
plt.bar(x=results_df.index, height=results_df.multiple_macd_peak_strategy_net)
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# - Separate into 2 dataframes 1 for 30m and another for 1h

# %%
results_peak_df_30m = results_df[results_df.interval_opt == '30m']
results_peak_df_30m
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       2662          30m             32              2               10
# 1       2734          30m             32             10                2
# 2       1924          30m             20              8               12
# 3       1960          30m             20             12                8
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.039160           0.004520          0.075988           0.059481
# 1       1.039160           0.004520          0.075988           0.059481
# 2       0.698155          -0.043155          0.185884          -0.232163
# 3       0.698155          -0.043155          0.185884          -0.232163
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.160205                0.017490               0.047161
# ...

# %%
results_peak_df_1h = results_df[results_df.interval_opt == '1h']
results_peak_df_1h
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 6       3945           1h             26             10               30
# 7       4077           1h             28             10               28
# 8       4209           1h             30             10               26
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 6       0.869411          -0.043768            0.0891           -0.49123
# 7       0.869411          -0.043768            0.0891           -0.49123
# 8       0.869411          -0.043768            0.0891           -0.49123
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 6                     1.154041                0.044848               0.060238
# 7                     1.154041                0.044848               0.060238
# 8                     1.154041                0.044848               0.060238
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# ...

# %% [markdown]
# - Since there are duplicated results, the ones that have the combination of parameters in the shape HIGH - LOW - HIGH are the ones chosen (just for shape preference taking into account other combinations observed that have same shape in other trends)

# %%
results_peak_df_1h_filt = results_peak_df_1h.drop([6,8], axis=0, errors='ignore')
results_peak_df_1h_filt
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 7       4077           1h             28             10               28
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 7       0.869411          -0.043768            0.0891           -0.49123
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 7                     1.154041                0.044848               0.060238
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 7                 0.74452                         1.098508
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 7                    0.029411                   0.060833
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 7                    0.483462        OO  2020-08-18-00:00  2020-10-06-00:00

# %% [markdown]
# # 28,10, 28 for 1h interval as parameters average

# %%
results_peak_df_30m_filt = results_peak_df_30m.drop([3,1], axis=0, errors='ignore')
results_peak_df_30m_filt
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       2662          30m             32              2               10
# 2       1924          30m             20              8               12
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.039160           0.004520          0.075988           0.059481
# 2       0.698155          -0.043155          0.185884          -0.232163
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.160205                0.017490               0.047161
# 2                     1.585557                0.055379               0.143353
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.370867                         0.960629
# 2                0.386311                         1.337602
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# ...

# %%
plt.bar(x=results_peak_df_30m_filt.index, height=results_peak_df_30m_filt.multiple_macd_peak_strategy)
# Out:
# <BarContainer object of 2 artists>

# %%
results_peak_df_30m_filt.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     2.000000       2.000000       2.000000         2.000000
# mean   2293.000000      26.000000       5.000000        11.000000
# std     521.844805       8.485281       4.242641         1.414214
# min    1924.000000      20.000000       2.000000        10.000000
# 25%    2108.500000      23.000000       3.500000        10.500000
# 50%    2293.000000      26.000000       5.000000        11.000000
# 75%    2477.500000      29.000000       6.500000        11.500000
# max    2662.000000      32.000000       8.000000        12.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       2.000000           2.000000          2.000000           2.000000
# mean        0.868658          -0.019318          0.130936          -0.086341
# std         0.241127           0.033712          0.077708           0.206224
# ...

# %% [markdown]
# # 26,5,11 average  for 30m interval as parameters average or
# # better results with single case -> 20, 8, 12

# %%
results_peak_df_15m = results_df[results_df.interval_opt == '15m']
results_peak_df_15m
# Out:
#     index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4         256          15m             18             14               22
# 5         520          15m             22             14               18
# 9         593          15m             24              8               12
# 10        629          15m             24             12                8
#
#     multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4        0.921833          -0.004270          0.056452          -0.075632
# 5        0.921833          -0.004270          0.056452          -0.075632
# 9        1.242887           0.008404          0.053890           0.155941
# 10       1.242887           0.008404          0.053890           0.155941
#
#     multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 4                      1.151061                0.007381
# 5                      1.151061                0.007381
# ...

# %%
results_peak_df_15m.describe()
# Out:
#         index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count    4.000000       4.000000       4.000000         4.000000
# mean   499.500000      22.000000      12.000000        15.000000
# std    168.547718       2.828427       2.828427         6.218253
# min    256.000000      18.000000       8.000000         8.000000
# 25%    454.000000      21.000000      11.000000        11.000000
# 50%    556.500000      23.000000      13.000000        15.000000
# 75%    602.000000      24.000000      14.000000        19.000000
# max    629.000000      24.000000      14.000000        22.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       4.000000           4.000000          4.000000           4.000000
# mean        1.082360           0.002067          0.055171           0.040154
# std         0.185361           0.007317          0.001479           0.133699
# ...

# %% [markdown]
# ## Regarding 15m interval, better results are 22,12,15 for average
