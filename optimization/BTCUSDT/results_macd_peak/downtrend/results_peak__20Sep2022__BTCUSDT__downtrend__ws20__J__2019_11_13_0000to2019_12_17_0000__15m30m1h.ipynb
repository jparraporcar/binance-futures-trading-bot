# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm/')
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_peak_opt_j = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
# df = pd.read_csv('downtrend_peak_j.csv')
# macd_opt_j.opt_results = df

# %%
macd_peak_opt_j.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2019-11-13-00:00', end_opt='2019-12-17-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='J', type_trend='downtrend_peak_j')
# Out:
# 3248
# 3268
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.902325               -0.011687               0.042539
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.274732                          0.72582
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.036438                   0.042878
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.849811
# processed 1 out of a total 4788
# 3248
# 3270
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.909861               -0.010741               0.041133
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.261132                         0.713448
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038393                   0.041727
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.920091
# processed 2 out of a total 4788
# 3248
# 3272
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.881576               -0.014332               0.041719
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.343535                         0.698359
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040823                   0.042319
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.964663
# processed 3 out of a total 4788
# 3248
# 3274
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.858245               -0.017382               0.041217
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.421714                         0.685682
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042906                   0.041824
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.025869
# processed 4 out of a total 4788
# 3248
# 3276
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.847527               -0.018811                 0.0418
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.450022                         0.679426
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043949                   0.042419
#
#    sharpe_ratio_macd_peak_net
# 0                    -1.03606
# processed 5 out of a total 4788
# 3248
# 3278
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.861493               -0.016952               0.043237
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.392083                         0.700082
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040543                    0.04382
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.925211
# processed 6 out of a total 4788
# 3248
# 3280
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.870682               -0.015746               0.043116
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.365203                         0.706347
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03953                   0.043708
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.904423
# processed 7 out of a total 4788
# 3248
# 3282
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.864527               -0.016553               0.042921
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.385657                         0.707343
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03937                   0.043506
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.904927
# processed 8 out of a total 4788
# 3248
# 3284
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.823334               -0.022104               0.039392
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.561127                         0.677084
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044341                   0.039983
#
#    sharpe_ratio_macd_peak_net
# 0                    -1.10899
# processed 9 out of a total 4788
# 3248
# 3286
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.801083               -0.025219               0.039174
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.643774                         0.661031
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04707                   0.039755
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.184002
# processed 10 out of a total 4788
# 3248
# 3288
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.842525               -0.019484               0.039482
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.493488                         0.697596
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040948                   0.040054
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.022325
# processed 11 out of a total 4788
# 3248
# 3290
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.826908               -0.021611               0.038245
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.565072                         0.684665
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043075                    0.03882
#
#    sharpe_ratio_macd_peak_net
# 0                    -1.10962
# processed 12 out of a total 4788
# 3248
# 3292
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.830589               -0.021106               0.038057
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.554603                         0.690056
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042183                   0.038628
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.092046
# processed 13 out of a total 4788
# 3248
# 3294
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.813387               -0.023486               0.037962
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.618671                         0.678067
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044176                   0.038531
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.146524
# processed 14 out of a total 4788
# 3248
# 3296
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.79931               -0.025471               0.038444
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.662557                         0.669739
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045581                   0.039001
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.168713
# processed 15 out of a total 4788
# 3248
# 3298
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.792125               -0.026498               0.038286
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.692109                         0.668249
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045835                   0.038828
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.180455
# processed 16 out of a total 4788
# 3248
# 3300
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.798773               -0.025548               0.038465
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.664177                         0.677305
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044304                   0.039008
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.135786
# processed 17 out of a total 4788
# 3248
# 3302
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.801613               -0.025144               0.038399
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.654808                         0.679713
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043901                   0.038943
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.127306
# processed 18 out of a total 4788
# 3248
# 3304
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.792613               -0.026428               0.038335
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.689401                         0.676669
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044411                   0.038865
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.142688
# processed 19 out of a total 4788
# 3248
# 3268
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.909861               -0.010741               0.041133
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.261132                         0.713448
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038393                   0.041727
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.920091
# processed 20 out of a total 4788
# 3248
# 3270
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.887772               -0.013536               0.042485
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                 -0.3186                         0.694945
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041381                   0.043159
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.958796
# processed 21 out of a total 4788
# 3248
# 3272
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.928008               -0.008496               0.043102
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.197104                         0.733891
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03518                   0.043818
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.802873
# processed 22 out of a total 4788
# 3248
# 3274
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.895815                -0.01251               0.043014
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.290844                         0.715698
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038035                   0.043707
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.870215
# processed 23 out of a total 4788
# 3248
# 3276
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.866479               -0.016296               0.042963
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.379307                         0.694619
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041434                    0.04365
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.949226
# processed 24 out of a total 4788
# 3248
# 3278
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.909049               -0.010843               0.040953
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.264762                         0.732472
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                     -0.0354                   0.041687
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.849187
# processed 25 out of a total 4788
# 3248
# 3280
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.903915               -0.011487               0.040733
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.281997                         0.734556
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035077                    0.04144
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.846465
# processed 26 out of a total 4788
# 3248
# 3282
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.870995               -0.015705               0.036852
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.426165                         0.715063
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038136                   0.037586
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.014632
# processed 27 out of a total 4788
# 3248
# 3284
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.835753               -0.020402               0.037037
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.550846                         0.691989
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041865                   0.037723
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.109822
# processed 28 out of a total 4788
# 3248
# 3286
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.775657               -0.028887               0.035784
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.807265                         0.645515
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04977                    0.03645
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.365441
# processed 29 out of a total 4788
# 3248
# 3288
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.785829               -0.027405               0.035724
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.767134                         0.656209
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047902                   0.036382
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.316639
# processed 30 out of a total 4788
# 3248
# 3290
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.789399                -0.02689               0.035618
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.754945                          0.65919
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047387                   0.036279
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.306176
# processed 31 out of a total 4788
# 3248
# 3292
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.807006               -0.024382               0.035547
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.685904                         0.673892
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044879                   0.036202
#
#    sharpe_ratio_macd_peak_net
# 0                    -1.23967
# processed 32 out of a total 4788
# 3248
# 3294
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.798713               -0.025556                0.03511
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.727884                         0.672662
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045086                   0.035726
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.261994
# processed 33 out of a total 4788
# 3248
# 3296
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.806237                -0.02449                0.03537
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.692389                         0.681312
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043633                    0.03599
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.212363
# processed 34 out of a total 4788
# 3248
# 3298
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.789651               -0.026854               0.035486
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.75673                          0.66957
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04561                   0.036104
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.263313
# processed 35 out of a total 4788
# 3248
# 3300
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.795731               -0.025981               0.035577
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.730277                         0.677024
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044351                   0.036187
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.225597
# processed 36 out of a total 4788
# 3248
# 3302
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.788953               -0.026954                0.03544
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.760555                         0.673544
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044937                    0.03604
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.246863
# processed 37 out of a total 4788
# 3248
# 3304
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.77941               -0.028338               0.035611
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.795752                         0.665397
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046321                   0.036208
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.279304
# processed 38 out of a total 4788
# 3248
# 3268
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.881576               -0.014332               0.041719
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.343535                         0.698359
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040823                   0.042319
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.964663
# processed 39 out of a total 4788
# 3248
# 3270
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.928008               -0.008496               0.043102
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.197104                         0.733891
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03518                   0.043818
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.802873
# processed 40 out of a total 4788
# 3248
# 3272
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.889945               -0.013258               0.042871
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.309251                           0.7098
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038976                   0.043593
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.894078
# processed 41 out of a total 4788
# 3248
# 3274
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.883534                -0.01408               0.040898
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.344266                         0.709497
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039024                   0.041636
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.937268
# processed 42 out of a total 4788
# 3248
# 3276
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.862962               -0.016759               0.040874
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.410008                         0.701275
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04035                   0.041592
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.970134
# processed 43 out of a total 4788
# 3248
# 3278
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.857901               -0.017427               0.041172
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.423283                         0.704313
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039858                    0.04185
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.952414
# processed 44 out of a total 4788
# 3248
# 3280
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.783083               -0.027803               0.037129
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.748827                         0.655029
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048107                   0.037761
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.273991
# processed 45 out of a total 4788
# 3248
# 3282
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.771222               -0.029539                0.03749
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.78792                         0.646205
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049649                     0.0381
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.303129
# processed 46 out of a total 4788
# 3248
# 3284
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.779681               -0.028298               0.037298
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.758699                         0.656635
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047828                   0.037916
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.261422
# processed 47 out of a total 4788
# 3248
# 3286
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.770275               -0.029678               0.035887
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.826992                         0.654252
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048242                   0.036493
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.321933
# processed 48 out of a total 4788
# 3248
# 3288
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.751444               -0.032493               0.035836
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.906707                         0.648101
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049316                   0.036379
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.355612
# processed 49 out of a total 4788
# 3248
# 3290
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.762269               -0.030867               0.035285
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.874777                           0.6608
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047109                   0.035831
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.314751
# processed 50 out of a total 4788
# 3248
# 3292
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.751509               -0.032483               0.035703
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.909819                          0.64926
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049113                   0.036252
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.354764
# processed 51 out of a total 4788
# 3248
# 3294
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.753785               -0.032139               0.035901
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.895218                         0.652335
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048575                   0.036471
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.331898
# processed 52 out of a total 4788
# 3248
# 3296
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.750932                -0.03257                0.03582
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.909285                         0.649866
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049007                   0.036395
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.346525
# processed 53 out of a total 4788
# 3248
# 3298
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.749863               -0.032732               0.035839
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.91332                          0.65226
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048588                   0.036397
#
#    sharpe_ratio_macd_peak_net
# 0                    -1.33495
# processed 54 out of a total 4788
# 3248
# 3300
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.754976                -0.03196               0.036315
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.880064                         0.656708
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047816                    0.03686
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.297218
# processed 55 out of a total 4788
# 3248
# 3302
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.759134               -0.031335               0.036391
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.861073                         0.660325
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047191                   0.036942
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.277436
# processed 56 out of a total 4788
# 3248
# 3304
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.763609               -0.030667               0.036459
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.841126                         0.663088
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046716                   0.037023
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.261804
# processed 57 out of a total 4788
# 3248
# 3268
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.858245               -0.017382               0.041217
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.421714                         0.685682
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042906                   0.041824
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.025869
# processed 58 out of a total 4788
# 3248
# 3270
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.895815                -0.01251               0.043014
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.290844                         0.715698
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038035                   0.043707
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.870215
# processed 59 out of a total 4788
# 3248
# 3272
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.883534                -0.01408               0.040898
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.344266                         0.709497
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039024                   0.041636
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.937268
# processed 60 out of a total 4788
# 3248
# 3274
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.853908               -0.017958               0.040998
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.438021                         0.696282
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041162                   0.041706
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.986964
# processed 61 out of a total 4788
# 3248
# 3276
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.845169               -0.019128               0.041085
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.465559                         0.697409
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040978                   0.041728
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.982023
# processed 62 out of a total 4788
# 3248
# 3278
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.789935               -0.026813               0.037013
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.724414                          0.66076
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047116                   0.037661
#
#    sharpe_ratio_macd_peak_net
# 0                    -1.25107
# processed 63 out of a total 4788
# 3248
# 3280
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.787714               -0.027133               0.037044
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.732455                         0.665659
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046276                   0.037668
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.228536
# processed 64 out of a total 4788
# 3248
# 3282
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.745291               -0.033428               0.036459
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.916845                         0.634109
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.051798                   0.037054
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.397877
# processed 65 out of a total 4788
# 3248
# 3284
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.726949               -0.036261               0.036447
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.994887                         0.624846
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.053471                   0.036995
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.445335
# processed 66 out of a total 4788
# 3248
# 3286
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.744714               -0.033516               0.035929
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.932837                         0.647782
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049372                   0.036448
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.354588
# processed 67 out of a total 4788
# 3248
# 3288
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.72519               -0.036537               0.036318
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -1.006004                         0.630799
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.052393                   0.036852
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.421713
# processed 68 out of a total 4788
# 3248
# 3290
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.757927               -0.031516               0.036177
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.871172                         0.658154
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047566                   0.036745
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.294463
# processed 69 out of a total 4788
# 3248
# 3292
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.745898               -0.033335               0.036338
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.917359                         0.653239
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048418                   0.036864
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.313404
# processed 70 out of a total 4788
# 3248
# 3294
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.76053               -0.031126               0.036665
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.848923                         0.668324
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045822                   0.037162
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.233034
# processed 71 out of a total 4788
# 3248
# 3296
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.808728          -0.024132          0.056896          -0.424134
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.771397               -0.029513                0.03649
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                 -0.8088                         0.677873
#
# ...
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.927639               -0.034185               0.093107
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.367156                         0.904275
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045794                   0.093531
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.489612
# processed 4757 out of a total 4788
# 813
# 885
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.933042               -0.031542               0.092991
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.339193                          0.91109
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042377                   0.093398
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.453726
# processed 4758 out of a total 4788
# 813
# 887
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.912959               -0.041445               0.088324
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.469232                         0.889965
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.053054                   0.088809
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.597395
# processed 4759 out of a total 4788
# 813
# 889
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.894037               -0.050976               0.088719
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.574581                          0.87152
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.062585                   0.089222
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.701455
# processed 4760 out of a total 4788
# 813
# 891
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.892912               -0.051549               0.088785
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.580602                         0.870424
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.063158                    0.08926
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.707574
# processed 4761 out of a total 4788
# 813
# 855
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.978878               -0.009716               0.080165
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.121199                         0.939731
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.028291                   0.080646
#
#    sharpe_ratio_macd_peak_net
# 0                     -0.3508
# processed 4762 out of a total 4788
# 813
# 857
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.033245                0.014884               0.086204
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.172665                         0.990238
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.004464                   0.086743
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.051467
# processed 4763 out of a total 4788
# 813
# 859
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.078152                0.034247               0.087931
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.389471                         1.040328
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    0.017994                   0.088459
#
#    sharpe_ratio_macd_peak_net
# 0                     0.20341
# processed 4764 out of a total 4788
# 813
# 861
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.986695               -0.006096               0.088377
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.068976                          0.95208
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.022349                   0.088816
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.25163
# processed 4765 out of a total 4788
# 813
# 863
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.029987                0.013447               0.090864
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.147989                         0.998937
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.000484                    0.09137
#
#    sharpe_ratio_macd_peak_net
# 0                     -0.0053
# processed 4766 out of a total 4788
# 813
# 865
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.033486                 0.01499                0.09061
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.165439                         1.004036
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    0.001833                   0.091023
#
#    sharpe_ratio_macd_peak_net
# 0                     0.02014
# processed 4767 out of a total 4788
# 813
# 867
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.957463               -0.019783               0.094166
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.210084                         0.933349
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.031392                   0.094538
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.332059
# processed 4768 out of a total 4788
# 813
# 869
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.944825                -0.02583               0.094347
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.273778                         0.921029
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.037439                   0.094902
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.394506
# processed 4769 out of a total 4788
# 813
# 871
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.926034               -0.034973               0.094331
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.370747                         0.902711
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046582                   0.094855
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.491089
# processed 4770 out of a total 4788
# 813
# 873
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.915906               -0.039978               0.094246
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.424183                         0.894358
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.050813                   0.094729
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.536402
# processed 4771 out of a total 4788
# 813
# 875
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.927583               -0.034212               0.094467
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.362159                          0.90576
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045047                   0.094964
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.474364
# processed 4772 out of a total 4788
# 813
# 877
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.944199               -0.026132               0.093161
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.280502                         0.920418
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.037741                   0.093685
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.402851
# processed 4773 out of a total 4788
# 813
# 879
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.946761               -0.024898               0.093114
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.267398                         0.922916
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.036508                   0.093649
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.389834
# processed 4774 out of a total 4788
# 813
# 881
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.923396               -0.036271                0.09373
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.386973                          0.90014
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04788                   0.094215
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.508201
# processed 4775 out of a total 4788
# 813
# 883
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.923671               -0.036136               0.093644
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.385882                          0.90194
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046971                   0.094105
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.499131
# processed 4776 out of a total 4788
# 813
# 885
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.895904               -0.050027               0.089006
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.562063                         0.873339
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.061636                    0.08953
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.68844
# processed 4777 out of a total 4788
# 813
# 887
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.907516               -0.044166                0.08877
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.497533                         0.886165
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.055001                   0.089253
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.616236
# processed 4778 out of a total 4788
# 813
# 889
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.938783                -0.02875               0.084548
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.340041                         0.916696
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039585                    0.08506
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.465379
# processed 4779 out of a total 4788
# 813
# 891
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.940847                -0.02775               0.084799
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.327249                         0.918712
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038586                   0.085315
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.452274
# processed 4780 out of a total 4788

# %% [markdown]
# ### 2) Extract combinations of max

# %%
# macd_opt_j.opt_results[macd_opt_j.opt_results.multiple_macd_strategy == macd_opt_j.opt_results.multiple_macd_strategy.max()]

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
# macd_opt_j_15m = Macd_long_backtester('BTCUSDT')

# %%
# macd_opt_j_15m.prepare_data(start='2019-11-13-00:00', end='2019-12-17-00:00', interval='15m')

# %%
# macd_opt_j_15m.execute_backtest(start='2019-11-13-00:00', ema_slow=36, ema_fast=6, ema_signal=20)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
# macd_opt_j_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
# macd_opt_j_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
# plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
# macd_opt_j.opt_results[macd_opt_j.opt_results.multiple_macd_strategy_net == macd_opt_j.opt_results.multiple_macd_strategy_net.max()]

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %%
# macd_opt_j_15m_v2 = Macd_long_backtester('BTCUSDT')

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %%
# macd_opt_j_15m_v2.prepare_data(start='2019-11-13-00:00', end='2019-12-17-00:00', interval='15m')

# %%
# macd_opt_j_15m_v2.execute_backtest(start='2019-11-13-00:00', ema_slow=24, ema_fast=14, ema_signal=26)

# %% [markdown]
# ### 8) Further...
