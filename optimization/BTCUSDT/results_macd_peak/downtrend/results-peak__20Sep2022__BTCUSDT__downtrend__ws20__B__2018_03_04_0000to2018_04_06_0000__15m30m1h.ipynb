# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm/')
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_peak_opt_b = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
macd_peak_opt_b.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-03-04-00:00', end_opt='2018-04-06-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='B', type_trend='downtrend_peak_b')
# Out:
# 3169
# 3189
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.967204               -0.003887               0.086136
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.04513                          0.76294
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.031543                   0.086413
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.365023
# processed 1 out of a total 4788
# 3169
# 3191
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.739825               -0.035129               0.080979
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.433807                         0.574717
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.064569                   0.081541
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.791855
# processed 2 out of a total 4788
# 3169
# 3193
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.774431                 -0.0298               0.084123
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.354243                         0.614526
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.056761                   0.084688
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.670241
# processed 3 out of a total 4788
# 3169
# 3195
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.759346               -0.032093               0.082903
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.387115                          0.61289
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.057072                   0.083465
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.683782
# processed 4 out of a total 4788
# 3169
# 3197
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.926405               -0.008912               0.086065
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.103544                         0.746458
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.034089                    0.08664
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.393455
# processed 5 out of a total 4788
# 3169
# 3199
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.91488               -0.010371               0.085141
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.121809                         0.739683
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035152                   0.085658
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.410374
# processed 6 out of a total 4788
# 3169
# 3201
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.92858               -0.008638               0.085254
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.101322                         0.753317
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.033022                   0.085771
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.385008
# processed 7 out of a total 4788
# 3169
# 3203
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.936962               -0.007591               0.085526
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.088751                         0.765305
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.031182                   0.086064
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.362311
# processed 8 out of a total 4788
# 3169
# 3205
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.000889                0.000104                0.08578
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.001207                         0.820305
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.023091                   0.086324
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.267496
# processed 9 out of a total 4788
# 3169
# 3207
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.897608               -0.012593                0.08459
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.148868                         0.741941
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.034796                   0.085148
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.408659
# processed 10 out of a total 4788
# 3169
# 3209
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.993356               -0.000777               0.083455
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.009311                         0.819689
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.023179                   0.084024
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.275859
# processed 11 out of a total 4788
# 3169
# 3211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.953884               -0.005504               0.083672
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.06578                         0.787117
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.027906                   0.084242
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.331257
# processed 12 out of a total 4788
# 3169
# 3213
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.992666               -0.000858               0.083073
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.01033                         0.820513
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.023062                   0.083645
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.275711
# processed 13 out of a total 4788
# 3169
# 3215
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      1.03652                0.004181               0.081753
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.051147                         0.861144
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.017427                   0.082332
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.211673
# processed 14 out of a total 4788
# 3169
# 3217
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      1.02289                0.002638               0.081764
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.032268                         0.854167
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.018376                    0.08233
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.223195
# processed 15 out of a total 4788
# 3169
# 3219
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      1.00688                0.000799               0.081825
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.009769                         0.846537
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.019422                   0.082369
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.23579
# processed 16 out of a total 4788
# 3169
# 3221
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.007365                0.000855               0.081143
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.010542                         0.848386
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.019167                   0.081679
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.234667
# processed 17 out of a total 4788
# 3169
# 3223
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     1.031138                0.003575               0.080904
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                0.044183                         0.868407
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.016448                   0.081463
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.201911
# processed 18 out of a total 4788
# 3169
# 3225
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.990328               -0.001133               0.081531
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.013896                         0.838304
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.020561                   0.082072
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.250527
# processed 19 out of a total 4788
# 3169
# 3189
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.739825               -0.035129               0.080979
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.433807                         0.574717
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.064569                   0.081541
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.791855
# processed 20 out of a total 4788
# 3169
# 3191
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.778061               -0.029255               0.082923
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.352796                         0.613221
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.057009                   0.083574
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.682142
# processed 21 out of a total 4788
# 3169
# 3193
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.886276               -0.014074               0.086501
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.162703                         0.704474
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040837                   0.087114
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.468779
# processed 22 out of a total 4788
# 3169
# 3195
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.841424               -0.020128               0.087634
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.229683                         0.673387
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046098                   0.088256
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.522325
# processed 23 out of a total 4788
# 3169
# 3197
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.89489               -0.012946               0.085713
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.151042                         0.718616
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03852                   0.086351
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.446089
# processed 24 out of a total 4788
# 3169
# 3199
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.942456               -0.006909               0.083978
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.082272                         0.769792
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                     -0.0305                   0.084598
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.360534
# processed 25 out of a total 4788
# 3169
# 3201
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.896683               -0.012713               0.083031
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.153112                         0.736151
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03571                   0.083668
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.426801
# processed 26 out of a total 4788
# 3169
# 3203
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.902764               -0.011925               0.081912
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.145583                         0.747473
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03393                   0.082538
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.411085
# processed 27 out of a total 4788
# 3169
# 3205
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.947182               -0.006326               0.081896
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.077242                         0.786922
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.027935                   0.082543
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.338426
# processed 28 out of a total 4788
# 3169
# 3207
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.905116               -0.011622               0.081831
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.142022                         0.754535
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.032834                    0.08246
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.39818
# processed 29 out of a total 4788
# 3169
# 3209
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.880666               -0.014814               0.080831
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.183273                         0.737908
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035432                   0.081451
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.435006
# processed 30 out of a total 4788
# 3169
# 3211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.890027               -0.013581               0.081231
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.167197                         0.748292
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.033803                   0.081843
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.413018
# processed 31 out of a total 4788
# 3169
# 3213
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                       0.8523               -0.018631               0.081399
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.228884                         0.716573
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038852                   0.082016
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.473712
# processed 32 out of a total 4788
# 3169
# 3215
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.860895               -0.017461                 0.0815
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.214248                         0.727501
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.037088                   0.082109
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.451686
# processed 33 out of a total 4788
# 3169
# 3217
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.895114               -0.012917               0.080711
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.160042                         0.756419
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.032543                   0.081324
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.400169
# processed 34 out of a total 4788
# 3169
# 3219
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.929335               -0.008543               0.081317
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.105063                         0.785337
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.02817                   0.081916
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.343885
# processed 35 out of a total 4788
# 3169
# 3221
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.970937               -0.003438               0.081161
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.042364                         0.820492
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.023065                   0.081771
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.282063
# processed 36 out of a total 4788
# 3169
# 3223
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.980726               -0.002269               0.081454
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.027854                         0.827357
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.022093                    0.08208
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.269169
# processed 37 out of a total 4788
# 3169
# 3225
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.981903               -0.002129               0.081378
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.026162                         0.831172
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.021557                   0.081995
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.262907
# processed 38 out of a total 4788
# 3169
# 3189
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.774431                 -0.0298               0.084123
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.354243                         0.614526
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.056761                   0.084688
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.670241
# processed 39 out of a total 4788
# 3169
# 3191
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.886276               -0.014074               0.086501
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.162703                         0.704474
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040837                   0.087114
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.468779
# processed 40 out of a total 4788
# 3169
# 3193
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.84915               -0.019062               0.085691
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.222455                         0.677263
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045429                   0.086386
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.525885
# processed 41 out of a total 4788
# 3169
# 3195
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.866263               -0.016736               0.083973
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.199308                         0.701568
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041319                   0.084666
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.488023
# processed 42 out of a total 4788
# 3169
# 3197
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.834888               -0.021037               0.082819
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.254014                         0.684255
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.044232                   0.083478
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.529865
# processed 43 out of a total 4788
# 3169
# 3199
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.869079               -0.016358               0.081534
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.200629                         0.718359
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038562                   0.082197
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.469135
# processed 44 out of a total 4788
# 3169
# 3201
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.903686               -0.011806                0.08205
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.143888                         0.750785
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.033415                   0.082691
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.404093
# processed 45 out of a total 4788
# 3169
# 3203
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.921916               -0.009478               0.081422
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.116403                         0.771159
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.030294                    0.08206
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.369163
# processed 46 out of a total 4788
# 3169
# 3205
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.859146               -0.017698               0.081095
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.218239                         0.723559
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.037721                   0.081747
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.461438
# processed 47 out of a total 4788
# 3169
# 3207
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.920278               -0.009685               0.082004
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.118104                         0.775043
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.029708                    0.08265
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.359441
# processed 48 out of a total 4788
# 3169
# 3209
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.910074               -0.010985               0.081784
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.134317                         0.770369
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.030413                   0.082432
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.368945
# processed 49 out of a total 4788
# 3169
# 3211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.93963               -0.007259               0.081992
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.088534                         0.795388
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.026687                    0.08266
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.322857
# processed 50 out of a total 4788
# 3169
# 3213
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.878625               -0.015085               0.081224
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.185716                         0.748824
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03372                   0.081872
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.411857
# processed 51 out of a total 4788
# 3169
# 3215
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.911852               -0.010757               0.081594
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.13184                         0.778466
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.029194                   0.082239
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.354992
# processed 52 out of a total 4788
# 3169
# 3217
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.973802               -0.003095               0.082652
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.037444                         0.832768
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.021333                   0.083286
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.256147
# processed 53 out of a total 4788
# 3169
# 3219
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.915047                -0.01035               0.081707
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.126667                         0.781193
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.028786                   0.082335
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.349627
# processed 54 out of a total 4788
# 3169
# 3221
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.899971               -0.012286               0.082123
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.149608                         0.768323
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.030723                   0.082763
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.371221
# processed 55 out of a total 4788
# 3169
# 3223
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.935099               -0.007823               0.082497
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.094823                         0.798311
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.02626                   0.083139
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.315853
# processed 56 out of a total 4788
# 3169
# 3225
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.913881               -0.010498               0.082177
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.127752                         0.781525
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.028737                   0.082813
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.347012
# processed 57 out of a total 4788
# 3169
# 3189
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.759346               -0.032093               0.082903
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.387115                          0.61289
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.057072                   0.083465
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.683782
# processed 58 out of a total 4788
# 3169
# 3191
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.841424               -0.020128               0.087634
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.229683                         0.673387
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046098                   0.088256
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.522325
# processed 59 out of a total 4788
# 3169
# 3193
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.866263               -0.016736               0.083973
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.199308                         0.701568
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041319                   0.084666
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.488023
# processed 60 out of a total 4788
# 3169
# 3195
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.878436                -0.01511               0.083072
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.181886                         0.721171
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038106                   0.083751
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.454995
# processed 61 out of a total 4788
# 3169
# 3197
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.835918               -0.020893               0.081869
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.255205                         0.693304
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                     -0.0427                   0.082541
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.517325
# processed 62 out of a total 4788
# 3169
# 3199
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.931112               -0.008321               0.081776
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.10175                         0.777527
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.029335                   0.082447
#
#    sharpe_ratio_macd_peak_net
# 0                     -0.3558
# processed 63 out of a total 4788
# 3169
# 3201
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.800789               -0.025898               0.082018
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.315763                         0.675559
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045723                    0.08271
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.552811
# processed 64 out of a total 4788
# 3169
# 3203
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.844317               -0.019728               0.082666
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.238646                         0.714706
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039156                    0.08338
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.469612
# processed 65 out of a total 4788
# 3169
# 3205
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.84927               -0.019046               0.082331
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.231334                         0.721348
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038078                   0.083035
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.458573
# processed 66 out of a total 4788
# 3169
# 3207
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.827781               -0.022034               0.081285
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.271067                           0.7091
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040074                   0.081973
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.48887
# processed 67 out of a total 4788
# 3169
# 3209
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.840077               -0.020315               0.081314
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.24983                         0.723314
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03776                   0.081975
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.460632
# processed 68 out of a total 4788
# 3169
# 3211
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.842555               -0.019971               0.081253
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.245793                         0.725447
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.037417                   0.081915
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.456783
# processed 69 out of a total 4788
# 3169
# 3213
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.912085               -0.010728               0.080332
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.133542                         0.787988
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.027777                   0.080987
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.342978
# processed 70 out of a total 4788
# 3169
# 3215
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.90571               -0.011545               0.080537
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.143353                         0.782481
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.028594                   0.081177
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.352249
# processed 71 out of a total 4788
# 3169
# 3217
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.591327          -0.061228          0.119675          -0.511618
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.886683                -0.01402               0.080705
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.173723                         0.767347
#
# ...
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.745765               -0.136919               0.192671
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.710638                          0.73008
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.146841                   0.193029
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.760719
# processed 4757 out of a total 4788
# 793
# 865
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.745765               -0.136919               0.192671
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.710638                          0.73008
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.146841                   0.193029
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.760719
# processed 4758 out of a total 4788
# 793
# 867
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.834228               -0.084598               0.188337
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.449183                         0.816682
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.09452                   0.188712
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.500869
# processed 4759 out of a total 4788
# 793
# 869
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.834228               -0.084598               0.188337
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.449183                         0.816682
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.09452                   0.188712
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.500869
# processed 4760 out of a total 4788
# 793
# 871
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.801119               -0.103501               0.186299
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.555562                         0.785604
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.112629                   0.186628
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.603493
# processed 4761 out of a total 4788
# 793
# 835
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.747137               -0.136061               0.176107
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.772609                         0.712395
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.158286                   0.176583
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.896384
# processed 4762 out of a total 4788
# 793
# 837
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.849196               -0.076298               0.181317
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.420798                         0.811086
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.097729                   0.181847
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.537425
# processed 4763 out of a total 4788
# 793
# 839
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.729083               -0.147478               0.190433
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.774439                          0.70231
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.164941                   0.190943
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.863821
# processed 4764 out of a total 4788
# 793
# 841
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.722416               -0.151766               0.187423
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.809756                         0.697072
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.168435                   0.187955
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.896148
# processed 4765 out of a total 4788
# 793
# 843
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.730457                 -0.1466               0.192394
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.76198                         0.707232
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.161681                   0.192915
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.838097
# processed 4766 out of a total 4788
# 793
# 845
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.712151               -0.158446               0.191329
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.828133                         0.691858
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.17194                   0.191894
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.896015
# processed 4767 out of a total 4788
# 793
# 847
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.726436               -0.149176               0.191572
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.778694                          0.70814
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.161082                   0.192075
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.838641
# processed 4768 out of a total 4788
# 793
# 849
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.720106               -0.153261               0.195767
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.782877                         0.701969
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.165168                   0.196235
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.841682
# processed 4769 out of a total 4788
# 793
# 851
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.714827               -0.156695               0.196191
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.798687                         0.697417
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.168204                   0.196622
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.855471
# processed 4770 out of a total 4788
# 793
# 853
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.756174               -0.130449               0.194376
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.671118                         0.739012
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.141165                   0.194772
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.724772
# processed 4771 out of a total 4788
# 793
# 855
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.743687               -0.138222               0.194188
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.711792                         0.726808
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.148937                   0.194586
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.765406
# processed 4772 out of a total 4788
# 793
# 857
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.747986               -0.135531               0.192457
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.704216                          0.73101
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.146247                   0.192858
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.758311
# processed 4773 out of a total 4788
# 793
# 859
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.796502               -0.106198               0.189607
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.560095                         0.779749
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.11612                   0.189976
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.611235
# processed 4774 out of a total 4788
# 793
# 861
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.814223               -0.095927               0.189492
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.506233                         0.797098
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.105849                   0.189827
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.557608
# processed 4775 out of a total 4788
# 793
# 863
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.841583               -0.080501               0.188506
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.427048                         0.823882
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.090423                   0.188829
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.478863
# processed 4776 out of a total 4788
# 793
# 865
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.838153               -0.082407               0.188585
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.436976                         0.820524
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.092329                   0.188899
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.488777
# processed 4777 out of a total 4788
# 793
# 867
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.798903               -0.104793               0.186381
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.562253                         0.783431
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.113921                   0.186686
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.61023
# processed 4778 out of a total 4788
# 793
# 869
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.797512               -0.105607               0.186077
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.567541                         0.782067
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.114735                   0.186379
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.615597
# processed 4779 out of a total 4788
# 793
# 871
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.593626          -0.243103          0.241127          -1.008196
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.787693               -0.111389               0.187928
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.59272                         0.772438
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.120517                   0.188262
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.640155
# processed 4780 out of a total 4788

# %%
# df = pd.read_csv('downtrend_peak_b.csv')
# macd_opt_b.opt_results = df

# %% [markdown]
# ### 2) Extract combinations of max

# %%
# macd_opt_b.opt_results[macd_opt_b.opt_results.multiple_macd_strategy == macd_opt_b.opt_results.multiple_macd_strategy.max()]

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
# macd_opt_b_1h = Macd_long_backtester('BTCUSDT')

# %%
# macd_opt_b_1h.prepare_data(start='2018-03-04-00:00', end='2018-04-06-00:00', interval='1h')

# %%
# macd_opt_b_1h.execute_backtest(start='2018-03-04-00:00', ema_slow=24, ema_fast=14, ema_signal=24)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
# macd_opt_b_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
# macd_opt_b_1h.data_init.macd_log_returns_acum.plot(figsize=(15,10))
# plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
# macd_opt_b.opt_results[macd_opt_b.opt_results.multiple_macd_strategy_net == macd_opt_b.opt_results.multiple_macd_strategy_net.max()]

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %% [markdown]
# max and max_net are the same combination

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %% [markdown]
# ### 8) Carry out backtest with optimized strategy macd_peak with same parameters and see results

# %%
# sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm')
# from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm

# %%
# macd_opt_b_1h_peak = Macd_long_backtester_1stpkbm('BTCUSDT')

# %%
# macd_opt_b_1h_peak.prepare_data(start='2018-03-04-00:00', end='2018-04-06-00:00', interval='1h')

# %%
# macd_opt_b_1h_peak.execute_backtest(start='2018-03-04-00:00', ema_slow=24, ema_fast=14, ema_signal=24)

# %% [markdown]
# ### 9) Plot results of macd_peak acum vs macd acum vs hold

# %%
# macd_opt_b_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
# macd_opt_b_1h.data_init.macd_log_returns_acum.plot(figsize=(15,10))
# macd_opt_b_1h_peak.data_init.macd_peak_log_returns_acum.plot(figsize=(15,10))
# plt.legend()

# %%
# macd_opt_b_1h_peak.data_init
