# %%
import pandas as pd
import sys
sys.path.append('/Users/jp/Desktop/Investment/utils')
import utils as utils
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = [file for file in os.listdir() if os.path.splitext(file)[1] == '.csv']

# %%
files
# Out:
# ['downtrend_peak_j.csv',
#  'downtrend_peak_f.csv',
#  'downtrend_peak_b.csv',
#  'downtrend_peak_c.csv',
#  'downtrend_peak_a.csv']

# %%
results_peak = []
for name in files:
    results_peak.append(utils.find_max(filename=name, type_max='max', type_trend='downtrend', strategy='peak'))
# Out:
# newmax      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3615           1h             22              4               28
# 4011           1h             28              4               22
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3615       0.806879          -0.097537          0.112425          -0.867577
# 4011       0.806879          -0.097537          0.112425          -0.867577
#
#       multiple_macd_peak_strategy  ann_log_mean_macd_peak  \
# 3615                     1.108469                0.046867
# 4011                     1.108469                0.046867
#
#       ann_log_std_macd_peak  sharpe_ratio_macd_peak  \
# 3615               0.085073                0.550906
# 4011               0.085073                0.550906
#
#       multiple_macd_peak_strategy_net  ann_log_mean_macd_peak_net  \
# 3615                          1.06595                    0.029066
# ...

# %%
len(results_peak)
# Out:
# 5

# %%
results_peak_df = pd.DataFrame(data=results_peak[0])

# %%
results_peak_df = results_peak_df.append(results_peak[1])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28186/2549901859.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[1])

# %%
results_peak_df = results_peak_df.append(results_peak[2])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28186/2895677857.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[2])

# %%
results_peak_df = results_peak_df.append(results_peak[3])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28186/2168530471.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[3])

# %%
results_peak_df = results_peak_df.append(results_peak[4])
# Out:
# /var/folders/x3/hrhy35c93hb19c1q4dglf1fm0000gn/T/ipykernel_28186/3063767121.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_peak_df = results_peak_df.append(results_peak[4])

# %%
results_peak_df
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3615           1h             22              4               28
# 4011           1h             28              4               22
# 398           15m             22              2                2
# 2806          30m             34              4                6
# 2824          30m             34              6                4
# 1609          30m             16              4                6
# 1627          30m             16              6                4
# 1464          15m             38              2                4
# 1482          15m             38              4                2
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3615       0.806879          -0.097537          0.112425          -0.867577
# 4011       0.806879          -0.097537          0.112425          -0.867577
# 398        0.501985          -0.070188          0.101641          -0.690546
# ...

# %%
results_df.describe()
# Out:
#          index_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# count     4.000000       4.000000            4.0         4.000000
# mean   2643.000000      31.500000            3.5        14.000000
# std    1360.657929       7.895146            1.0        12.961481
# min    1464.000000      22.000000            2.0         2.000000
# 25%    1477.500000      26.500000            3.5         3.500000
# 50%    2548.500000      33.000000            4.0        13.000000
# 75%    3714.000000      38.000000            4.0        23.500000
# max    4011.000000      38.000000            4.0        28.000000
#
#        multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# count       4.000000           4.000000          4.000000           4.000000
# mean        0.659754          -0.093145          0.158481          -0.650750
# std         0.169886           0.005071          0.053181           0.250370
# ...

# %%
results_peak_df.reset_index(inplace=True)

# %%
results_peak_df.rename(columns={'index': 'index_opt'}, inplace=True)

# %%
results_peak_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       3615           1h             22              4               28
# 1       4011           1h             28              4               22
# 2        398          15m             22              2                2
# 3       2806          30m             34              4                6
# 4       2824          30m             34              6                4
# 5       1609          30m             16              4                6
# 6       1627          30m             16              6                4
# 7       1464          15m             38              2                4
# 8       1482          15m             38              4                2
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
# 1       0.806879          -0.097537          0.112425          -0.867577
# ...

# %%
plt.bar(x=results_peak_df.index, height=results_peak_df.multiple_macd_peak_strategy)
# Out:
# <BarContainer object of 9 artists>

# %%
cond1 = results_peak_df.index != 2
cond2 = results_peak_df.index != 5
cond3 = results_peak_df.index != 6
results_peak_df = results_peak_df[cond1&cond2&cond3]

# %%
results_peak_df
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0       3615           1h             22              4               28
# 1       4011           1h             28              4               22
# 3       2806          30m             34              4                6
# 4       2824          30m             34              6                4
# 7       1464          15m             38              2                4
# 8       1482          15m             38              4                2
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.806879          -0.097537          0.112425          -0.867577
# 1       0.806879          -0.097537          0.112425          -0.867577
# 3       0.589082          -0.123342          0.170489          -0.723463
# 4       0.589082          -0.123342          0.170489          -0.723463
# 7       0.512629          -0.088753          0.204537          -0.433923
# ...

# %%
cond1 = results_peak_df.index == 1
results_peak_df_1h = results_peak_df[cond1]
results_peak_df_1h
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1       4011           1h             28              4               22
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 1       0.806879          -0.097537          0.112425          -0.867577
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 1                     1.108469                0.046867               0.085073
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 1                0.550906                          1.06595
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 1                    0.029066                   0.085601
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 1                    0.339557         J  2019-11-13-00:00  2019-12-17-00:00

# %% [markdown]
# Find the average of these 2 combinations

# %% [markdown]
# ##  Parameters for 1h -> 28, 4, 22 (returns < 1)

# %%
cond1 = results_peak_df.index == 3
results_peak_df_30 = results_peak_df[cond1]
results_peak_df_30
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 3       2806          30m             34              4                6
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 3       0.589082          -0.123342          0.170489          -0.723463
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 3                     1.162645                0.035147               0.119681
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 3                 0.29367                         1.033921
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 3                     0.00778                   0.120386
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 3                    0.064625         B  2018-03-04-00:00  2018-04-06-00:00

# %% [markdown]
# ## Parameters for 30m (only one measure) -> 34, 4, 6

# %%
cond1 = results_peak_df.index == 7
results_peak_df_15 = results_peak_df[cond1]
results_peak_df_15
# Out:
#    index_opt interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 7       1464          15m             38              2                4
#
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 7       0.512629          -0.088753          0.204537          -0.433923
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 7                     1.629106                0.064846               0.158022
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 7                0.410358                         1.317136
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 7                    0.036601                   0.158425
#
#    sharpe_ratio_macd_peak_net trend_ref         start_opt           end_opt
# 7                    0.231031         A  2018-01-07-00:00  2018-02-05-00:00

# %% [markdown]
# ## Parameters for 15m (only one measure) -> 38, 2, 4
