# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm/')
from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_peak_opt_c = Macd_long_backtester_1stpkbm('BTCUSDT')
# Out:
# class version 1.0 is being used

# %%
# df = pd.read_csv('downtrend_peak_c.csv')
# macd_opt_c.opt_results = df

# %%
macd_peak_opt_c.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-05-06-00:00', end_opt='2018-06-28-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='C', type_trend='downtrend_peak_c')
# Out:
# 5042
# 5062
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                       0.7701               -0.019055               0.045987
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.414351                         0.549472
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043677                   0.046305
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.943252
# processed 1 out of a total 4788
# 5042
# 5064
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.84857               -0.011977               0.048156
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.248718                         0.581247
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039577                   0.048654
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.813428
# processed 2 out of a total 4788
# 5042
# 5066
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.865717               -0.010518               0.049042
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.214469                         0.610385
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.036009                   0.049584
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.726214
# processed 3 out of a total 4788
# 5042
# 5068
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.871504               -0.010032               0.049307
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.203459                         0.616559
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035275                   0.049879
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.707209
# processed 4 out of a total 4788
# 5042
# 5070
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.866216               -0.010476               0.048824
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.214566                         0.623329
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.034478                   0.049403
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.697897
# processed 5 out of a total 4788
# 5042
# 5072
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.809386               -0.015426               0.046083
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.334735                         0.590411
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.038436                   0.046682
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.823349
# processed 6 out of a total 4788
# 5042
# 5074
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.774568               -0.018633               0.045515
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.409381                         0.573727
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040526                   0.046088
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.879328
# processed 7 out of a total 4788
# 5042
# 5076
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.759917               -0.020026               0.044962
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.445398                         0.567682
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041299                   0.045546
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.906749
# processed 8 out of a total 4788
# 5042
# 5078
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.746645               -0.021311               0.045222
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.471253                         0.561574
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042088                   0.045806
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.918839
# processed 9 out of a total 4788
# 5042
# 5080
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.752545               -0.020737               0.045457
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.456185                         0.574741
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040398                   0.046009
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.878036
# processed 10 out of a total 4788
# 5042
# 5082
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.745034               -0.021469               0.045381
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.473073                         0.568038
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041253                   0.045937
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.898043
# processed 11 out of a total 4788
# 5042
# 5084
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.725386               -0.023418               0.045541
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.514217                         0.556833
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042707                   0.046085
#
#    sharpe_ratio_macd_peak_net
# 0                     -0.9267
# processed 12 out of a total 4788
# 5042
# 5086
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.733053               -0.022651               0.045681
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.495859                         0.566559
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041444                   0.046222
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.896611
# processed 13 out of a total 4788
# 5042
# 5088
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.727229               -0.023233               0.045733
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.508011                         0.564933
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041653                   0.046257
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.900474
# processed 14 out of a total 4788
# 5042
# 5090
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.727615               -0.023194               0.045737
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.507117                         0.563313
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041863                    0.04627
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.904745
# processed 15 out of a total 4788
# 5042
# 5092
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.736195               -0.022339               0.045673
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.489108                         0.570926
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040884                   0.046198
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.884963
# processed 16 out of a total 4788
# 5042
# 5094
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.73203               -0.022753               0.045336
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.501878                          0.56963
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041049                   0.045851
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.895269
# processed 17 out of a total 4788
# 5042
# 5096
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.743083                -0.02166                0.04545
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.476559                         0.576268
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040204                   0.045975
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.87448
# processed 18 out of a total 4788
# 5042
# 5098
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.72897               -0.023059               0.045682
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.504758                         0.567249
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041355                     0.0462
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.89513
# processed 19 out of a total 4788
# 5042
# 5062
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.84857               -0.011977               0.048156
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.248718                         0.581247
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039577                   0.048654
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.813428
# processed 20 out of a total 4788
# 5042
# 5064
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.947735               -0.003916                0.04873
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.080352                          0.64149
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.032383                   0.049422
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.65524
# processed 21 out of a total 4788
# 5042
# 5066
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.883227               -0.009057               0.048601
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.186364                         0.619562
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03492                   0.049262
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.708868
# processed 22 out of a total 4788
# 5042
# 5068
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.701442               -0.025866               0.046117
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.560885                         0.507339
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049497                   0.046766
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.058389
# processed 23 out of a total 4788
# 5042
# 5070
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.689404               -0.027129               0.046105
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.588422                         0.508912
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049271                   0.046728
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.054405
# processed 24 out of a total 4788
# 5042
# 5072
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.642192               -0.032304               0.046849
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.689523                         0.480554
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.053453                   0.047449
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.126533
# processed 25 out of a total 4788
# 5042
# 5074
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.637616               -0.032825               0.044987
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.72966                         0.482023
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.05323                   0.045609
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.167095
# processed 26 out of a total 4788
# 5042
# 5076
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.655734               -0.030781               0.044705
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.688547                         0.500804
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.050442                   0.045311
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.113251
# processed 27 out of a total 4788
# 5042
# 5078
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.681073               -0.028016               0.044217
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.633605                         0.521041
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047553                   0.044814
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.061119
# processed 28 out of a total 4788
# 5042
# 5080
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.676742               -0.028481               0.044414
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.641266                         0.521262
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047522                   0.044989
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.056294
# processed 29 out of a total 4788
# 5042
# 5082
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.666162               -0.029631               0.044926
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.659535                         0.515737
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048299                   0.045497
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.061586
# processed 30 out of a total 4788
# 5042
# 5084
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.671236               -0.029077               0.044825
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.648684                         0.522323
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047373                   0.045392
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.043646
# processed 31 out of a total 4788
# 5042
# 5086
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.713983               -0.024574               0.044357
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.554004                         0.556532
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042746                    0.04493
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.951386
# processed 32 out of a total 4788
# 5042
# 5088
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.731647               -0.022791               0.044152
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.516197                         0.571272
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040839                   0.044725
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.91313
# processed 33 out of a total 4788
# 5042
# 5090
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.702517               -0.025755               0.043712
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.589186                         0.552271
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043307                   0.044267
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.978302
# processed 34 out of a total 4788
# 5042
# 5092
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.717156                -0.02425               0.043495
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.557544                         0.564738
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041678                   0.044054
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.946083
# processed 35 out of a total 4788
# 5042
# 5094
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.716853               -0.024281               0.043641
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.556382                         0.565461
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041585                   0.044194
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.940967
# processed 36 out of a total 4788
# 5042
# 5096
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.724216               -0.023536               0.043705
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.538519                         0.569329
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041088                   0.044272
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.928078
# processed 37 out of a total 4788
# 5042
# 5098
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.726296               -0.023327               0.043707
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.533704                         0.571936
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.040755                   0.044263
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.920729
# processed 38 out of a total 4788
# 5042
# 5062
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.865717               -0.010518               0.049042
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.214469                         0.610385
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.036009                   0.049584
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.726214
# processed 39 out of a total 4788
# 5042
# 5064
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.883227               -0.009057               0.048601
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.186364                         0.619562
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03492                   0.049262
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.708868
# processed 40 out of a total 4788
# 5042
# 5066
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.681551               -0.027965               0.046011
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.607781                         0.492952
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.051595                   0.046663
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.105694
# processed 41 out of a total 4788
# 5042
# 5068
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.658499               -0.030474               0.046819
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.650892                         0.487754
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.052368                   0.047445
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.103761
# processed 42 out of a total 4788
# 5042
# 5070
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.654893               -0.030875               0.045932
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.672192                         0.490059
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.052024                   0.046597
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.116483
# processed 43 out of a total 4788
# 5042
# 5072
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.672791               -0.028908               0.043648
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.662313                         0.512957
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.048693                   0.044332
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.098382
# processed 44 out of a total 4788
# 5042
# 5074
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.682342                -0.02788               0.043721
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.637681                         0.524682
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047045                   0.044373
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.060204
# processed 45 out of a total 4788
# 5042
# 5076
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.681655               -0.027954               0.043816
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.637972                         0.526835
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046746                   0.044467
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.051247
# processed 46 out of a total 4788
# 5042
# 5078
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.68197                -0.02792               0.043963
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.635073                         0.530676
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.046216                   0.044584
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.036612
# processed 47 out of a total 4788
# 5042
# 5080
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.686867               -0.027398               0.044033
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.622215                         0.535396
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04557                   0.044662
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.020334
# processed 48 out of a total 4788
# 5042
# 5082
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.682373               -0.027877               0.043723
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.63757                         0.535524
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.045553                   0.044337
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.027418
# processed 49 out of a total 4788
# 5042
# 5084
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.696405               -0.026392                0.04445
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.593751                         0.549331
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.043696                   0.045037
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.970215
# processed 50 out of a total 4788
# 5042
# 5086
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.704603               -0.025538               0.044598
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.572632                         0.557691
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.042594                   0.045175
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.942877
# processed 51 out of a total 4788
# 5042
# 5088
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.734852               -0.022472               0.043224
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.519902                         0.581633
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.039528                   0.043817
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.902125
# processed 52 out of a total 4788
# 5042
# 5090
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.735602               -0.022398               0.043037
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.520433                         0.583218
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03933                   0.043627
#
#    sharpe_ratio_macd_peak_net
# 0                     -0.9015
# processed 53 out of a total 4788
# 5042
# 5092
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.721849               -0.023775               0.042954
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.553493                          0.57622
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04021                   0.043534
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.923657
# processed 54 out of a total 4788
# 5042
# 5094
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.766157               -0.019429               0.042556
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.456557                         0.613673
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035617                   0.043134
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.825727
# processed 55 out of a total 4788
# 5042
# 5096
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.791527               -0.017053               0.043001
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.396579                         0.632916
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.033365                   0.043581
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.765581
# processed 56 out of a total 4788
# 5042
# 5098
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.785082                -0.01765               0.043612
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.404692                         0.625631
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.034209                   0.044201
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.773947
# processed 57 out of a total 4788
# 5042
# 5062
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.871504               -0.010032               0.049307
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.203459                         0.616559
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035275                   0.049879
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.707209
# processed 58 out of a total 4788
# 5042
# 5064
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.701442               -0.025866               0.046117
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.560885                         0.507339
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049497                   0.046766
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.058389
# processed 59 out of a total 4788
# 5042
# 5066
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.658499               -0.030474               0.046819
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.650892                         0.487754
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.052368                   0.047445
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.103761
# processed 60 out of a total 4788
# 5042
# 5068
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.67021               -0.029189               0.045419
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.642657                         0.504943
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.049842                   0.046081
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.081614
# processed 61 out of a total 4788
# 5042
# 5070
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.682904                -0.02782                0.04384
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.634577                         0.521554
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047481                   0.044511
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.066723
# processed 62 out of a total 4788
# 5042
# 5072
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                      0.67302               -0.028883               0.043763
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.660002                         0.521047
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047552                   0.044408
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.070788
# processed 63 out of a total 4788
# 5042
# 5074
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.662039               -0.030083               0.044229
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.680172                         0.515167
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.04838                    0.04486
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.078451
# processed 64 out of a total 4788
# 5042
# 5076
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.667289               -0.029507               0.044512
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.662911                         0.523685
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047183                   0.045125
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.045622
# processed 65 out of a total 4788
# 5042
# 5078
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.659327               -0.030383               0.044183
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.687656                         0.520969
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.047563                   0.044774
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.062272
# processed 66 out of a total 4788
# 5042
# 5080
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.711847               -0.024792               0.044687
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.554802                         0.563425
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.041848                   0.045277
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.924277
# processed 67 out of a total 4788
# 5042
# 5082
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.773622               -0.018722               0.043496
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.43043                         0.612319
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035778                   0.044119
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.810943
# processed 68 out of a total 4788
# 5042
# 5084
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.776387               -0.018462               0.043317
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.426207                         0.616602
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.03527                   0.043945
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.802585
# processed 69 out of a total 4788
# 5042
# 5086
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.769332               -0.019128               0.043111
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.443686                          0.61308
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.035687                   0.043728
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.816129
# processed 70 out of a total 4788
# 5042
# 5088
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.861588               -0.010867               0.043511
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.249743                         0.690111
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.027054                   0.044111
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.613323
# processed 71 out of a total 4788
# 5042
# 5090
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.617234          -0.035188          0.065108          -0.540453
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.848247               -0.012005               0.043883
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.27357                          0.68174
#
# ...
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.787774               -0.069599               0.109361
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.636415                         0.758201
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.080763                   0.109678
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.736368
# processed 4757 out of a total 4788
# 1262
# 1334
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.804935               -0.063311               0.109017
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.58075                         0.774718
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.074475                   0.109331
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.681194
# processed 4758 out of a total 4788
# 1262
# 1336
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.802515                -0.06419               0.109055
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.588604                         0.772388
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.075354                   0.109369
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.688988
# processed 4759 out of a total 4788
# 1262
# 1338
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.816079                 -0.0593               0.109812
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.54001                          0.78678
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.069967                   0.110071
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.635658
# processed 4760 out of a total 4788
# 1262
# 1340
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.788045               -0.069499               0.110684
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.627904                         0.759753
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.080167                   0.110975
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.722382
# processed 4761 out of a total 4788
# 1262
# 1304
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.685659               -0.110105               0.091531
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -1.202922                         0.648241
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.126479                   0.091866
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.376772
# processed 4762 out of a total 4788
# 1262
# 1306
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.673983               -0.115117               0.101898
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -1.129727                          0.63666
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.131738                   0.102289
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.287902
# processed 4763 out of a total 4788
# 1262
# 1308
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.699767               -0.104163               0.107173
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.971911                         0.663268
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.119792                   0.107572
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.113606
# processed 4764 out of a total 4788
# 1262
# 1310
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.683809               -0.110894                0.10781
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -1.028598                         0.651458
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.125034                    0.10816
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.156012
# processed 4765 out of a total 4788
# 1262
# 1312
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.706526               -0.101358               0.109214
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.928071                         0.675393
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.114507                   0.109474
#
#    sharpe_ratio_macd_peak_net
# 0                   -1.045972
# processed 4766 out of a total 4788
# 1262
# 1314
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.751964               -0.083173                0.10996
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.756392                         0.721277
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.095329                   0.110217
#
#    sharpe_ratio_macd_peak_net
# 0                    -0.86492
# processed 4767 out of a total 4788
# 1262
# 1316
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.734119                -0.09018               0.109741
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.821754                          0.70536
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.10184                   0.110026
#
#    sharpe_ratio_macd_peak_net
# 0                     -0.9256
# processed 4768 out of a total 4788
# 1262
# 1318
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.756319               -0.081488               0.109843
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.741862                          0.72669
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.093148                   0.110103
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.846006
# processed 4769 out of a total 4788
# 1262
# 1320
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.736703               -0.089155               0.110567
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.806349                         0.707842
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.100815                   0.110851
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.909465
# processed 4770 out of a total 4788
# 1262
# 1322
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.790966                -0.06842               0.109666
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.623889                         0.759979
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.08008                   0.110002
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.727986
# processed 4771 out of a total 4788
# 1262
# 1324
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.788704               -0.069255               0.109622
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.631762                         0.757806
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.080915                    0.10996
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.735856
# processed 4772 out of a total 4788
# 1262
# 1326
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.790096               -0.068741               0.109675
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.626768                         0.759143
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.080401                   0.109997
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.730936
# processed 4773 out of a total 4788
# 1262
# 1328
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.791923               -0.068067               0.110028
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.61863                         0.760899
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.079727                   0.110345
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.722518
# processed 4774 out of a total 4788
# 1262
# 1330
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.794043               -0.067287               0.109611
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.613866                         0.764235
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.07845                   0.109893
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.713879
# processed 4775 out of a total 4788
# 1262
# 1332
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.775565               -0.074156               0.108417
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.683996                          0.74645
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                    -0.08532                   0.108709
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.784851
# processed 4776 out of a total 4788
# 1262
# 1334
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.761126                -0.07964               0.109725
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.725809                           0.7338
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.090307                   0.110031
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.820747
# processed 4777 out of a total 4788
# 1262
# 1336
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.767028               -0.077386               0.109693
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0                -0.70548                          0.73949
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.088054                   0.109977
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.800657
# processed 4778 out of a total 4788
# 1262
# 1338
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.765115               -0.078114                0.10988
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.710909                         0.737646
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.088782                   0.110169
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.805875
# processed 4779 out of a total 4788
# 1262
# 1340
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.613704          -0.142339          0.133825          -1.063616
#
#    multiple_macd_peak_strategy  ann_log_mean_macd_peak  ann_log_std_macd_peak  \
# 0                     0.764074               -0.078512               0.109901
#
#    sharpe_ratio_macd_peak  multiple_macd_peak_strategy_net  \
# 0               -0.714388                         0.736642
#
#    ann_log_mean_macd_peak_net  ann_log_std_macd_peak_net  \
# 0                   -0.089179                   0.110195
#
#    sharpe_ratio_macd_peak_net
# 0                   -0.809284
# processed 4780 out of a total 4788

# %% [markdown]
# ### 2) Extract combinations of max

# %%
# macd_opt_c.opt_results[macd_opt_c.opt_results.multiple_macd_strategy == macd_opt_c.opt_results.multiple_macd_strategy.max()]

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max

# %%
# macd_opt_c_15m = Macd_long_backtester('BTCUSDT')

# %%
# macd_opt_c_15m.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='15m')

# %%
# macd_opt_c_15m.execute_backtest(start='2018-05-06-00:00', ema_slow=18, ema_fast=2, ema_signal=2)

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %%
# macd_opt_c_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
# macd_opt_c_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
# plt.legend()

# %% [markdown]
# ### 5) Extract combinations of max_net

# %%
# macd_opt_c.opt_results[macd_opt_c.opt_results.multiple_macd_strategy_net == macd_opt_c.opt_results.multiple_macd_strategy_net.max()]

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %%
# macd_opt_c_1h = Macd_long_backtester('BTCUSDT')

# %%
# macd_opt_c_1h.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='1h')

# %%
# macd_opt_c_1h.execute_backtest(start='2018-05-06-00:00', ema_slow=28, ema_fast=14, ema_signal=18)

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %%
# macd_opt_c_1h.data_init.multiple_hold_acum.plot(figsize=(15,10))
# macd_opt_c_1h.data_init.macd_log_returns_acum.plot(figsize=(15,10))
# plt.legend()

# %% [markdown]
# ### 8) Carry out backtest with optimized strategy macd_peak with same parameters and see results

# %%
# sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester_1stpkbm')
# from macd_long_backtester_1stpkbm import Macd_long_backtester_1stpkbm

# %% [markdown]
# ### 9) Plot results of macd_peak acum vs macd acum vs hold

# %%
# macd_opt_c_15m_peak = Macd_long_backtester_1stpkbm('BTCUSDT')

# %%
# macd_opt_c_15m_peak.prepare_data(start='2018-05-06-00:00', end='2018-06-28-00:00', interval='15m')

# %%
# macd_opt_c_15m_peak.execute_backtest(start='2018-05-06-00:00', ema_slow=18, ema_fast=2, ema_signal=2)

# %%
# macd_opt_c_15m.data_init.multiple_hold_acum.plot(figsize=(15,10))
# macd_opt_c_15m.data_init.macd_log_returns_acum.plot(figsize=(15,10))
# macd_opt_c_15m_peak.data_init.macd_peak_log_returns_acum.plot()
# plt.legend()
