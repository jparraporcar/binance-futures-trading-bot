# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
down = Macd_long_backtester('BTCUSDT')

# %%
down.prepare_data(start='2018-01-01-00:00', end='2022-09-20-00:00', interval='1d')
# Out:
# 1723

# %%
down.assign_trends(window_size=20,plot=True)

# %%
a_down = down.get_trend_dates(type_trend='Down Trend', trend_ref='A', do_plot=True)
a_down
# Out:
# date_init: 2018-01-07 00:00:00 1515283200000
# date_end: 2018-02-05 00:00:00 1517788800000
# (1515283200000, 1517788800000)

# %%
b_down = down.get_trend_dates(type_trend='Down Trend', trend_ref='B', do_plot=True)
b_down
# Out:
# date_init: 2018-03-04 00:00:00 1520121600000
# date_end: 2018-04-06 00:00:00 1522972800000
# (1520121600000, 1522972800000)

# %%
c_down = down.get_trend_dates(type_trend='Down Trend', trend_ref='C', do_plot=True)
c_down
# Out:
# date_init: 2018-05-06 00:00:00 1525564800000
# date_end: 2018-06-28 00:00:00 1530144000000
# (1525564800000, 1530144000000)

# %%
f_down = down.get_trend_dates(type_trend='Down Trend', trend_ref='F', do_plot=True)
f_down
# Out:
# date_init: 2018-11-07 00:00:00 1541548800000
# date_end: 2018-12-15 00:00:00 1544832000000
# (1541548800000, 1544832000000)

# %%
j_down = down.get_trend_dates(type_trend='Down Trend', trend_ref='J', do_plot=True)
j_down
# Out:
# date_init: 2019-11-13 00:00:00 1573603200000
# date_end: 2019-12-17 00:00:00 1576540800000
# (1573603200000, 1576540800000)
