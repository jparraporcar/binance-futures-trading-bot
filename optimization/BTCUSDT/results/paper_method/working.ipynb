# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Calculating interval for subperiods

# %%
macd_td = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_td.prepare_data(start='2016-01-29-20:00', end='2023-09-11-20:00', interval='1d')
# Out:
# 1859

# %%
mindate = macd_td.data_init.index[0]

# %%
maxdate = macd_td.data_init.index[-1]

# %%
total_days = maxdate - mindate
total_days
# Out:
# Timedelta('1858 days 00:00:00')

# %%
total_subperiod = total_days/3
total_subperiod
# Out:
# Timedelta('619 days 08:00:00')

# %%
subperiod1 = (mindate, mindate + total_subperiod)
subperiod1
# Out:
# (Timestamp('2017-08-17 00:00:00'), Timestamp('2019-04-28 08:00:00'))

# %%
subperiod2 = (mindate + total_subperiod, mindate + total_subperiod*2)
subperiod2
# Out:
# (Timestamp('2019-04-28 08:00:00'), Timestamp('2021-01-06 16:00:00'))

# %%
subperiod3 = (mindate + total_subperiod*2, mindate + total_subperiod*3)
subperiod3
# Out:
# (Timestamp('2021-01-06 16:00:00'), Timestamp('2022-09-18 00:00:00'))

# %% [markdown]
# ### Running optimization for subperiod1

# %%
macd_subperiod1 = Macd_long_backtester('BTCUSDT')

# %%
subperiod1
# Out:
# (Timestamp('2017-08-17 00:00:00'), Timestamp('2019-04-28 08:00:00'))

# %%
macd_subperiod1.execute_opt(start_opt='2017-08-17-00:00', end_opt='2019-04-28-00:00', interval_opt=('4h', '1d', '1w'), ema_fast_opt=(3,20,1), ema_slow_opt=(5,40,1), ema_sign_opt=(3,40,1), int_for_max='4h', type_trend='paper_method', trend_ref='subperiod1')
# Out:
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.00196           0.000193          0.259417
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.000745                    0.419482              -0.085746
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.261931              -0.327361
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.507855           0.040536          0.256643
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.157946                    0.691408              -0.036423
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.258983               -0.14064
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.199128           0.017924           0.26123
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.068613                    0.580596              -0.053664
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.263517              -0.203647
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.697473           0.052227          0.256119
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.203918                    0.853217              -0.015668
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.258374              -0.060641
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.449141           0.036616          0.256081
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.142985                    0.752315              -0.028091
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.258283              -0.108759
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.643715           0.049051          0.257733
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.190316                    0.888875              -0.011627
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.259871              -0.044741
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.526965           0.041779          0.252613
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.165386                    0.839903               -0.01722
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.254677              -0.067617
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.269399           0.023545          0.251943
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.093453                     0.70539              -0.034447
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.253971              -0.135635
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.202813           0.018227          0.252468
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.072194                    0.672951              -0.039094
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.254503               -0.15361
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.322076           0.027558          0.251662
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.109504                    0.748534              -0.028588
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.253692              -0.112688
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.375174           0.031445          0.251856
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.124851                    0.787921              -0.023526
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.253873               -0.09267
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.57903           0.045088          0.254297
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.177305                    0.921806              -0.008036
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.256316              -0.031353
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.530485           0.042006           0.25426
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.165209                    0.904166              -0.009943
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.256254              -0.038803
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.448441           0.036568          0.253903
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.144023                    0.855697              -0.015382
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.255832              -0.060124
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.430539            0.03534          0.253876
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.139203                       0.848              -0.016273
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.25581              -0.063615
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.791118           0.057527          0.252528
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.227807                    1.076288               0.007256
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.254414               0.028522
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                  1.7073           0.052797          0.252111
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.20942                    1.032924               0.003197
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.25399               0.012588
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.746912           0.055061          0.252515
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.21805                    1.058689               0.005629
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.2544               0.022127
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.74372            0.05488          0.253766
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.216264                    1.063967                0.00612
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.25565               0.023939
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.974773           0.067162          0.252556
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.26593                    1.217306               0.019409
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.254429               0.076284
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.849458           0.060691          0.253283
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.239618                    1.143943               0.013274
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.255148               0.052023
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.71788           0.053407          0.253261
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.210877                     1.05895               0.005653
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.255175               0.022155
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.971619           0.067004          0.253447
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.264372                    1.224698               0.020006
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.251292               0.053574
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.809893           0.058557          0.247314
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.236771                    1.187115                0.01693
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.248992               0.067994
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.921007           0.064438          0.247268
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.260598                    1.266439               0.023314
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.248924               0.093661
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 2.19019           0.077381          0.243802
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.317394                    1.448819               0.036594
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.245459               0.149082
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.177804           0.076821          0.243862
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.31502                    1.443078               0.036202
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.245525               0.147446
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.458448           0.088785          0.243417
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.364746                    1.631814               0.048334
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.245063                0.19723
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.511219           0.090882          0.243553
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.37315                    1.669678               0.050598
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.24519               0.206361
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.653174           0.096309          0.243558
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.395426                    1.764062               0.056025
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.245197                0.22849
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.855878           0.103576          0.244738
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.423211                    1.905307               0.063628
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.246366               0.258265
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.655856           0.096409          0.244807
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.393815                    1.768851               0.056293
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.246438               0.228426
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                     1.0                0.0               0.0
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0                NaN                         1.0                    0.0
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                   0.0                    NaN
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:327: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd = ann_log_mean_macd / ann_log_std_macd
# /Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:332: RuntimeWarning: invalid value encountered in double_scalars
#   sharpe_ratio_macd_net = ann_log_mean_macd_net / ann_log_std_macd_net
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# ...
# 0               0.25198               0.080672
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.948208           0.065825          0.250793
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.262469                    1.367783               0.030913
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.252109               0.122616
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.905536           0.063639          0.250128
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.254427                    1.351544               0.029734
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.251438               0.118255
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.042862           0.070508          0.250625
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.281328                    1.463806               0.037609
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.251926               0.149287
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.119362           0.074137           0.25074
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.295671                    1.516041                0.04107
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.251974               0.162993
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.158407           0.075938          0.250228
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.303477                    1.538729               0.042536
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.251446               0.169167
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.611056            0.09473          0.246532
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.384248                    1.861422               0.061328
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.247724               0.247564
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.840931           0.103058          0.246578
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.417952                    2.028747               0.069824
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.247738               0.281844
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.852659           0.103465          0.247184
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.418572                    2.040589               0.070398
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.248327                0.28349
# 3699
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0        1.21438           0.019171          0.382426           0.050131
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                2.735726           0.099333          0.247149
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.401917                    1.963611               0.066603
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.248266               0.268272
# HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fd3286d96d0>, 'Connection to api.binance.com timed out. (connect timeout=10)'))
# Something went wrong. Error occured at 2022-09-18 04:54:23.424357+00:00. Wait for 1 min.
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x7fd3286d96d0>, 'Connection to api.binance.com timed out. (connect timeout=10)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fd3286d96d0>, 'Connection to api.binance.com timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:356, in Macd_long_backtester.execute_opt(self, start_opt, end_opt, interval_opt, ema_slow_opt, ema_fast_opt, ema_sign_opt, int_for_max, type_trend, trend_ref)
#     355 try:
# --> 356     self.prepare_data(start=start_opt, end=end_opt, interval=comb[0])
#     357     tuple_results = (*self.execute_backtest(comb[1], comb[2], comb[3]), trend_ref, start_opt, end_opt)
#
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:123, in Macd_long_backtester.prepare_data(self, start, end, interval)
#     122 to_time = int(datetime.strptime(end, "%Y-%m-%d-%H:%M").timestamp()*1000)
# --> 123 self.data_init = utils.get_history_v2(symbol=self.symbol, interval=interval, start=from_time, end=to_time)[0]
#     124 self.data_init['log_returns_hold'] = np.log(self.data_init.Close.div(self.data_init.Close.shift(1)))
#
# File ~/Desktop/Investment/utils/utils.py:90, in get_history_v2(symbol, interval, start, end)
#      89 api_secret = "LeiOCoJdBuCtfgrt1WfsBweeyC2ZwuogPuDrkXFTioEGoaZYOGkju1GRM3yVqp7v"
# ---> 90 client = Client(api_key=api_key, api_secret=api_secret)
#      92 try:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:300, in Client.__init__(self, api_key, api_secret, requests_params, tld, testnet)
#     299 # init DNS and SSL cert
# --> 300 self.ping()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:526, in Client.ping(self)
#     513 """Test connectivity to the Rest API.
#     514
#     515 https://binance-docs.github.io/apidocs/spot/en/#test-connectivity
#    (...)
#     524
#     525 """
# --> 526 return self._get('ping', version=self.PRIVATE_API_VERSION)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:371, in Client._get(self, path, signed, version, **kwargs)
#     370 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 371     return self._request_api('get', path, signed, version, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:334, in Client._request_api(self, method, path, signed, version, **kwargs)
#     333 uri = self._create_api_uri(path, signed, version)
# --> 334 return self._request(method, uri, signed, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:314, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     312 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
# --> 314 self.response = getattr(self.session, method)(uri, **kwargs)
#     315 return self._handle_response(self.response)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:553, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     552     if not isinstance(e.reason, NewConnectionError):
# --> 553         raise ConnectTimeout(e, request=request)
#     555 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fd3286d96d0>, 'Connection to api.binance.com timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 macd_subperiod1.execute_opt(start_opt='2017-08-17-00:00', end_opt='2019-04-28-00:00', interval_opt=('4h', '1d', '1w'), ema_fast_opt=(3,20,1), ema_slow_opt=(5,40,1), ema_sign_opt=(3,40,1), int_for_max='4h', type_trend='paper_method', trend_ref='subperiod1')
#
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:363, in Macd_long_backtester.execute_opt(self, start_opt, end_opt, interval_opt, ema_slow_opt, ema_fast_opt, ema_sign_opt, int_for_max, type_trend, trend_ref)
#     361         print('Something went wrong. Error occured at %s. Wait for 1 min.' % (datetime.now().astimezone(timezone.utc)))
#     362         time.sleep(60)
# --> 363         client = Client(api_key, api_secret)
#     365 combinations_df = pd.DataFrame(data=combinations, columns=['interval_opt', 'macd_slow_opt', 'macd_fast_opt', 'macd_signal_opt'])
#     366 many_results_df = pd.DataFrame(data=results, columns = ['multiple_hold', 'ann_log_mean_hold', 'ann_log_std_hold', 'sharpe_ratio_hold', 'multiple_macd_strategy', 'ann_log_mean_macd', 'ann_log_std_macd', 'sharpe_ratio_macd', 'multiple_macd_strategy_net', 'ann_log_mean_macd_net', 'ann_log_std_macd_net', 'sharpe_ratio_macd_net', 'trend_ref', 'start_opt', 'end_opt'])
#
# NameError: name 'Client' is not defined

# %%
pd.set_option('display.max_rows', None)

# %%
macd_subperiod1.opt_results.info()

# %%
macd_subperiod1.opt_results[macd_subperiod1.opt_results.multiple_macd_strategy == macd_subperiod1.opt_results.multiple_macd_strategy.max()]

# %%
macd_subperiod1.data_init.Close.plot(figsize=(15,10))

# %% [markdown]
# ### Implementing parameters obtained in opt of subperiod1 in subperiod 2: the problem is that subperiod2 has a very big part that is uptrend.

# %%
macd_subperiod2 = Macd_long_backtester('BTCUSDT')

# %%
macd_subperiod2.prepare_data(start='2019-04-28-00:00', end='2021-01-06-00:00', interval='4h')

# %%
macd_subperiod2.execute_backtest(ema_fast=8, ema_slow=7, ema_signal=26)

# %%
macd_subperiod2.data_init.Close.plot(figsize=(15,10))

# %%
macd_subperiod3 = Macd_long_backtester('BTCUSDT')

# %%
macd_subperiod3.prepare_data(start='2021-01-06-00:00', end='2022-09-17-00:00', interval='4h')

# %%
macd_subperiod3.execute_backtest(ema_fast=8, ema_slow=7, ema_signal=26)

# %%
macd_subperiod3.data_init.Close.plot(figsize=(15,10))
