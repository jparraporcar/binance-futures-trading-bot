# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_td = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_td.prepare_data(start='2018-01-29-20:00', end='2022-09-11-20:00', interval='1d')
# Out:
# 1686

# %%
macd_td.assign_trends(window_size=20, plot=True)

# %% [markdown]
# ## Analysis of 'sideways' trend 'EE'

# %%
macd_td.get_trend_dates(type='sideways', trend_ref='EE', do_plot=True)
# Out:
# date_init: 2018-08-11 00:00:00 1533945600000
# date_end: 2018-10-15 00:00:00 1539561600000
# (1533945600000, 1539561600000)

# %%
macd_opt_ee = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_ee.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-08-11-00:00', end_opt='2018-10-15-00:00', ema_fast_opt=(4,16,4), ema_slow_opt=(16,40,1), ema_sign_opt=(6, 30, 4), int_for_max='15m')
# Out:
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# 6241
# ...

# %%
macd_opt_ee.multiple_macd_strategy_max
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 15          15m             16             12               18         0.9917
#
#     multiple_macd_strategy  multiple_macd_strategy_net
# 15                1.069489                    0.738197

# %%
macd_opt_ee.multiple_macd_strategy_net_max
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 376          15m             36             12               22
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 376         0.9917                0.980832                    0.753563

# %%
filt30m = macd_opt_ee.opt_results.loc[macd_opt_ee.opt_results.interval_opt == '30m']
filt30m.loc[filt30m.multiple_macd_strategy ==filt30m.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 863          30m             39             12               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 863       0.988676                1.085166                     0.96502

# %%
filt30m.loc[filt30m.multiple_macd_strategy_net ==filt30m.multiple_macd_strategy_net.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 863          30m             39             12               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 863       0.988676                1.085166                     0.96502

# %%
filt1h= macd_opt_ee.opt_results.loc[macd_opt_ee.opt_results.interval_opt == '1h']
filt1h.loc[filt1h.multiple_macd_strategy ==filt1h.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 915           1h             18             12               18
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 915       0.988957                1.159299                     1.07298

# %%
filt1h.loc[filt1h.multiple_macd_strategy_net ==filt1h.multiple_macd_strategy_net.max() ]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 1241           1h             36             12               26
#
#       multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 1241       0.988957                1.134483                    1.078974

# %%
macd_opt_ee.opt_results.to_csv('sideways.csv', mode='w', index=False, header=True)

# %%
macd_opt_ee.opt_results
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0             15m             16              4                6
# 1             15m             16              4               10
# 2             15m             16              4               14
# 3             15m             16              4               18
# 4             15m             16              4               22
# ...           ...            ...            ...              ...
# 1291           1h             39             12               10
# 1292           1h             39             12               14
# 1293           1h             39             12               18
# 1294           1h             39             12               22
# 1295           1h             39             12               26
#
#       multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 0          0.991700                1.058174                    0.465412
# ...

# %%
test1 = pd.read_csv('sideways.csv')

# %%
test1
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0             15m             16              4                6
# 1             15m             16              4               10
# 2             15m             16              4               14
# 3             15m             16              4               18
# 4             15m             16              4               22
# ...           ...            ...            ...              ...
# 1291           1h             39             12               10
# 1292           1h             39             12               14
# 1293           1h             39             12               18
# 1294           1h             39             12               22
# 1295           1h             39             12               26
#
#       multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 0          0.991700                1.058174                    0.465412
# ...

# %%
test1.columns
# Out:
# Index(['interval_opt', 'macd_slow_opt', 'macd_fast_opt', 'macd_signal_opt',
#        'multiple_hold', 'multiple_macd_strategy',
#        'multiple_macd_strategy_net'],
#       dtype='object')

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   interval_opt                1296 non-null   object
#  1   macd_slow_opt               1296 non-null   int64
#  2   macd_fast_opt               1296 non-null   int64
#  3   macd_signal_opt             1296 non-null   int64
#  4   multiple_hold               1296 non-null   float64
#  5   multiple_macd_strategy      1296 non-null   float64
#  6   multiple_macd_strategy_net  1296 non-null   float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 71.0+ KB
