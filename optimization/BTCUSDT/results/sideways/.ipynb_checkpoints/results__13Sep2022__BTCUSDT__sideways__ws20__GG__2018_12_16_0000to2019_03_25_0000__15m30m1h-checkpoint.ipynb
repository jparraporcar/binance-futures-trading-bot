# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_td = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_td.prepare_data(start='2018-01-29-20:00', end='2022-09-11-20:00', interval='1d')
# Out:
# 1686

# %%
macd_td.assign_trends(window_size=20, plot=True)

# %% [markdown]
# ## Analysis of 'sideways' trend 'GG'

# %%
macd_td.get_trend_dates(type='sideways', trend_ref='GG', do_plot=True)
# Out:
# date_init: 2018-12-16 00:00:00 1544918400000
# date_end: 2019-03-25 00:00:00 1553472000000
# (1544918400000, 1553472000000)

# %%
macd_opt_gg = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_gg.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2018-12-16-00:00', end_opt='2019-03-25-00:00', ema_fast_opt=(3,20,4), ema_slow_opt=(16,40,4), ema_sign_opt=(6, 30, 4), int_for_max='15m')
# Out:
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 9481
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 4741
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371
# 2371

# %%
macd_opt_gg.opt_comb_num
# Out:
# 324

# %%
macd_opt_gg.opt_results
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0            15m             16              4                6
# 1            15m             16              4               10
# 2            15m             16              4               14
# 3            15m             16              4               18
# 4            15m             16              4               22
# ..           ...            ...            ...              ...
# 319           1h             36             12               10
# 320           1h             36             12               14
# 321           1h             36             12               18
# 322           1h             36             12               22
# 323           1h             36             12               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 0         1.258419                0.999316                    0.260543
# 1         1.258419                1.111206                    0.366346
# 2         1.258419                1.096963                    0.401863
# 3         1.258419                1.035598                    0.403335
# 4         1.258419                1.027473                    0.418261
# ..             ...                     ...                         ...
# 319       1.258776                0.968019                    0.842737
# 320       1.258776                0.981994                    0.862203
# 321       1.258776                1.027868                    0.914843
# 322       1.258776                1.022682                    0.916440
# 323       1.258776                1.015150                    0.912790
#
# [324 rows x 7 columns]

# %%
macd_opt_gg.multiple_macd_strategy_max
# Out:
#   interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 6          15m             16              8                6       1.258419
#
#    multiple_macd_strategy  multiple_macd_strategy_net
# 6                1.146178                    0.417046

# %%
macd_opt_gg.multiple_macd_strategy_net_max
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 89          15m             32             12               26       1.258419
#
#     multiple_macd_strategy  multiple_macd_strategy_net
# 89                1.004467                    0.646074

# %%
filt30m = macd_opt_gg.opt_results.loc[macd_opt_gg.opt_results.interval_opt == '30m']
filt30m.loc[filt30m.multiple_macd_strategy ==filt30m.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 212          30m             36             12               14
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 212       1.260787                1.362267                    1.061854

# %%
filt30m.loc[filt30m.multiple_macd_strategy_net ==filt30m.multiple_macd_strategy_net.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 177          30m             28             12               18
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 177       1.260787                1.344456                    1.067759

# %%
filt1h= macd_opt_gg.opt_results.loc[macd_opt_gg.opt_results.interval_opt == '1h']
filt1h.loc[filt1h.multiple_macd_strategy ==filt1h.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 222           1h             16              8                6
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 222       1.258776                1.276351                    1.008512

# %%
filt1h.loc[filt1h.multiple_macd_strategy_net ==filt1h.multiple_macd_strategy_net.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 223           1h             16              8               10
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 223       1.258776                1.243256                    1.021546

# %%
macd_opt_gg.opt_results.to_csv('sideways.csv', mode='a', index=False, header=False)

# %%
macd_opt_gg.opt_results
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0            15m             16              4                6
# 1            15m             16              4               10
# 2            15m             16              4               14
# 3            15m             16              4               18
# 4            15m             16              4               22
# ..           ...            ...            ...              ...
# 319           1h             36             12               10
# 320           1h             36             12               14
# 321           1h             36             12               18
# 322           1h             36             12               22
# 323           1h             36             12               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 0         1.258419                0.999316                    0.260543
# 1         1.258419                1.111206                    0.366346
# 2         1.258419                1.096963                    0.401863
# 3         1.258419                1.035598                    0.403335
# 4         1.258419                1.027473                    0.418261
# ..             ...                     ...                         ...
# 319       1.258776                0.968019                    0.842737
# 320       1.258776                0.981994                    0.862203
# 321       1.258776                1.027868                    0.914843
# 322       1.258776                1.022682                    0.916440
# 323       1.258776                1.015150                    0.912790
#
# [324 rows x 7 columns]
