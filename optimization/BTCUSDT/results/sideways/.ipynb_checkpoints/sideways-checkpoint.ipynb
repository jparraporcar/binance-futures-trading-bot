# %%
import pandas as pd

# %%
df_side = pd.read_csv('sideways.csv')

# %%
df_side
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0             15m             16              4                6
# 1             15m             16              4               10
# 2             15m             16              4               14
# 3             15m             16              4               18
# 4             15m             16              4               22
# ...           ...            ...            ...              ...
# 3559           1h             36             12               10
# 3560           1h             36             12               14
# 3561           1h             36             12               18
# 3562           1h             36             12               22
# 3563           1h             36             12               26
#
#       multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net  \
# 0          0.991700                1.058174                    0.465412
# 1          0.991700                1.022814                    0.504150
# 2          0.991700                0.983969                    0.519143
# 3          0.991700                0.987105                    0.554619
# 4          0.991700                0.987858                    0.571323
# ...             ...                     ...                         ...
# 3559       0.958424                1.068867                    0.981739
# 3560       0.958424                1.130066                    1.048594
# 3561       0.958424                1.055744                    0.976305
# 3562       0.958424                1.037076                    0.963946
# 3563       0.958424                1.028732                    0.964356
#
#      trend_ref            start_opt              end_opt
# 0           EE  2018-08-11 00:00:00  2018-10-15 00:00:00
# 1           EE  2018-08-11 00:00:00  2018-10-15 00:00:00
# 2           EE  2018-08-11 00:00:00  2018-10-15 00:00:00
# 3           EE  2018-08-11 00:00:00  2018-10-15 00:00:00
# 4           EE  2018-08-11 00:00:00  2018-10-15 00:00:00
# ...        ...                  ...                  ...
# 3559        NN  2020-05-08 00:00:00  2020-07-20 00:00:00
# 3560        NN  2020-05-08 00:00:00  2020-07-20 00:00:00
# 3561        NN  2020-05-08 00:00:00  2020-07-20 00:00:00
# 3562        NN  2020-05-08 00:00:00  2020-07-20 00:00:00
# 3563        NN  2020-05-08 00:00:00  2020-07-20 00:00:00
#
# [3564 rows x 10 columns]

# %%
df_side_15m = df_side[df_side.interval_opt == '15m']

# %%
df_side_15m_one = df_side_15m[df_side_15m.multiple_macd_strategy_net > 1]
