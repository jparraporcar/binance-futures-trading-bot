# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_td = Macd_long_backtester(symbol='BTCUSDT')

# %%
macd_td.prepare_data(start='2018-01-29-20:00', end='2022-09-11-20:00', interval='1d')
# Out:
# 1686

# %%
macd_td.assign_trends(window_size=20, plot=True)

# %% [markdown]
# ## Analysis of 'sideways' trend 'MM'

# %%
macd_td.get_trend_dates(type='sideways', trend_ref='MM', do_plot=True)
# Out:
# date_init: 2020-02-15 00:00:00 1581724800000
# date_end: 2020-04-19 00:00:00 1587254400000
# (1581724800000, 1587254400000)

# %%
macd_opt_mm = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_mm.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2020-02-15-00:00', end_opt='2020-04-19-00:00', ema_fast_opt=(4,16,4), ema_slow_opt=(16,40,4), ema_sign_opt=(6, 30, 4), int_for_max='15m')
# Out:
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 6114
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# 3058
# ...

# %%
macd_opt_mm.opt_comb_num
# Out:
# 324

# %%
macd_opt_mm.opt_results
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0            15m             16              4                6
# 1            15m             16              4               10
# 2            15m             16              4               14
# 3            15m             16              4               18
# 4            15m             16              4               22
# ..           ...            ...            ...              ...
# 319           1h             36             12               10
# 320           1h             36             12               14
# 321           1h             36             12               18
# 322           1h             36             12               22
# 323           1h             36             12               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 0         0.702748                0.666393                    0.286688
# ...

# %%
macd_opt_mm.multiple_macd_strategy_max
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 98          15m             36              8               14       0.702748
#
#     multiple_macd_strategy  multiple_macd_strategy_net
# 98                1.129888                    0.797999

# %%
macd_opt_mm.multiple_macd_strategy_net_max
# Out:
#    interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  multiple_hold  \
# 53          15m             24             12               26       0.702748
#
#     multiple_macd_strategy  multiple_macd_strategy_net
# 53                1.054783                    0.808314

# %%
filt30m = macd_opt_mm.opt_results.loc[macd_opt_mm.opt_results.interval_opt == '30m']
filt30m.loc[filt30m.multiple_macd_strategy ==filt30m.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 198          30m             36              4                6
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 198       0.704532                1.120548                    0.788715

# %%
filt30m.loc[filt30m.multiple_macd_strategy_net ==filt30m.multiple_macd_strategy_net.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 215          30m             36             12               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 215       0.704532                1.079199                    0.939528

# %%
filt1h= macd_opt_mm.opt_results.loc[macd_opt_mm.opt_results.interval_opt == '1h']
filt1h.loc[filt1h.multiple_macd_strategy ==filt1h.multiple_macd_strategy.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 231           1h             16             12               18
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 231       0.706674                1.322997                    1.234945

# %%
filt1h.loc[filt1h.multiple_macd_strategy_net ==filt1h.multiple_macd_strategy_net.max() ]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 231           1h             16             12               18
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net
# 231       0.706674                1.322997                    1.234945

# %%
df_imported = pd.read_csv('sideways.csv')

# %%
df_complete = pd.concat([df_imported, macd_opt_mm.opt_results], axis = 0)

# %%
df_complete.to_csv('sideways.csv', mode='w', index=False, header=True)
