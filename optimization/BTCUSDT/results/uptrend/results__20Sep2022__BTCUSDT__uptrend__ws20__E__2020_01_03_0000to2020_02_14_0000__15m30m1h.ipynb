# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1) Launch optimization

# %%
macd_opt_e = Macd_long_backtester('BTCUSDT')

# %%
macd_opt_e.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2020-01-03-00:00', end_opt='2020-02-14-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='E', type_trend='uptrend')
# Out:
# 4029
# 4049
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.134975           0.011576           0.03955
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.292702                    0.360135              -0.093378
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.04319              -2.162058
# processed 1 out of a total 4788
# 4029
# 4051
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.188261           0.015771          0.039118
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.403168                    0.513815              -0.060884
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.042031              -1.448567
# processed 2 out of a total 4788
# 4029
# 4053
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.164618           0.013934          0.039229
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.355192                    0.562451              -0.052615
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041873              -1.256539
# processed 3 out of a total 4788
# 4029
# 4055
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.125734           0.010829          0.039319
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.275409                    0.576033              -0.050433
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041823               -1.20588
# processed 4 out of a total 4788
# 4029
# 4057
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.09956           0.008678          0.038999
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.222516                    0.581116               -0.04963
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041359               -1.19998
# processed 5 out of a total 4788
# 4029
# 4059
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.094996           0.008298          0.038602
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.214954                    0.604866              -0.045968
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040883              -1.124364
# processed 6 out of a total 4788
# 4029
# 4061
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.136928           0.011734          0.038788
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.302506                    0.648652              -0.039578
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040965              -0.966139
# processed 7 out of a total 4788
# 4029
# 4063
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.135854           0.011647          0.038688
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.301056                    0.661399              -0.037798
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040825              -0.925849
# processed 8 out of a total 4788
# 4029
# 4065
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.119837           0.010349          0.038295
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.270233                     0.65876              -0.038164
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040371              -0.945313
# processed 9 out of a total 4788
# 4029
# 4067
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.135791           0.011642          0.038353
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.303551                    0.679027              -0.035393
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040364              -0.876838
# processed 10 out of a total 4788
# 4029
# 4069
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.136697           0.011715          0.038592
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.303563                    0.685372              -0.034543
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.04056              -0.851637
# processed 11 out of a total 4788
# 4029
# 4071
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.135947           0.011655           0.03867
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.301389                    0.696667              -0.033048
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040617              -0.813659
# processed 12 out of a total 4788
# 4029
# 4073
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.134941           0.011574          0.038582
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.299972                    0.705584              -0.031885
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040494              -0.787403
# processed 13 out of a total 4788
# 4029
# 4075
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.161466           0.013686          0.038732
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.353345                     0.72824              -0.028996
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040612              -0.713968
# processed 14 out of a total 4788
# 4029
# 4077
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.163361           0.013835          0.038885
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.355792                    0.731914              -0.028536
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040739              -0.700439
# processed 15 out of a total 4788
# 4029
# 4079
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.144906           0.012373          0.038841
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.318556                    0.714204              -0.030775
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040697              -0.756195
# processed 16 out of a total 4788
# 4029
# 4081
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.162948           0.013803          0.038895
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.35487                    0.734146              -0.028257
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040706              -0.694177
# processed 17 out of a total 4788
# 4029
# 4083
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.151727           0.012916          0.039028
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.330943                    0.730781              -0.028677
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040841              -0.702171
# processed 18 out of a total 4788
# 4029
# 4085
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.143877           0.012291          0.039054
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.314709                    0.723337              -0.029613
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040881              -0.724372
# processed 19 out of a total 4788
# 4029
# 4049
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.188261           0.015771          0.039118
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.403168                    0.513815              -0.060884
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.042031              -1.448567
# processed 20 out of a total 4788
# 4029
# 4051
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.177697           0.014955          0.039285
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.380675                    0.618192              -0.043975
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041573              -1.057786
# processed 21 out of a total 4788
# 4029
# 4053
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.128689           0.011069          0.039081
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.283219                    0.648347              -0.039621
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041079                -0.9645
# processed 22 out of a total 4788
# 4029
# 4055
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.109599           0.009509          0.038593
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.246386                    0.681087              -0.035116
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040433              -0.868514
# processed 23 out of a total 4788
# 4029
# 4057
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.090637           0.007933           0.03809
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.208266                    0.692608              -0.033582
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039833              -0.843082
# processed 24 out of a total 4788
# 4029
# 4059
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.119192           0.010296          0.038347
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.268494                    0.729105              -0.028887
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039933              -0.723383
# processed 25 out of a total 4788
# 4029
# 4061
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.112934           0.009783           0.03843
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.254578                    0.734335              -0.028234
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039934              -0.707013
# processed 26 out of a total 4788
# 4029
# 4063
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.149975           0.012777          0.038479
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.332045                    0.767862              -0.024152
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039853              -0.606013
# processed 27 out of a total 4788
# 4029
# 4065
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.18776           0.015733          0.038525
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.40838                    0.816354              -0.018552
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039845              -0.465617
# processed 28 out of a total 4788
# 4029
# 4067
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.229918           0.018922          0.038499
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.491486                    0.874575              -0.012254
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039715              -0.308542
# processed 29 out of a total 4788
# 4029
# 4069
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.215814           0.017867          0.038661
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.462145                    0.863076              -0.013464
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039885              -0.337562
# processed 30 out of a total 4788
# 4029
# 4071
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.229427           0.018885          0.038773
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.48707                    0.880193              -0.011668
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039978              -0.291861
# processed 31 out of a total 4788
# 4029
# 4073
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.21728           0.017977          0.038851
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.462726                    0.868537              -0.012887
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040054              -0.321744
# processed 32 out of a total 4788
# 4029
# 4075
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.210823           0.017491           0.03883
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.450454                    0.869827              -0.012751
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040002              -0.318767
# processed 33 out of a total 4788
# 4029
# 4077
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.199414           0.016625          0.038885
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.427553                    0.864566              -0.013306
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040066              -0.332102
# processed 34 out of a total 4788
# 4029
# 4079
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.197823           0.016504          0.038904
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.424232                    0.863419              -0.013427
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040099              -0.334852
# processed 35 out of a total 4788
# 4029
# 4081
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.190104           0.015913          0.039023
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.407787                    0.865181              -0.013241
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040169              -0.329632
# processed 36 out of a total 4788
# 4029
# 4083
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.193783           0.016195          0.039117
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.414021                    0.863439              -0.013425
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040271              -0.333371
# processed 37 out of a total 4788
# 4029
# 4085
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.192057           0.016063          0.039374
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.407962                    0.868076              -0.012936
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.04054               -0.31908
# processed 38 out of a total 4788
# 4029
# 4049
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.164618           0.013934          0.039229
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.355192                    0.562451              -0.052615
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041873              -1.256539
# processed 39 out of a total 4788
# 4029
# 4051
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.128689           0.011069          0.039081
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.283219                    0.648347              -0.039621
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041079                -0.9645
# processed 40 out of a total 4788
# 4029
# 4053
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.123219           0.010624          0.038494
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.275998                     0.70726              -0.031668
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040206              -0.787646
# processed 41 out of a total 4788
# 4029
# 4055
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.138287           0.011843          0.038309
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.309137                    0.741545               -0.02734
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039778              -0.687325
# processed 42 out of a total 4788
# 4029
# 4057
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.14543           0.012415          0.038578
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.32181                    0.776623              -0.023114
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039883              -0.579546
# processed 43 out of a total 4788
# 4029
# 4059
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.177066           0.014906          0.038636
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.385801                    0.814526              -0.018757
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039889              -0.470244
# processed 44 out of a total 4788
# 4029
# 4061
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.185553           0.015563          0.038568
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.403517                    0.844463              -0.015457
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039738              -0.388974
# processed 45 out of a total 4788
# 4029
# 4063
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.210615           0.017475          0.038558
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.453222                    0.880092              -0.011679
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039672               -0.29438
# processed 46 out of a total 4788
# 4029
# 4065
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.242208           0.019831          0.038745
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.51183                    0.918548              -0.007768
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039794              -0.195211
# processed 47 out of a total 4788
# 4029
# 4067
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.255759           0.020823          0.038866
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.535755                    0.936497              -0.005999
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039857               -0.15051
# processed 48 out of a total 4788
# 4029
# 4069
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.264936           0.021489          0.039124
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.549242                    0.951396              -0.004556
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040083              -0.113656
# processed 49 out of a total 4788
# 4029
# 4071
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.255168            0.02078          0.039175
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.530437                    0.952111              -0.004487
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040148              -0.111761
# processed 50 out of a total 4788
# 4029
# 4073
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.24738           0.020211          0.039177
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.515885                    0.941389              -0.005522
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040147              -0.137558
# processed 51 out of a total 4788
# 4029
# 4075
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.228459           0.018813          0.039112
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.481015                    0.931851              -0.006454
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040064              -0.161082
# processed 52 out of a total 4788
# 4029
# 4077
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.234408           0.019255           0.03909
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.492583                    0.937957              -0.005856
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040027              -0.146311
# processed 53 out of a total 4788
# 4029
# 4079
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.234036           0.019227          0.039108
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.491644                    0.940869              -0.005573
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040032              -0.139215
# processed 54 out of a total 4788
# 4029
# 4081
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.234634           0.019272          0.039045
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.493582                    0.950979              -0.004596
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039919              -0.115125
# processed 55 out of a total 4788
# 4029
# 4083
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.206982           0.017201          0.038956
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.441537                    0.931262              -0.006511
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039845              -0.163414
# processed 56 out of a total 4788
# 4029
# HTTPSConnectionPool(host='api.binance.com', port=443): Read timed out.
# Something went wrong. Error occured at 2022-09-22 04:27:50.767862+00:00. Wait for 1 min.
# 4085
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.214327           0.017755          0.038992
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.455355                     0.93693              -0.005957
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039852              -0.149469
# processed 57 out of a total 4788
# 4029
# 4049
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.125734           0.010829          0.039319
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.275409                    0.576033              -0.050433
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041823               -1.20588
# processed 58 out of a total 4788
# 4029
# 4051
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.109599           0.009509          0.038593
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.246386                    0.681087              -0.035116
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.040433              -0.868514
# processed 59 out of a total 4788
# 4029
# 4053
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.138287           0.011843          0.038309
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.309137                    0.741545               -0.02734
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039778              -0.687325
# processed 60 out of a total 4788
# 4029
# 4055
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.13969           0.011955          0.038611
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.309634                    0.783315               -0.02233
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039897              -0.559691
# processed 61 out of a total 4788
# 4029
# 4057
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.175237           0.014764          0.038653
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.381953                      0.8244              -0.017656
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039814              -0.443459
# processed 62 out of a total 4788
# 4029
# 4059
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.189842           0.015893          0.038571
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.412038                    0.866462              -0.013106
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039677              -0.330312
# processed 63 out of a total 4788
# 4029
# 4061
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.237499           0.019484          0.038632
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.50434                    0.924451              -0.007183
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039611              -0.181327
# processed 64 out of a total 4788
# 4029
# 4063
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.268471           0.021744           0.03888
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.55925                     0.96384              -0.003368
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0                0.0398               -0.08461
# processed 65 out of a total 4788
# 4029
# 4065
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.241843           0.019804          0.038922
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.508815                    0.958159              -0.003908
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039852              -0.098061
# processed 66 out of a total 4788
# 4029
# 4067
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.205394            0.01708          0.038794
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.44028                    0.928457              -0.006787
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039678              -0.171055
# processed 67 out of a total 4788
# 4029
# 4069
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.22216           0.018343          0.038841
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.47227                    0.947796              -0.004902
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039683              -0.123536
# processed 68 out of a total 4788
# 4029
# 4071
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.214802           0.017791          0.038844
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.458018                      0.9453              -0.005143
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039667              -0.129663
# processed 69 out of a total 4788
# 4029
# 4073
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.229546           0.018894          0.038996
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.484509                    0.955147              -0.004196
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.03985              -0.105292
# processed 70 out of a total 4788
# 4029
# 4075
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.210095           0.017436           0.03898
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.44731                    0.935253               -0.00612
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039824              -0.153685
# processed 71 out of a total 4788
# 4029
# 4077
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.187383           0.015704          0.038828
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.404442                    0.923964              -0.007231
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039639              -0.182416
# processed 72 out of a total 4788
# 4029
# 4079
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.190691           0.015958          0.038845
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.410815                    0.934449              -0.006199
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039638               -0.15639
# processed 73 out of a total 4788
# 4029
# 4081
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.206015           0.017127           0.03881
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.441314                     0.95944              -0.003786
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039559              -0.095699
# processed 74 out of a total 4788
# 4029
# 4083
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.200649            0.01672          0.038978
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.428946                    0.951928              -0.004505
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039718              -0.113413
# processed 75 out of a total 4788
# 4029
# 4085
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.200777           0.016729          0.038947
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.429545                    0.952029              -0.004495
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039648              -0.113369
# processed 76 out of a total 4788
# 4029
# 4049
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.09956           0.008678          0.038999
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.222516                    0.581116               -0.04963
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.041359               -1.19998
# processed 77 out of a total 4788
# 4029
# 4051
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.090637           0.007933           0.03809
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.208266                    0.692608              -0.033582
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039833              -0.843082
# processed 78 out of a total 4788
# 4029
# 4053
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                 1.14543           0.012415          0.038578
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0            0.32181                    0.776623              -0.023114
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039883              -0.579546
# processed 79 out of a total 4788
# 4029
# 4055
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.175237           0.014764          0.038653
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.381953                      0.8244              -0.017656
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039814              -0.443459
# processed 80 out of a total 4788
# 4029
# 4057
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.202228            0.01684          0.038593
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.436344                    0.876972              -0.012003
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0               0.03967              -0.302577
# processed 81 out of a total 4788
# 4029
# 4059
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.262031           0.021279          0.038818
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.548161                    0.954067              -0.004299
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.039733              -0.108205
# processed 82 out of a total 4788
# 4029
# 4061
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       1.470931           0.035284          0.053896           0.654659
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                1.239633           0.019641          0.039136
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0           0.501872                    0.954829              -0.004226
#
# ...
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:396, in Macd_long_backtester.execute_opt(self, start_opt, end_opt, interval_opt, ema_slow_opt, ema_fast_opt, ema_sign_opt, int_for_max, type_trend, trend_ref)
#     395 self.prepare_data(start=start_opt, end=end_opt, interval=comb[0])
# --> 396 tuple_results = (*self.execute_backtest(start=self.start, ema_slow=comb[1], ema_fast=comb[2], ema_signal=comb[3]), trend_ref, start_opt, end_opt)
#     397 results.append(tuple_results)
#
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:296, in Macd_long_backtester.execute_backtest(self, start, ema_slow, ema_fast, ema_signal)
#     295 pre_from_time = int((from_time_obj - td).timestamp()*1000)
# --> 296 self.data_init_pre = utils.get_history_v2(symbol=self.symbol, interval=self.interval, start=pre_from_time, end=self.to_time)[0]
#     297 #Assign the MACD parameters to the class to see which para,tershave been used last
#
# File ~/Desktop/Investment/utils/utils.py:90, in get_history_v2(symbol, interval, start, end)
#      89 api_secret = "LeiOCoJdBuCtfgrt1WfsBweeyC2ZwuogPuDrkXFTioEGoaZYOGkju1GRM3yVqp7v"
# ---> 90 client = Client(api_key=api_key, api_secret=api_secret)
#      92 try:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:300, in Client.__init__(self, api_key, api_secret, requests_params, tld, testnet)
#     299 # init DNS and SSL cert
# --> 300 self.ping()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:526, in Client.ping(self)
#     513 """Test connectivity to the Rest API.
#     514
#     515 https://binance-docs.github.io/apidocs/spot/en/#test-connectivity
#    (...)
#     524
#     525 """
# --> 526 return self._get('ping', version=self.PRIVATE_API_VERSION)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:371, in Client._get(self, path, signed, version, **kwargs)
#     370 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 371     return self._request_api('get', path, signed, version, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:334, in Client._request_api(self, method, path, signed, version, **kwargs)
#     333 uri = self._create_api_uri(path, signed, version)
# --> 334 return self._request(method, uri, signed, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:314, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     312 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
# --> 314 self.response = getattr(self.session, method)(uri, **kwargs)
#     315 return self._handle_response(self.response)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561 if isinstance(e.reason, _SSLError):
#     562     # This branch is for urllib3 v1.22 and later.
# --> 563     raise SSLError(e, request=request)
#     565 raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fa4f1629580>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa4f1629580>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 macd_opt_e.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2020-01-03-00:00', end_opt='2020-02-14-00:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='1h', trend_ref='E', type_trend='uptrend')
#
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:404, in Macd_long_backtester.execute_opt(self, start_opt, end_opt, interval_opt, ema_slow_opt, ema_fast_opt, ema_sign_opt, int_for_max, type_trend, trend_ref)
#     402         api_key = "Q3Zsx6rO7uy0YntyWjb9CTGxbQAfENBxbPAkeOtksXm2AcLcu1y7IOj1fgPFtutO"
#     403         api_secret = "LeiOCoJdBuCtfgrt1WfsBweeyC2ZwuogPuDrkXFTioEGoaZYOGkju1GRM3yVqp7v"
# --> 404         client = Client(api_key, api_secret)
#     405 except KeyboardInterrupt as e2:
#     406         print("error type is 'KeyboardInterrupt'. The data calculated so far has been stored in self.opt_results")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:300, in Client.__init__(self, api_key, api_secret, requests_params, tld, testnet)
#     297 super().__init__(api_key, api_secret, requests_params, tld, testnet)
#     299 # init DNS and SSL cert
# --> 300 self.ping()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:526, in Client.ping(self)
#     512 def ping(self) -> Dict:
#     513     """Test connectivity to the Rest API.
#     514
#     515     https://binance-docs.github.io/apidocs/spot/en/#test-connectivity
#    (...)
#     524
#     525     """
# --> 526     return self._get('ping', version=self.PRIVATE_API_VERSION)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:371, in Client._get(self, path, signed, version, **kwargs)
#     370 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 371     return self._request_api('get', path, signed, version, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:334, in Client._request_api(self, method, path, signed, version, **kwargs)
#     330 def _request_api(
#     331     self, method, path: str, signed: bool = False, version=BaseClient.PUBLIC_API_VERSION, **kwargs
#     332 ):
#     333     uri = self._create_api_uri(path, signed, version)
# --> 334     return self._request(method, uri, signed, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/binance/client.py:314, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     310 def _request(self, method, uri: str, signed: bool, force_params: bool = False, **kwargs):
#     312     kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
# --> 314     self.response = getattr(self.session, method)(uri, **kwargs)
#     315     return self._handle_response(self.response)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.binance.com', port=443): Max retries exceeded with url: /api/v3/ping (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa4f1629580>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# ### 2) Extract combinations of max

# %% [markdown]
# ### 8) Further...

# %% [markdown]
# ### 7) Plot the accumulated max_net vs hold

# %% [markdown]
# ### 6) Create new class for interval of max_net and launch backtest for the combinations of max_net

# %% [markdown]
# ### 5) Extract combinations of max_net

# %% [markdown]
# ### 4) Plot the accumulated max vs hold

# %% [markdown]
# ### 3) Create new class for interval of max and launch backtest for the combinations of max
