# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_overall = Macd_long_backtester('BTCUSDT')

# %%
macd_overall.execute_opt(interval_opt=('15m', '30m', '1h') ,start_opt='2022-09-14-04:00', end_opt='2022-09-18-16:00', ema_fast_opt=(2,16,2), ema_slow_opt=(16,40,2), ema_sign_opt=(2, 40, 2), int_for_max='15m', type_trend='overall', trend_ref='cpi_after_drop_2')
# Out:
# 433
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.995549          -0.003769          0.052417          -0.071908
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.971594          -0.024348          0.031532
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 0          -0.772157                    0.858895              -0.128518
#
#    ann_log_std_macd_net  sharpe_ratio_macd_net
# 0              0.035688              -3.601128
# processed 1 out of a total 4788
# 433
#    multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 0       0.995549          -0.003769          0.052417          -0.071908
#
#    multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 0                0.969401          -0.026257           0.03111
#
#    sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# ...

# %%
macd_overall.opt_results.multiple_macd_strategy.max()
# Out:
# 1.02731754218866

# %%
macd_overall.opt_results[macd_overall.opt_results.multiple_macd_strategy_net == macd_overall.opt_results.multiple_macd_strategy_net.max()]
# Out:
#      interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 4404           1h             34              2               32
# 4405           1h             34              2               34
# 4406           1h             34              2               36
#
#       multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 4404       0.988641           -0.03861          0.089293          -0.432402
# 4405       0.988641           -0.03861          0.089293          -0.432402
# 4406       0.988641           -0.03861          0.089293          -0.432402
#
#       multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 4404                1.022135           0.073991          0.035574
# 4405                1.022135           0.073991          0.035574
# 4406                1.022135           0.073991          0.035574
#
#       sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# ...

# %%
macd_overall.opt_results[macd_overall.opt_results.multiple_macd_strategy == macd_overall.opt_results.multiple_macd_strategy.max()]
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 190          15m             18              8                2
#
#      multiple_hold  ann_log_mean_hold  ann_log_std_hold  sharpe_ratio_hold  \
# 190       0.995549          -0.003769          0.052417          -0.071908
#
#      multiple_macd_strategy  ann_log_mean_macd  ann_log_std_macd  \
# 190                1.027318           0.022771          0.029306
#
#      sharpe_ratio_macd  multiple_macd_strategy_net  ann_log_mean_macd_net  \
# 190           0.777006                    0.968779              -0.026799
#
#      ann_log_std_macd_net  sharpe_ratio_macd_net         trend_ref  \
# 190              0.031692              -0.845615  cpi_after_drop_2
#
#             start_opt           end_opt
# 190  2022-09-14-04:00  2022-09-18-16:00

# %%
macd_overall.data_init.multiple_hold_acum.plot()
macd_overall.data_init
# Out:
#                          Open      High       Low     Close       Volume  \
# Date
# 2022-09-13 19:00:00  20248.52  20346.00  20030.00  20283.58  19949.15336
# 2022-09-13 20:00:00  20284.89  20421.15  20224.10  20233.14  11263.72471
# 2022-09-13 21:00:00  20233.14  20281.00  19860.00  20131.58  12954.19030
# 2022-09-13 22:00:00  20131.58  20265.00  20068.85  20224.16  12591.56219
# 2022-09-13 23:00:00  20224.16  20245.00  20098.87  20173.57   8478.20032
# ...                       ...       ...       ...       ...          ...
# 2022-09-18 03:00:00  20032.92  20038.65  19951.00  20000.33   6559.30453
# 2022-09-18 04:00:00  20000.33  20033.37  19953.58  20010.57   5760.80635
# 2022-09-18 05:00:00  20010.57  20085.14  19995.96  20071.80   4748.91706
# 2022-09-18 06:00:00  20071.80  20098.00  20029.88  20038.55   5746.91721
# 2022-09-18 07:00:00  20039.62  20089.73  20034.06  20053.17   6562.76015
#
#                      log_returns_hold  multiple_hold_acum  position  inv_sign  \
# ...
