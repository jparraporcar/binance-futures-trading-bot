# %%
import sys
sys.path.append('/Users/jp/Desktop/Investment/trading_BOT/macd_long_backtester')
from macd_long_backtester import Macd_long_backtester
import pandas as pd

# %%
macd_overall = Macd_long_backtester('BTCUSDT')

# %%
macd_overall.execute_opt(interval_opt=('1h', '4h', '1d') ,start_opt='2018-01-01-00:00', end_opt='2020-01-01-08:00', ema_fast_opt=(4,16,1), ema_slow_opt=(16,40,1), ema_sign_opt=(6, 30, 1), int_for_max='4h', type_trend='overall', trend_ref='random1')
# Out:
# 17439
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 macd_overall.execute_opt(interval_opt=('1h', '4h', '1d') ,start_opt='2018-01-01-00:00', end_opt='2020-01-01-08:00', ema_fast_opt=(4,16,1), ema_slow_opt=(16,40,1), ema_sign_opt=(6, 30, 1), int_for_max='4h', type_trend='overall', trend_ref='random1')
#
# File ~/Desktop/Investment/trading_BOT/macd_long_backtester/macd_long_backtester.py:340, in Macd_long_backtester.execute_opt(self, start_opt, end_opt, interval_opt, ema_slow_opt, ema_fast_opt, ema_sign_opt, int_for_max, type_trend, trend_ref)
#     338 try:
#     339     self.prepare_data(start=start_opt, end=end_opt, interval=comb[0])
# --> 340     tuple_results = (*self.execute_backtest(comb[1], comb[2], comb[3]), trend_ref, start_opt, end_opt)
#     341     results.append(tuple_results)
#     342 except Exception as e:
#
# ...

# %%
macd_overall.opt_results
# Out:
#     interval_opt  macd_slow_opt  macd_fast_opt  macd_signal_opt  \
# 0             1h             16              4                6
# 1             1h             16              4                7
# 2             1h             16              4                8
# 3             1h             16              4                9
# 4             1h             16              4               10
# ..           ...            ...            ...              ...
# 712           1h             18              9               22
# 713           1h             18              9               23
# 714           1h             18              9               24
# 715           1h             18              9               25
# 716           1h             18              9               26
#
#      multiple_hold  multiple_macd_strategy  multiple_macd_strategy_net  \
# 0          0.54457                0.445359                    0.046669
# ...
